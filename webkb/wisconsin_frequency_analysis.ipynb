# %% [markdown]
# Import dependencies

# %%
from model.layers import GraphSpectralFilterLayer, AnalysisFilter
from model.spectral_filter import Graph
import torch
import torch.nn.functional as F
from torch import nn
from random import seed as rseed
from numpy.random import seed as nseed
from webkb import get_dataset, run
from webkb.train_eval import evaluate
import numpy as np

# %% [markdown]
# Define hyperparameters

# %%
dataset_name = 'wisconsin'

random_splits = False
runs = 1
epochs =2000
alpha = 0.2
seed =729
lr =0.01
weight_decay = 0.0008
patience=100
hidden=256
heads = 4
dropout=0.2
normalize_features =True
pre_training = False
cuda = False
order =16
edge_dropout =0
node_feature_dropout =0
filter_name ='analysis'

rseed(seed)
nseed(seed)
torch.manual_seed(seed)

cuda = cuda and torch.cuda.is_available()

if cuda:
    torch.cuda.manual_seed(seed)
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
    
def get_correctly_predicted_node_idx(net, key, dataset):
    net.eval()
    with torch.no_grad():
        logits  = net(dataset[0])[0]
    mask = dataset[0]['{}_mask'.format(key)][1, :]
    pred = logits[mask].max(1)[1]
    return { *pred.eq(dataset[0].y[mask]).nonzero().view(-1).tolist() }

# %%
def matching_labels_distribution(nodes_set):
    hop_1_matching_percent = []
    hop_2_matching_percent = []
    hop_3_matching_percent = []
    for n in nodes_set:
        hop_1_neighbours = list(nx.ego_graph(G, n.item(), 1).nodes())
        hop_2_neighbours = list(nx.ego_graph(G, n.item(), 2).nodes())
        hop_3_neighbours = list(nx.ego_graph(G, n.item(), 3).nodes())
        node_label = dataset[0].y[n]
        hop_1_labels = dataset[0].y[hop_1_neighbours]
        hop_2_labels = dataset[0].y[hop_2_neighbours]
        hop_3_labels = dataset[0].y[hop_3_neighbours]
        matching_1_labels = node_label == hop_1_labels
        matching_2_labels = node_label == hop_2_labels
        matching_3_labels = node_label == hop_3_labels
        hop_1_matching_percent.append(matching_1_labels.float().sum()/matching_1_labels.shape[0])
        hop_2_matching_percent.append(matching_2_labels.float().sum()/matching_2_labels.shape[0])
        hop_3_matching_percent.append(matching_3_labels.float().sum()/matching_3_labels.shape[0])


    print('matching labels in 1st hop:', torch.tensor(hop_1_matching_percent).mean())
    print('matching labels in 2st hop:', torch.tensor(hop_2_matching_percent).mean())
    print('matching labels in 3rd hop:', torch.tensor(hop_3_matching_percent).mean())
    plt.figure(figsize=(15,3))
    plt.subplot(1, 3, 1)
    plt.hist(hop_1_matching_percent, color = 'blue', edgecolor = 'black', bins = 10)
    plt.subplot(1, 3, 2)
    plt.hist(hop_2_matching_percent, color = 'blue', edgecolor = 'black', bins = 10)
    plt.subplot(1, 3, 3)
    plt.hist(hop_2_matching_percent, color = 'blue', edgecolor = 'black', bins = 10)
    return hop_1_matching_percent, hop_2_matching_percent, hop_3_matching_percent

# %% [markdown]
# Define model

# %%
class Net(torch.nn.Module):
    def __init__(self, dataset):
        super(Net, self).__init__()
        data = dataset[0]
        adj = torch.sparse_coo_tensor(data.edge_index, torch.ones(data.num_edges))
        self.G = Graph(adj)
        self.G.estimate_lmax()

        self.analysis = GraphSpectralFilterLayer(self.G, dataset.num_node_features, hidden,
                                                 dropout=dropout, out_channels=heads, filter=filter_name,
                                                 pre_training=pre_training, device='cuda' if cuda else 'cpu',
                                                 alpha=alpha, order=order)
        # self.mlp = nn.Sequential(nn.Linear(hidden * heads, 128),
        #                             nn.ReLU(inplace=True),
        #                             nn.Linear(128, 64),
        #                             nn.ReLU(inplace=True),
        #                             nn.Linear(64, 32),
        #                             nn.ReLU(inplace=True),
        #                             nn.Linear(32, dataset.num_classes),
        #                             nn.ReLU(inplace=True))

        # self.W = torch.zeros(hidden * heads, dataset.num_classes)

        self.synthesis = GraphSpectralFilterLayer(self.G, hidden * heads, dataset.num_classes, filter=filter_name,
                                                  device='cuda' if cuda else 'cpu', dropout=dropout,
                                                  out_channels=1, alpha=alpha, pre_training=False,
                                                  order=order)

    def reset_parameters(self):
        self.analysis.reset_parameters()
        # torch.nn.init.xavier_uniform_(self.W.data, gain=1.414)
        # for layer in self.mlp:
        #     if hasattr(layer, 'reset_parameters'):
        #         layer.reset_parameters()
        self.synthesis.reset_parameters()

    def forward(self, data):
        x = data.x
        x = F.dropout(x, p=dropout, training=self.training)
        x, attentions_1 = self.analysis(x)
        x = F.dropout(x, p=dropout, training=self.training)
        x, attentions_2 = self.synthesis(x)
        x = F.elu(x)
        # x = F.elu(x.mm(self.W))
        # x = self.mlp(x)
        return F.log_softmax(x, dim=1), attentions_1, attentions_2


dataset = get_dataset(dataset_name, normalize_features, edge_dropout=edge_dropout,
                                node_feature_dropout=node_feature_dropout)

if cuda:
    dataset[0].to('cuda')

# permute_masks = random_planetoid_splits if random_splits else None
# run(dataset, Net(dataset), runs, epochs, lr, weight_decay,
#     early_stopping, permute_masks)

# %%
class SingleNet(torch.nn.Module):
    def __init__(self, dataset):
        super(SingleNet, self).__init__()
        data = dataset[0]
        adj = torch.sparse_coo_tensor(data.edge_index, torch.ones(data.num_edges))
        self.G = Graph(adj)
        self.G.estimate_lmax()

        self.analysis = GraphSpectralFilterLayer(self.G, dataset.num_node_features, hidden,
                                                 dropout=dropout, out_channels=heads, filter=filter_name,
                                                 pre_training=pre_training, device='cuda' if cuda else 'cpu',
                                                 alpha=alpha, order=order)

        self.linear = torch.nn.Linear(hidden * heads, dataset.num_classes)

    def reset_parameters(self):
        self.analysis.reset_parameters()
        self.linear.reset_parameters()

    def forward(self, data):
        x = data.x
        x = F.dropout(x, p=dropout, training=self.training)
        x, attentions_1 = self.analysis(x)
        x = F.dropout(x, p=dropout, training=self.training)
        x = F.elu(self.linear(x))
        return F.log_softmax(x, dim=1), attentions_1, None

# %% [markdown]
# Load trained model and evaluate

# %%
model = Net(dataset)
model.load_state_dict(torch.load('./model/best_wisconsin_dec.pkl'.format(dataset_name),  map_location={'cuda:0': 'cpu'}))

# model = SingleNet(dataset)
# model.load_state_dict(torch.load('./model/best_wisconsin_single_dec.pkl'.format(dataset_name)))

filter_kernel = model.analysis.filter_kernel
# syn_filter_kernel = model.synthesis.filter_kernel

model_correct_indices = get_correctly_predicted_node_idx(model, 'test', dataset)
eval_info = evaluate(model, dataset[0], split=1)
print(eval_info)
# Out:
# {'train_loss': 0.07130248099565506, 'train_acc': 1.0, 'train_macro_f1': 1.0, 'val_loss': 0.7196247577667236, 'val_acc': 0.8125, 'val_macro_f1': 0.6486301206448175, 'test_loss': 0.5243783593177795, 'test_acc': 0.8431372549019607, 'test_macro_f1': 0.6788089330024814}

# %% [markdown]
# Obtain attention weights in layer 1 and 2

# %%
with torch.no_grad():
    _, att1, att2 = model(dataset[0])
model_att1_sum = torch.stack(att1).sum(dim=0)

# %%
for i in range(heads):
    print(att1[i][(att1[i].bool().float() - torch.eye(att1[i].shape[0], att1[i].shape[1])).nonzero(as_tuple=True)].mean())
# Out:
# tensor(0.1428)
# tensor(5.5403e-06)
# tensor(2.5722e-06)
# tensor(2.0865e-05)

# %% [markdown]
# Build NetworkX Graph

# %%
import networkx as nx
from scipy.sparse import coo_matrix
import numpy as np

# Build graph
adj = coo_matrix(
    (np.ones(dataset[0].num_edges),
    (dataset[0].edge_index[0].numpy(), dataset[0].edge_index[1].numpy())),
    shape=(dataset[0].num_nodes, dataset[0].num_nodes))
G = nx.Graph(adj)

# %%
from matplotlib import pyplot as plt
def plot_filter_banks(idx=list(range(heads)), kernel=model.analysis.filter._kernel, ax=None, no_ticks=False, legend=True):
    x = torch.linspace(0, 2, 100)
    if not ax:
        plt.figure(figsize=(10,10))
        plt.plot(x, kernel(x).detach()[:, idx])
#         if len(idx) > 1 and legend:
#             plt.legend(['filter {}'.format(i) for i in range(1, len(idx) + 1)])
#         plt.show()
    else:
        ax.plot(x, kernel(x).detach()[:, idx])
#         if len(idx) > 1 and legend:
#             ax.legend(['filter {}'.format(i) for i in range(1, len(idx) + 1)])
    if no_ticks:
        plt.xticks([])
        plt.yticks([])
    else:
        plt.xticks(fontsize=18)
        plt.yticks(fontsize=18)

# %% [markdown]
# Plot filterbanks in layer 1 and 2

# %%
plt.figure(figsize=(15,10))
ax1 = plt.subplot(2, 2, 1)
ax1.set_title('layer 1 fitlerbanks')
plot_filter_banks(kernel=model.analysis.filter._kernel, ax=ax1, idx=[2])
ax2 = plt.subplot(2, 2, 2)
ax2.set_title('chebyshev approx. layer 1 fitlerbanks')
plot_filter_banks(kernel=model.analysis.filter.cheby_eval, ax=ax2)

if hasattr(model, 'synthesis'):
    ax3 = plt.subplot(2, 2, 3)
    ax3.set_title('layer 2 fitlerbank')
    plot_filter_banks(idx=[0], kernel=model.synthesis.filter._kernel, ax=ax3, legend=False)
    ax4 = plt.subplot(2, 2, 4)
    ax4.set_title('chebyshev approx. layer 2 fitlerbank')
    plot_filter_banks(idx=[0], kernel=model.synthesis.filter.cheby_eval, ax=ax4, legend=False)

# %%
for i in range(heads):
    plot_filter_banks(idx=[i], kernel=model.analysis.filter._kernel)
    plt.savefig('./node_269_filter_{}.svg'.format(str(i)), format='svg', dpi=450)

# %%
node = 14
# node = model_not_gat_correct_nodes[1].item()
Gego = nx.ego_graph(G, node, 2)
nodePos = nx.layout.kamada_kawai_layout(Gego)

node_colors = {
   0: plt.cm.Reds, 1: plt.cm.Oranges, 2: plt.cm.RdPu, 
   3: plt.cm.Greens, 4: plt.cm.Greys, 5: plt.cm.Purples, 
}
node_shapes={0: '8', 1: 'o', 2: 'd', 3: '^', 4: 's', 5: '*'}



plt.figure(figsize=(15,15));
# plt.figure(figsize=(15,15));                 

for n in Gego.nodes:
    nx.draw_networkx_nodes(Gego, nodePos,
                           nodelist=[n],
                           node_color=[node_colors[dataset[0].y[n].item()](0.8)],
                           node_shape=node_shapes[dataset[0].y[n].item()],
                           node_size=1800 if n == node else 200,)
nx.draw_networkx_edges(Gego, nodePos,
#                            edgelist=[*[(node, n) for n in nodes], ],
                           edgelist= Gego.edges,
#                            width=[5 if e in edges else 2 for e in Gego.edges],
                           width=9,
#                            edge_color=[plt.cm.Greys(0.8) if e in edges else plt.cm.Greys(0.2) for e in Gego.edges],
                           edge_color=plt.cm.Greys(0.2))
plt.box(on=None)
plt.show()
# plt.savefig('./node_269_ego.svg', format='svg', dpi=450)
# plt.clf()

# for j in G.nodes:
#     a = None
#     for i in range(len(att1)):
#     #     plt.figure(figsize=(15,5), dpi=450)
# #         plt.figure(figsize=(15,5));

#         att = att1[i]
#         if a is None and len((att[j] > 0.001).nonzero().view(-1).tolist()) != 1:
#             a = len((att[j] > 0.0001).nonzero().view(-1).tolist())
#         else:
#             if a is not None and np.abs(a - len((att[j] > 0.001).nonzero().view(-1).tolist())) > 3 and len((att[j] > 0.001).nonzero().view(-1).tolist()) != 1:
#                 if nx.single_source_shortest_path_length(G, j) > 1:
#                     print(j)
#                     print(i, a, len((att[j] > 0.001).nonzero().view(-1).tolist()))

# %%
node=14
# # node=4|
# # node = model_not_gat_correct_nodes[1].item()
# Gego = nx.ego_graph(G, node, 3)
# nodePos = nx.layout.kamada_kawai_layout(Gego)
# node_colors = {
#    0: plt.cm.Reds, 1: plt.cm.Oranges, 2: plt.cm.RdPu, 
#    3: plt.cm.Greens, 4: plt.cm.Greys, 5: plt.cm.Purples, 
# }
# node_shapes={0: '8', 1: 'o', 2: 'd', 3: '^', 4: 's', 5: '*'}



# for n in Gego.nodes:
#     nx.draw_networkx_nodes(Gego, nodePos,
#                            nodelist=[n],
#                            node_color=[node_colors[dataset[0].y[n].item()](0.8)],
#                            node_shape="*" if n == node else node_shapes[dataset[0].y[n].item()],
#                            node_size=350 if n == node else 80)
# nx.draw_networkx_edges(Gego,nodePos, width=2, alpha=0.4)
for i in range(heads):
# for i in [0, 2, 4, 5]:
# for i in [3]:
    plt.figure(figsize=(10,10))
    plt.box(on=None)
    att = att1[i]
    nodes = (att[node] > 0.0).nonzero().view(-1).tolist()
    print(i, len(nodes))
#     plt.figure(figsize=(15,5), dpi=450);
#     ax = plt.subplot(1, 2, 1)
#     plot_filter_banks(idx=[i], ax=ax, no_ticks=True)

#     ax = plt.subplot(1, 2, 2)
    for n in Gego.nodes:
#     for n in nodes:
        nx.draw_networkx_nodes(Gego, nodePos,
                               nodelist=[n],
                               node_color=[node_colors[dataset[0].y[n].item()](0.7)],
                               node_shape=node_shapes[dataset[0].y[n].item()],
                               node_size=1200 if n == node else 600,
                               alpha=1 if n in nodes else 0.2
#                                node_size=300 if n == node else (torch.exp(att[node, n])*100).clamp(max=300, min=50),
#                                node_size=300 if n == node else 200
                              )
    edges = list(filter(lambda e: e[0] in nodes and e[1] in nodes, list(Gego.edges)))
    nx.draw_networkx_edges(Gego, nodePos,
#                            edgelist=[*[(node, n) for n in nodes], ],
                           edgelist= Gego.edges,
#                            width=[5 if e in edges else 2 for e in Gego.edges],
                           width=7,
#                            edge_color=[plt.cm.Greys(0.8) if e in edges else plt.cm.Greys(0.2) for e in Gego.edges],
                           edge_color=plt.cm.Greys(0.2),
                           alpha=0.3)
    nx.draw_networkx_edges(Gego, nodePos,
                           edgelist=[*[(n, node) for n in nodes], ],
#                            edgelist= Gego.edges,
#                            width=[5 if e in edges else 2 for e in Gego.edges],
                           width=4,
                           style="dashed",
#                            edge_color=[plt.cm.Greys(0.8) if e in edges else plt.cm.Greys(0.2) for e in Gego.edges],
#                            alpha=0.5,
                           edge_color=plt.cm.Greys(0.4),
                           arrows=True)
#     Gego = nx.DiGraph(Gego)
#     nx.draw_networkx_edges(Gego, nodePos,
#                            edgelist=[*[(n, node) for n in nodes], ],
# #                            edgelist= Gego.edges,
# #                            width=[5 if e in edges else 2 for e in Gego.edges],
#                            width=7,
# #                            edge_color=[plt.cm.Greys(0.8) if e in edges else plt.cm.Greys(0.2) for e in Gego.edges],
#                            alpha=0.6,
#                            arrowsize=36,
#                            arrowstyle='->',
#                            edge_color=plt.cm.Blues(0.8),
#                            connectionstyle='arc3,rad=0.1',
#                            arrows=True)
    plt.show()
    # plt.savefig('./node_269_ego_{}.svg'.format(str(i)), format='svg', dpi=450)
    # plt.clf()
# Out:
# 0 1
# 1 1
# 2 1
# 3 1

# %% [markdown]
# ### Frequency cutoff analysis

# %%
# Cut frequency bands abruptly
class CutOff(nn.Module):
    def __init__(self, kernel, min_val = 0, max_val = 2):
        super(CutOff, self).__init__()
        self.min = min_val
        self.max = max_val
        self.kernel = kernel

    def reset_parameters(self):
        pass

    def forward(self, x):
        h = torch.where(
            (x.view(-1,1).repeat(1, heads) >= self.min).logical_and(x.view(-1,1).repeat(1, heads) < self.max), 
            torch.zeros(x.shape[0], heads), self.kernel(x))
        return h

# %% [markdown]
# Evaluate low pass cutoff

# %%
threshold = 1
model.analysis.filter_kernel = CutOff(max_val=threshold, kernel=filter_kernel)
model.analysis.filter._kernel = CutOff(max_val=threshold, kernel=filter_kernel)
plot_filter_banks(kernel=model.analysis.filter_kernel)
print(evaluate(model, dataset[0], split=1))

low_pass_correct_indices = get_correctly_predicted_node_idx(model, 'test', dataset)
with torch.no_grad():
    _, low_att1, low_att2 = model(dataset[0])
# Out:
# {'train_loss': 0.11416419595479965, 'train_acc': 0.975, 'train_macro_f1': 0.9860447086186845, 'val_loss': 0.7225571870803833, 'val_acc': 0.8125, 'val_macro_f1': 0.6580617035546613, 'test_loss': 0.5869251489639282, 'test_acc': 0.8431372549019607, 'test_macro_f1': 0.625475599669148}

# %%
min_threshold = 0.75
max_threshold = 1.25
model.analysis.filter_kernel = CutOff(max_val=max_threshold, min_val=min_threshold, kernel=filter_kernel)
model.analysis.filter._kernel = CutOff(max_val=max_threshold, min_val=min_threshold, kernel=filter_kernel)
plot_filter_banks(kernel=model.analysis.filter_kernel)
print(evaluate(model, dataset[0], split=1))

mid_pass_correct_indices = get_correctly_predicted_node_idx(model, 'test', dataset)
with torch.no_grad():
    _, low_att1, low_att2 = model(dataset[0])
# Out:
# {'train_loss': 0.9238414764404297, 'train_acc': 0.8583333333333333, 'train_macro_f1': 0.6696140350877193, 'val_loss': 1.1685006618499756, 'val_acc': 0.6, 'val_macro_f1': 0.43183565843140315, 'test_loss': 1.0979878902435303, 'test_acc': 0.6274509803921569, 'test_macro_f1': 0.2823275862068965}

# %% [markdown]
# Evaluate high pass cutoff

# %%
threshold = 1
model.analysis.filter_kernel = CutOff(min_val=threshold, kernel=filter_kernel)
model.analysis.filter._kernel = CutOff(min_val=threshold, kernel=filter_kernel)
plot_filter_banks(kernel=model.analysis.filter_kernel)
print(evaluate(model, dataset[0], split=1))

high_pass_correct_indices = get_correctly_predicted_node_idx(model, 'test', dataset)

with torch.no_grad():
    _, high_att1, high_att2 = model(dataset[0])
# Out:
# {'train_loss': 0.7772282958030701, 'train_acc': 0.7333333333333333, 'train_macro_f1': 0.5855728011825573, 'val_loss': 1.3519736528396606, 'val_acc': 0.55, 'val_macro_f1': 0.3847031808770939, 'test_loss': 1.1135436296463013, 'test_acc': 0.6470588235294118, 'test_macro_f1': 0.27003367003367}

# %% [markdown]
# Evaluate band pass cutoff

# %%
step = 1
acc = []
model.analysis.filter_kernel = filter_kernel
model.analysis.filter._kernel = filter_kernel
# model.synthesis.filter_kernel = syn_filter_kernel
# model.synthesis.filter._kernel = syn_filter_kernel
for threshold in torch.arange(0, 2, step):
    print()
    model.analysis.filter_kernel = CutOff(min_val=threshold, max_val=threshold+step, kernel=filter_kernel)
    model.analysis.filter._kernel = CutOff(min_val=threshold, max_val=threshold+step, kernel=filter_kernel)
#     model.synthesis.filter_kernel = CutOff(min_val=0, max_val=2- threshold, kernel=syn_filter_kernel)
#     model.synthesis.filter._kernel = CutOff(min_val=0,max_val=2 - threshold, kernel=syn_filter_kernel)
    
    plot_filter_banks(kernel=model.analysis.filter_kernel)
#     plot_filter_banks(kernel=model.analysis.filter.cheby_eval)
    eval_info = evaluate(model, dataset[0], split=1)
    acc.append(eval_info['test_acc'])
print(acc)
# Out:
# [0.8431372549019607, 0.6470588235294118]

# %%
x = torch.arange(0, 1.76, 1)

x = ['{} - {}'.format(f.item(), f.item()+1) for f in x]

x_pos = [i for i, _ in enumerate(x)]

plt.figure(dpi=450)
plt.bar(x_pos, acc, color='green')
plt.ylabel("Micro-F1")

plt.xticks(x_pos, x)
plt.setp(plt.gca().get_xticklabels(), rotation=45, horizontalalignment='right')
plt.ylim(0.76, 0.81)


plt.show()

# %%
model.analysis.filter_kernel = CutOff(min_val=2, max_val=0, kernel=filter_kernel)
model.analysis.filter._kernel = CutOff(min_val=2, max_val=0, kernel=filter_kernel)

plot_filter_banks(kernel=model.analysis.filter_kernel)
plot_filter_banks(kernel=model.analysis.filter.cheby_eval)
print(evaluate(model, dataset[0]))
# Out:
# {'train_loss': 0.5665571689605713, 'train_acc': 0.8166392993979201, 'train_micro_f1_score': 0.8166392993979201, 'train_macro_f1_score': 0.795342253328798, 'val_loss': 0.7179193496704102, 'val_acc': 0.776, 'val_micro_f1_score': 0.776, 'val_macro_f1_score': 0.7176899025538349, 'test_loss': 0.7270241379737854, 'test_acc': 0.786, 'test_micro_f1_score': 0.786, 'test_macro_f1_score': 0.7469471011831037}

# %% [markdown]
# #### Frequency analysis on cutoff

# %%
low_not_high_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(low_pass_correct_indices.difference(high_pass_correct_indices))]
high_not_low_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(high_pass_correct_indices.difference(low_pass_correct_indices))]
high_and_low_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(high_pass_correct_indices.intersection(low_pass_correct_indices))]
low_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(low_pass_correct_indices)]
high_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(high_pass_correct_indices)]
mid_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(mid_pass_correct_indices)]


print('Number of node classified correctly by low-pass filters:', len(low_correct_nodes))
print('Number of node classified correctly by high-pass filters:', len(high_correct_nodes))
print('Number of node classified correctly by mid-pass filters:', len(mid_correct_nodes))
print('Number of node classified correctly by low-pass filters but not by high-pass filters:', len(low_not_high_correct_nodes))
print('Number of node classified correctly by high-pass filters but not by low-pass filters:', len(high_not_low_correct_nodes))
print('Number of node classified correctly by both high-pass and low-pass filters:', len(high_and_low_correct_nodes))
# Out:
# Number of node classified correctly by low-pass filters: 801
# Number of node classified correctly by high-pass filters: 795
# Number of node classified correctly by mid-pass filters: 809
# Number of node classified correctly by low-pass filters but not by high-pass filters: 24
# Number of node classified correctly by high-pass filters but not by low-pass filters: 18
# Number of node classified correctly by both high-pass and low-pass filters: 777

# %% [markdown]
# Neighbour distribution of nodes classified correct by high-pass

# %%
matching_labels_distribution(high_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.9054)
# matching labels in 2st hop: tensor(0.8545)
# matching labels in 3rd hop: tensor(0.8085)

# %% [markdown]
# Neighbour distribution of nodes classified correct by low-pass

# %%
matching_labels_distribution(low_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.9054)
# matching labels in 2st hop: tensor(0.8535)
# matching labels in 3rd hop: tensor(0.8078)

# %% [markdown]
# Neighbour distribution of nodes classified correct by high-pass but not low pass

# %%
matching_labels_distribution(high_not_low_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.5389)
# matching labels in 2st hop: tensor(0.3711)
# matching labels in 3rd hop: tensor(0.2989)

# %%
matching_labels_distribution(low_not_high_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.6325)
# matching labels in 2st hop: tensor(0.4588)
# matching labels in 3rd hop: tensor(0.4045)

# %%
matching_labels_distribution(high_and_low_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.9200)
# matching labels in 2st hop: tensor(0.8792)
# matching labels in 3rd hop: tensor(0.8354)

# %% [markdown]
# Accuracy on less-similar neighbourhoods

# %%
from matplotlib import pyplot as plt
label_distributions = matching_labels_distribution(dataset[0]['test_mask'].nonzero().view(-1));
# Out:
# matching labels in 1st hop: tensor(0.8295)
# matching labels in 2st hop: tensor(0.7612)
# matching labels in 3rd hop: tensor(0.7151)

# %% [markdown]
# Draw attentions from high-pass filterbank(s)

# %%
low_attentions = torch.stack(low_att1, 0).sum(0)
high_attentions = torch.stack(high_att1, 0).sum(0)

index = 5
node = high_not_low_correct_nodes[index].item()
# node = low_not_high_correct_nodes[2].item()

Gego = nx.ego_graph(G, node, 2)
nodePos = nx.layout.spring_layout(Gego)

plt.figure(figsize=(15,5))
ax1 = plt.subplot(1, 2, 1)
ax1.set_title('high pass attentions')

for n in Gego.nodes:
    nx.draw_networkx_nodes(Gego, nodePos,
                           ax=ax1,
                           nodelist=[n],
                           node_color=[node_colors[dataset[0].y[n].item()](0.5)],
                           node_shape="*" if n == node else "o",
                           node_size=300 if n == node else (high_attentions[node, n]*400).clamp(max=400, min=20))
nx.draw_networkx_edges(Gego,nodePos, linewidths=0.5, ax=ax1)

ax2 = plt.subplot(1, 2, 2)
ax2.set_title('low pass attentions')

for n in Gego.nodes:
    nx.draw_networkx_nodes(Gego, nodePos,
                           ax=ax2,
                           nodelist=[n],
                           node_color=[node_colors[dataset[0].y[n].item()](0.5)],
                           node_shape="*" if n == node else "o",
                           node_size=300 if n == node else (low_attentions[node, n]*400).clamp(max=400, min=20))
nx.draw_networkx_edges(Gego,nodePos, linewidths=0.5, ax=ax2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-4bc6cadf3f25> in <module>
#       3
#       4 index = 5
# ----> 5 node = high_not_low_correct_nodes[index].item()
#       6 # node = low_not_high_correct_nodes[2].item()
#       7
#
# NameError: name 'high_not_low_correct_nodes' is not defined

# %%
# low_attentions = torch.stack(low_att1, 0).sum(0)
# high_attentions = torch.stack(high_att1, 0).sum(0)

index = 6
node = high_not_low_correct_nodes[index].item()
# node = low_not_high_correct_nodes[index].item()

Gego = nx.ego_graph(G, node, 2)
nodePos = nx.layout.spring_layout(Gego)

plt.figure(figsize=(15,30))

for i in range(heads):
    ax = plt.subplot(9, 2, i+1)
    ax.set_title(str(i+1) + 'th head attentions')

#     print([att1[i][node, n].item() for n in Gego.nodes])
    for n in Gego.nodes:
        nx.draw_networkx_nodes(Gego, nodePos,
                               ax=ax,
                               nodelist=[n],
                               node_color=[node_colors[dataset[0].y[n].item()](0.5)],
                               node_shape="*" if n == node else "o",
                               node_size=300 if n == node else (att1[i][node, n]*1000).clamp(max=400, min=5))
    nx.draw_networkx_edges(Gego,nodePos, linewidths=0.5, ax=ax)
plt.show()

# %% [markdown]
# Attended node centrality distribution by frequency bands

# %%
# compute all node's centrality
centrality_between = nx.betweenness_centrality(G)
centrality_degree = nx.degree_centrality(G)
centrality_close = nx.closeness_centrality(G)
centrality_eigen = nx.eigenvector_centrality(G)

# %%
min_att = 1
plt.figure(figsize=(15,15))

print('Degree centrality')
ax1 = plt.subplot(4, 2, 1)
ax1.set_title('high-pass degree centrality')
centralities = torch.tensor([centrality_degree[n] for n in (high_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)

ax2 = plt.subplot(4, 2, 2)
ax2.set_title('low-pass degree centrality')
centralities = torch.tensor([centrality_degree[n] for n in (low_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('low-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)

print('\nBetweeness centrality')
ax3 = plt.subplot(4, 2, 3)
ax3.set_title('high-pass betweeness centrality')
centralities = torch.tensor([centrality_between[n] for n in (high_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)

ax4 = plt.subplot(4, 2, 4)
ax4.set_title('low-pass betweeness centrality')
centralities = torch.tensor([centrality_between[n] for n in (low_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('low-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)

print('\nCloseness centrality')
ax5 = plt.subplot(4, 2, 5)
ax5.set_title('high-pass closeness centrality')
centralities = torch.tensor([centrality_close[n] for n in (high_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)

ax6 = plt.subplot(4, 2, 6)
ax6.set_title('low-pass closeness centrality')
centralities = torch.tensor([centrality_close[n] for n in (low_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('low-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)

print('\nEigen centrality')
ax7 = plt.subplot(4, 2, 7)
ax7.set_title('high-pass eigen centrality')
centralities = torch.tensor([centrality_eigen[n] for n in (high_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)


ax8 = plt.subplot(4, 2, 8)
ax8.set_title('low-pass eigen centrality')
centralities = torch.tensor([centrality_eigen[n] for n in (low_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('low-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# Degree centrality
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-e0b58fbf1400> in <module>
#       5 ax1 = plt.subplot(4, 2, 1)
#       6 ax1.set_title('high-pass degree centrality')
# ----> 7 centralities = torch.tensor([centrality_degree[n] for n in (high_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
#       8 print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
#       9 plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)
#
# NameError: name 'high_attentions' is not defined

# %% [markdown]
# Attended node page rank distribution by frequency bands

# %%
# compute all node's page rank
pr = nx.pagerank(G, alpha=0.9)

min_att = 1
plt.figure(figsize=(15,3))

print('Page Rank')
ax1 = plt.subplot(1, 2, 1)
ax1.set_title('high-pass degree centrality')
prs = torch.tensor([pr[n] for n in (high_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass  page rank mean: {}, std: {}'.format(prs.mean().item(), prs.std().item()))
plt.hist(prs, color = 'blue', edgecolor = 'black', bins = 20)

ax2 = plt.subplot(1, 2, 2)
ax2.set_title('low-pass degree centrality')
prs = torch.tensor([pr[n] for n in (low_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('low-pass page rank mean: {}, std: {}'.format(prs.mean().item(), prs.std().item()))
plt.hist(prs, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# Page Rank
# high-pass  page rank mean: 0.0003032942219767618, std: 0.0002581054545828176
# low-pass page rank mean: 0.0003389950388768384, std: 0.0002890852496913017

# %% [markdown]
# Distance distribution of attended node

# %%
# Compute distances to from a node to its attended nodes
min_att = 0

high_distances = []

masked_high_attenions = high_attentions > min_att
for n1 in G.nodes:
    for n2 in G.nodes:
        if masked_high_attenions[n1, n2]:
            high_distances.append(nx.shortest_path_length(G, n1, n2))

low_distances = []

masked_low_attenions = low_attentions > min_att
for n1 in G.nodes:
    for n2 in G.nodes:
        if masked_low_attenions[n1, n2]:
            low_distances.append(nx.shortest_path_length(G, n1, n2))

            
plt.figure(figsize=(15,3))

print('Attended node distance')
ax1 = plt.subplot(1, 2, 1)
ax1.set_title('high-pass node distance')
distances = torch.tensor(high_distances).float()
print('high-pass node distance mean: {}, std: {}'.format(distances.mean().item(), distances.std().item()))
plt.hist(distances, color = 'blue', edgecolor = 'black', bins = 20)

ax2 = plt.subplot(1, 2, 2)
ax2.set_title('low-pass node distance')
distances = torch.tensor(low_distances).float()
print('low-pass node distance mean: {}, std: {}'.format(distances.mean().item(), distances.std().item()))
plt.hist(distances, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-86dcb19e96ff> in <module>
#       4 high_distances = []
#       5
# ----> 6 masked_high_attenions = high_attentions > min_att
#       7 for n1 in G.nodes:
#       8     for n2 in G.nodes:
#
# NameError: name 'high_attentions' is not defined

# %% [markdown]
# Re-train model with cutoff

# %%
# Similar result as cutoff after training
from webkb import run, get_dataset

use_dataset = lambda : dataset

# model_cutoff = SingleNet(dataset)

# max_cutoff=1
# cutoff_kernel = model_cutoff.analysis.filter_kernel
# model_cutoff.analysis.filter_kernel = CutOff(max_val=max_cutoff, kernel=cutoff_kernel)
# model_cutoff.analysis.filter._kernel = CutOff(max_val=max_cutoff, kernel=cutoff_kernel)

# plot_filter_banks(kernel=model_cutoff.analysis.filter_kernel)
# print(evaluate(model_cutoff, dataset[0], split=1))

run(use_dataset, SingleNet, runs, epochs, lr, weight_decay, patience, None)

plot_filter_banks(kernel=model_cutoff.analysis.filter_kernel)
print(evaluate(model_cutoff, dataset[0], split=1))
# Out:
# Val Loss: 0.7279 ± 0.134, Train Accuracy: 0.994 ± 0.006, Val Accuracy: 0.756 ± 0.066, Test Accuracy: 0.738 ± 0.057, Macro-F1: 0.495 ± 0.115, Duration: 40.077, Epoch: 400
# {'train_loss': 1.6094365119934082, 'train_acc': 0.20689655172413793, 'train_macro_f1': 0.08571428571428572, 'val_loss': 1.6094366312026978, 'val_acc': 0.10169491525423731, 'val_macro_f1': 0.046153846153846156, 'test_loss': 1.609437108039856, 'test_acc': 0.16216216216216217, 'test_macro_f1': 0.05581395348837209}

# %% [markdown]
# ## Evaluate filterbanks
#
# Define kernel to eliminate certain filterbanks

# %%
class Elimination(nn.Module):
    def __init__(self, zero_out_indices):
        super(Elimination, self).__init__()
        self.zero_out_indices = zero_out_indices

    def reset_parameters(self):
        pass

    def forward(self, x):
        x = filter_kernel(x)
        x[:, self.zero_out_indices] = torch.zeros(x.shape[0], len(self.zero_out_indices))
        return x

# %% [markdown]
# Evaluate each filter bank

# %%
all_indices = set(list(range(heads)))
diff= []
for i in range(heads):
    zero_out_filters = list(all_indices.difference({i}))
    model.analysis.filter_kernel = Elimination(zero_out_filters)
    model.analysis.filter._kernel = Elimination(zero_out_filters)
    # plot_filter_banks(kernel=model.analysis.filter_kernel)
    test_acc = evaluate(model, dataset[0])['test_acc']
    diff.append(test_acc - eval_info['test_acc'])
print(' & '.join(['{:.2f}\%'.format(d*100) for d in diff]))
# Out:
# -1.80\% & -2.00\% & -1.70\% & -1.70\% & -1.80\% & -1.80\% & -1.70\% & -1.90\% & -1.70\% & -1.90\% & -1.70\% & -1.70\% & -1.90\% & -1.90\%

# %% [markdown]
# Evaluate by eliminating only one filter bank

# %%
diff= []
for i in range(heads):
    model.analysis.filter_kernel = Elimination([i])
    model.analysis.filter._kernel = Elimination([i])
    # plot_filter_banks(kernel=model.analysis.filter_kernel)
    test_acc = evaluate(model, dataset[0])['test_acc']
    diff.append(test_acc - eval_info['test_acc'])
print(' & '.join(['{:.2f}\%'.format(d*100) for d in diff]))
# Out:
# <>:8: DeprecationWarning: invalid escape sequence \%
# -0.20\% & -0.30\% & -0.70\% & -0.70\% & -0.40\% & -0.60\% & -0.80\% & 0.00\% & -0.60\% & 0.00\% & -0.80\% & -0.50\% & 0.00\% & 0.00\%

# %% [markdown]
# Load GAT model

# %%
from torch_geometric.nn import GATConv
class GAT(torch.nn.Module):
    def __init__(self, dataset):
        super(GAT, self).__init__()
        self.conv1 = GATConv(
            dataset.num_features,
            8,
            heads=8,
            dropout=0.6)
        self.conv2 = GATConv(
            64,
            dataset.num_classes,
            heads=1,
            concat=False,
            dropout=0.6)

    def reset_parameters(self):
        self.conv1.reset_parameters()
        self.conv2.reset_parameters()

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.dropout(x, p=0.6, training=self.training)
        x, (edge_index_1, att_val_1) = self.conv1(x, edge_index, return_attention_weights=True)
        x = F.elu(x)
        x = F.dropout(x, p=0.6, training=self.training)
        x, (edge_index_2, att_val_2) = self.conv2(x, edge_index, return_attention_weights=True)
        att1 = torch.zeros(data.num_nodes, data.num_nodes, 8)
        att2 = torch.zeros(data.num_nodes, data.num_nodes)
        att1[list(map(lambda x: torch.tensor(x), edge_index_1.tolist()))] = att_val_1
        att2[list(map(lambda x: torch.tensor(x), edge_index_2.tolist()))] = att_val_2.view(-1)
        return F.log_softmax(x, dim=1), att1, att2

gat = GAT(dataset)


gat.load_state_dict(torch.load('./model/best_{}_gat.pkl'.format(dataset_name)))
gat_correct_indices = get_correctly_predicted_node_idx(gat, 'test', dataset)

with torch.no_grad():
    _, gat_att1, gat_att2 = gat(dataset[0])
evaluate(gat, dataset[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-01cfef118afc> in <module>
#      36
#      37
# ---> 38 gat.load_state_dict(torch.load('./model/best_{}_gat.pkl'.format(dataset_name)))
#      39 gat_correct_indices = get_correctly_predicted_node_idx(gat, 'test', dataset)
#      40
#
# ~/work/git/decimation_branch_mark/venv/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     582         pickle_load_args['encoding'] = 'utf-8'
#     583
# --> 584     with _open_file_like(f, 'rb') as opened_file:
#     585         if _is_zipfile(opened_file):
#     586             with _open_zipfile_reader(f) as opened_zipfile:
#
# ~/work/git/decimation_branch_mark/venv/lib/python3.6/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     232 def _open_file_like(name_or_buffer, mode):
#     233     if _is_path(name_or_buffer):
# --> 234         return _open_file(name_or_buffer, mode)
#     235     else:
#     236         if 'w' in mode:
#
# ~/work/git/decimation_branch_mark/venv/lib/python3.6/site-packages/torch/serialization.py in __init__(self, name, mode)
#     213 class _open_file(_opener):
#     214     def __init__(self, name, mode):
# --> 215         super(_open_file, self).__init__(open(name, mode))
#     216
#     217     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: './model/best_CiteSeer_gat.pkl'

# %%
from torch_geometric.nn import GCNConv
class GCN(torch.nn.Module):
    def __init__(self, dataset):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(dataset.num_features, 64)
        self.conv2 = GCNConv(64, dataset.num_classes)

    def reset_parameters(self):
        self.conv1.reset_parameters()
        self.conv2.reset_parameters()

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1), None
    
gcn = GCN(dataset)
gcn.load_state_dict(torch.load('./model/best_Citeseer_gcn.pkl'.format(dataset_name)))
gcn_correct_indices = get_correctly_predicted_node_idx(gcn, 'test', dataset)

evaluate(gcn, dataset[0])
# Out:
# {'train_loss': 0.6749608516693115,
#  'train_acc': 0.8166392993979201,
#  'train_micro_f1': 0.8166392993979201,
#  'train_macro_f1': 0.774800487449197,
#  'val_loss': 0.7802919745445251,
#  'val_acc': 0.82,
#  'val_micro_f1': 0.82,
#  'val_macro_f1': 0.7548710129806285,
#  'test_loss': 0.7651001214981079,
#  'test_acc': 0.788,
#  'test_micro_f1': 0.788,
#  'test_macro_f1': 0.7265195784607675}

# %%
from torch_geometric.nn import SGConv

class SGC(torch.nn.Module):
    def __init__(self, dataset):
        super(SGC, self).__init__()
        self.conv1 = SGConv(
            dataset.num_features, dataset.num_classes, K=2, cached=True)

    def reset_parameters(self):
        self.conv1.reset_parameters()

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        return F.log_softmax(x, dim=1), None

dataset_unnormalized = get_dataset(dataset_name, False, edge_dropout=edge_dropout,
                                node_feature_dropout=node_feature_dropout)
sgc = SGC(dataset_unnormalized)
sgc.load_state_dict(torch.load('./model/best_Citeseer_sgc.pkl'.format(dataset_name)))
sgc_correct_indices = get_correctly_predicted_node_idx(sgc, 'test', dataset_unnormalized)

evaluate(sgc, dataset_unnormalized[0])
# Out:
# {'train_loss': 0.6347513198852539,
#  'train_acc': 0.7991242474001095,
#  'train_micro_f1': 0.7991242474001096,
#  'train_macro_f1': 0.7217705986934555,
#  'val_loss': 0.8052297830581665,
#  'val_acc': 0.786,
#  'val_micro_f1': 0.786,
#  'val_macro_f1': 0.708295666957094,
#  'test_loss': 0.8246657252311707,
#  'test_acc': 0.76,
#  'test_micro_f1': 0.76,
#  'test_macro_f1': 0.6788085029293738}

# %%
from torch_geometric.nn import ChebConv


class Cheb(torch.nn.Module):
    def __init__(self, dataset):
        super(Cheb, self).__init__()
        self.conv1 = ChebConv(dataset.num_features, 16, 2)
        self.conv2 = ChebConv(16, dataset.num_classes, 2)

    def reset_parameters(self):
        self.conv1.reset_parameters()
        self.conv2.reset_parameters()

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1), None
    
cheb = Cheb(dataset)
cheb.load_state_dict(torch.load('./model/best_Citeseer_cheb.pkl'.format(dataset_name)))
cheb_correct_indices = get_correctly_predicted_node_idx(cheb, 'test', dataset)

evaluate(cheb, dataset[0])
# Out:
# {'train_loss': 0.5563210248947144,
#  'train_acc': 0.8571428571428571,
#  'train_micro_f1': 0.8571428571428571,
#  'train_macro_f1': 0.8231449202874553,
#  'val_loss': 0.7509323358535767,
#  'val_acc': 0.81,
#  'val_micro_f1': 0.81,
#  'val_macro_f1': 0.749923239713278,
#  'test_loss': 0.7448410391807556,
#  'test_acc': 0.795,
#  'test_micro_f1': 0.795,
#  'test_macro_f1': 0.7489021889562496}

# %%
from torch_geometric.nn import APPNP
from torch.nn import Linear

class Appnp(torch.nn.Module):
    def __init__(self, dataset):
        super(Appnp, self).__init__()
        self.lin1 = Linear(dataset.num_features, 64)
        self.lin2 = Linear(64, dataset.num_classes)
        self.prop1 = APPNP(10, 0.1)

    def reset_parameters(self):
        self.lin1.reset_parameters()
        self.lin2.reset_parameters()

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(self.lin1(x))
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        x = self.prop1(x, edge_index)
        return F.log_softmax(x, dim=1), None
    
appnp = Appnp(dataset)
appnp.load_state_dict(torch.load('./model/best_Citeseer_appnp.pkl'.format(dataset_name)))
appnp_correct_indices = get_correctly_predicted_node_idx(appnp, 'test', dataset)

evaluate(appnp, dataset[0])
# Out:
# {'train_loss': 0.6745723485946655,
#  'train_acc': 0.8084291187739464,
#  'train_micro_f1': 0.8084291187739464,
#  'train_macro_f1': 0.7642930514952312,
#  'val_loss': 0.7715176939964294,
#  'val_acc': 0.806,
#  'val_micro_f1': 0.806,
#  'val_macro_f1': 0.7440469383028852,
#  'test_loss': 0.758247971534729,
#  'test_acc': 0.78,
#  'test_micro_f1': 0.78,
#  'test_macro_f1': 0.7115224574368039}

# %%
from torch_geometric.nn import ARMAConv

class ARMA(torch.nn.Module):
    def __init__(self, dataset):
        super(ARMA, self).__init__()
        self.conv1 = ARMAConv(
            dataset.num_features,
            16,
            1,
            1,
            False,
            dropout=0.75)
        self.conv2 = ARMAConv(
            16,
            dataset.num_classes,
            1,
            1,
            False,
            dropout=0.75)

    def reset_parameters(self):
        self.conv1.reset_parameters()
        self.conv2.reset_parameters()

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1), None
    
arma = ARMA(dataset)
arma.load_state_dict(torch.load('./model/best_Citeseer_arma.pkl'.format(dataset_name)))
arma_correct_indices = get_correctly_predicted_node_idx(arma, 'test', dataset)

evaluate(arma, dataset[0])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-239f566ac562> in <module>
#      31
#      32 arma = ARMA(dataset)
# ---> 33 arma.load_state_dict(torch.load('./model/best_Citeseer_arma.pkl'.format(dataset_name)))
#      34 arma_correct_indices = get_correctly_predicted_node_idx(arma, 'test', dataset)
#      35
#
# ~/work/git/decimation_branch_mark/venv/lib/python3.6/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#     845         if len(error_msgs) > 0:
#     846             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# --> 847                                self.__class__.__name__, "\n\t".join(error_msgs)))
#     848         return _IncompatibleKeys(missing_keys, unexpected_keys)
#     849
#
# RuntimeError: Error(s) in loading state_dict for ARMA:
# 	Missing key(s) in state_dict: "conv1.init_weight", "conv1.weight", "conv1.root_weight", "conv1.bias", "conv2.init_weight", "conv2.weight", "conv2.root_weight", "conv2.bias".
# 	Unexpected key(s) in state_dict: "conv1.ws.0", "conv1.vs.0", "conv2.ws.0", "conv2.vs.0".

# %%
from torch_geometric.nn import ARMAConv

class MLP(torch.nn.Module):
    def __init__(self, dataset):
        super(MLP, self).__init__()
        self.layers = nn.Sequential(nn.Linear(dataset[0].num_node_features, 64),
                                nn.Dropout(0.8),
                                nn.Linear(64, dataset.num_classes),
                                nn.ReLU(inplace=True),
                                nn.LogSoftmax(dim=1))

    def reset_parameters(self):
        for layer in self.layers:
            if hasattr(layer, 'reset_parameters'):
                layer.reset_parameters()

    def forward(self, data):
        x = data.x
        return self.layers(x), None, None

mlp = MLP(dataset)
mlp.load_state_dict(torch.load('./model/best_{}_mlp.pkl'.format(dataset_name)))
mlp_correct_indices = get_correctly_predicted_node_idx(mlp, 'test', dataset)

evaluate(mlp, dataset[0])
# Out:
# {'train_loss': 0.42962929606437683,
#  'train_acc': 0.9102353585112206,
#  'train_micro_f1': 0.9102353585112206,
#  'train_macro_f1': 0.8653994580165002,
#  'val_loss': 0.8128601908683777,
#  'val_acc': 0.752,
#  'val_micro_f1': 0.752,
#  'val_macro_f1': 0.6854480329526466,
#  'test_loss': 0.8103276491165161,
#  'test_acc': 0.756,
#  'test_micro_f1': 0.756,
#  'test_macro_f1': 0.6821793249114262}

# %%
from random import choice
from collections import Counter
from scipy.sparse import coo_matrix
import networkx as nx


def multimode(eles, num_classes):
    res = []
    if(len(eles) == 0):
        eles = list(range(num_classes))
    counter = Counter(eles)
    temp = counter.most_common(1)[0][1]
    for ele in eles:
      if eles.count(ele) == temp:
        res.append(ele)
    return list(set(res))

class MajorityVote(torch.nn.Module):
    def __init__(self, dataset):
        super(MajorityVote, self).__init__()
        self.num_classes = dataset.num_classes
        adj = coo_matrix(
            (np.ones(dataset[0].num_edges),
             (dataset[0].edge_index[0].numpy(), dataset[0].edge_index[1].numpy())),
            shape=(dataset[0].num_nodes, dataset[0].num_nodes))
        self.G = nx.Graph(adj)
        
    def forward(self, data):
        train_nodes = set(data.train_mask.nonzero().view(-1).tolist())

        logits = []
        for n in range(data.num_nodes):
            hop_1_neighbours = set(nx.ego_graph(self.G, n, 1).nodes())
            hop_1_labels = data.y[list(hop_1_neighbours)]
            label = choice(multimode(hop_1_labels.tolist(), self.num_classes))
            logits.append(F.one_hot(torch.tensor(label), self.num_classes).float())
        return torch.stack(logits, 0), None
    
majority_vote = MajorityVote(dataset)
# arma_correct_indices = get_correctly_predicted_node_idx(arma, 'test', dataset)

evaluate(majority_vote, dataset[0])
# Out:
# {'train_loss': -0.8500273823738098,
#  'train_acc': 0.8500273672687466,
#  'train_micro_f1': 0.8500273672687466,
#  'train_macro_f1': 0.8327738911556355,
#  'val_loss': -0.8679999709129333,
#  'val_acc': 0.868,
#  'val_micro_f1': 0.868,
#  'val_macro_f1': 0.842520557996031,
#  'test_loss': -0.8759999871253967,
#  'test_acc': 0.876,
#  'test_micro_f1': 0.8759999999999999,
#  'test_macro_f1': 0.857494909102209}

# %%
np.sum([torch.prod(torch.tensor(p.shape)) for p in list(gat.parameters())])
# Out:
# 237586

# %%
np.sum([torch.prod(torch.tensor(p.shape)) for p in list(model.parameters())])
# Out:
# 325983

# %%
def cal_acc_in_noisy_neighbourhood(m, dataset):
    m.eval()
    accs = []
    with torch.no_grad():
        logits  = m(dataset[0])[0]
    for p in torch.arange(0.2, 1.1, 0.1):
        dissimilar_neighbhour_nodes_mask = dataset[0]['test_mask'].clone()
        dissimilar_neighbhour_nodes_mask[dissimilar_neighbhour_nodes_mask] = torch.tensor(label_distributions[0]) <= p
        mask = dissimilar_neighbhour_nodes_mask
        pred = logits[mask].max(1)[1]
        accs.append(pred.eq(dataset[0].y[mask]).sum().item() / mask.sum().item())
    return accs

# Try to get some standard deviations

# %%
model_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(model, dataset))
# gat_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(gat, dataset))
gcn_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(gcn, dataset))
sgc_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(sgc, dataset_unnormalized))
cheb_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(cheb, dataset))
appnp_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(appnp, dataset))
# arma_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(arma, dataset))
majority_vote_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(majority_vote, dataset))
mlp_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(mlp, dataset))

# %%
plt.figure(dpi=450)
x = [str(p)+'%' for p in range(20, 110, 10)]
plt.plot(x,
         gcn_noisy_accs,
         linestyle=':',
         zorder=2)
# plt.plot(x,
#          gat_noisy_accs,
#          linestyle='--',
#          zorder=2)
plt.plot(x,
         sgc_noisy_accs,
         linestyle='--',
         zorder=2)
plt.plot(x,
         cheb_noisy_accs,
         linestyle=':',
         zorder=2)
plt.plot(x,
         appnp_noisy_accs,
         linestyle='--',
         zorder=2)
# plt.plot(x,
#          arma_noisy_accs,
#          linestyle=':',
#          zorder=2)
plt.plot(x,
         majority_vote_noisy_accs,
         linestyle='-',
#          linewidth=0.5,
         alpha=0.3,
         zorder=2)
plt.plot(x,
         mlp_noisy_accs,
         linewidth=1.5,
         linestyle='--',
         zorder=2)
plt.plot(x,
         model_noisy_accs,
         linewidth=1.5,
         linestyle='-',
         zorder=2)

s1 = plt.scatter(x, gcn_noisy_accs, zorder=1, marker='*')
# s2 = plt.scatter(x, gat_noisy_accs, zorder=1, marker="o")
s3 = plt.scatter(x, sgc_noisy_accs, zorder=1, marker='s')
s4 = plt.scatter(x, cheb_noisy_accs, zorder=1, marker='d')
s5 = plt.scatter(x, appnp_noisy_accs, zorder=1, marker='X')
# s6 = plt.scatter(x, arma_noisy_accs, zorder=1, marker='v')
s7 = plt.scatter(x, majority_vote_noisy_accs, zorder=1, marker='*', alpha=0.3)
s8 = plt.scatter(x, mlp_noisy_accs, zorder=1, marker='v')
s9 = plt.scatter(x, model_noisy_accs, zorder=1, marker='^')
# plt.legend((s1, s2, s3, s4, s5, s6, s7, s8), ('GCN', 'GAT', 'SGC', 'Cheby', 'APPNP', 'ARMA', 'Majority vote', 'Model'))
plt.legend((s1, s3, s4, s5, s7, s8, s9), ('GCN', 'SGC', 'Cheby', 'APPNP','Majority vote', 'MLP', 'Model'))

# %%
plt.figure(dpi=450)
x = [str(p)+'%' for p in range(20, 110, 10)]
plt.plot(x,
         gcn_noisy_accs,
         linestyle=':',
         zorder=2)
plt.plot(x,
         gat_noisy_accs,
         linestyle='--',
         zorder=2)
plt.plot(x,
         sgc_noisy_accs,
         linestyle='--',
         zorder=2)
plt.plot(x,
         cheb_noisy_accs,
         linestyle=':',
         zorder=2)
plt.plot(x,
         appnp_noisy_accs,
         linestyle='--',
         zorder=2)
plt.plot(x,
         arma_noisy_accs,
         linestyle=':',
         zorder=2)
plt.plot(x,
         model_noisy_accs,
         linewidth=1.5,
         linestyle='-',
         zorder=2)

s1 = plt.scatter(x, gcn_noisy_accs, zorder=1, marker='*')
s2 = plt.scatter(x, gat_noisy_accs, zorder=1, marker="o")
s3 = plt.scatter(x, sgc_noisy_accs, zorder=1, marker='s')
s4 = plt.scatter(x, cheb_noisy_accs, zorder=1, marker='d')
s5 = plt.scatter(x, appnp_noisy_accs, zorder=1, marker='X')
s6 = plt.scatter(x, arma_noisy_accs, zorder=1, marker='v')
s7 = plt.scatter(x, model_noisy_accs, zorder=1, marker='^')
plt.legend((s1, s2, s3, s4, s5, s6, s7), ('GCN', 'GAT', 'SGC', 'Cheby', 'APPNP', 'ARMA', 'Model'))

# %%
(model_noisy_accs - cheb_noisy_accs).mean()
# Out:
# tensor(0.0815)

# %% [markdown]
# Comparison with GAT

# %%
model_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(model_correct_indices)]
gat_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(gat_correct_indices)]
model_not_gat_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(model_correct_indices.difference(gat_correct_indices))]
model_and_gat_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(model_correct_indices.intersection(gat_correct_indices))]
gat_not_model_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(gat_correct_indices.difference(model_correct_indices))]
gat_and_model_incorrect_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(set(dataset[0].y[dataset[0]['test_mask']].nonzero().view(-1).tolist()).difference(model_correct_indices).difference(gat_correct_indices))]
print('Number of node classified correctly by our model:', len(model_correct_nodes))
print('Number of node classified correctly by GAT:', len(gat_correct_nodes))
print('Number of node classified correctly by our model but not by GAT:', len(model_not_gat_correct_nodes))
print('Number of node classified correctly by both GAT and our model:', len(model_and_gat_correct_nodes))
print('Number of node classified correctly by GAT but not by our model:', len(gat_not_model_correct_nodes))
print('Number of node classified incorrectly by GAT and our model:', len(gat_and_model_incorrect_nodes))
# Out:
# Number of node classified correctly by our model: 805
# Number of node classified correctly by GAT: 778
# Number of node classified correctly by our model but not by GAT: 59
# Number of node classified correctly by both GAT and our model: 746
# Number of node classified correctly by GAT but not by our model: 32
# Number of node classified incorrectly by GAT and our model: 118

# %%
gat_att1_sum = gat_att1.sum(dim=2)

# %%
node = model_not_gat_correct_nodes[1].item()
Gego = nx.ego_graph(G, node, 2)
nodePos = nx.layout.spring_layout(Gego)
plt.figure()
for n in Gego.nodes:
    nx.draw_networkx_nodes(Gego, nodePos,
                           nodelist=[n],
                           node_color=[node_colors[dataset[0].y[n].item()](0.8)],
                           node_shape="*" if n == node else "o",
                           node_size=300 if n == node else (model_att1_sum[node, n]*200).clamp(max=400, min=5))
nx.draw_networkx_edges(Gego,nodePos, linewidths=0.5)


plt.figure()
for n in Gego.nodes:
    nx.draw_networkx_nodes(Gego, nodePos,
                           nodelist=[n],
                           node_color=[node_colors[dataset[0].y[n].item()](0.8)],
                           node_shape="*" if n == node else "o",
                           node_size=300 if n == node else (gat_att1_sum[node, n]*200).clamp(max=400, min=5))
nx.draw_networkx_edges(Gego,nodePos, linewidths=0.5)

# %% [markdown]
# Label distribution of nodes classified correctly by our model

# %%
print('\nBetweeness centrality')
ax3 = plt.subplot(1, 1, 1)
# ax3.set_title('high-pass betweeness centrality')
centralities = torch.tensor([centrality_between[n] for n in (gat_att1_sum).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# Betweeness centrality
# high-pass centrality mean: 0.0031025800853967667, std: 0.008951541967689991

# %%
print('\nBetweeness centrality')
ax3 = plt.subplot(1, 1, 1)
# ax3.set_title('high-pass betweeness centrality')
centralities = torch.tensor([centrality_between[n] for n in (model_att1_sum).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# Betweeness centrality
# high-pass centrality mean: 0.003282387275248766, std: 0.008437315002083778

# %%
matching_labels_distribution(model_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.8937)
# matching labels in 2st hop: tensor(0.8390)
# matching labels in 3rd hop: tensor(0.7911)

# %%
min_att = 0.2

# %% [markdown]
# Label distribution of nodes classified correctly by our model

# %%
print('\nBetweeness centrality')
ax3 = plt.subplot(1, 1, 1)
# ax3.set_title('high-pass betweeness centrality')
centralities = torch.tensor([centrality_between[n] for n in (gat_att1_sum > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# Betweeness centrality
# high-pass centrality mean: 0.0024233979638665915, std: 0.0065828170627355576

# %%
print('\nBetweeness centrality')
ax3 = plt.subplot(1, 1, 1)
# ax3.set_title('high-pass betweeness centrality')
centralities = torch.tensor([centrality_between[n] for n in (model_att1_sum > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# Betweeness centrality
# high-pass centrality mean: 0.002925171982496977, std: 0.007751181721687317

# %%
matching_labels_distribution(model_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.8937)
# matching labels in 2st hop: tensor(0.8390)
# matching labels in 3rd hop: tensor(0.7911)
# ([tensor(0.6000),
#   tensor(0.5714),
#   tensor(0.6667),
#   tensor(0.9167),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7143),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5714),
#   tensor(1.),
#   tensor(0.6250),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.7143),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8462),
#   tensor(0.8333),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6250),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6923),
#   tensor(0.3750),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.6250),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8182),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.7500),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.5714),
#   tensor(0.8571),
#   tensor(0.8571),
#   tensor(0.8333),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.6667),
#   tensor(0.5000),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6364),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.4000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(0.6250),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.9000),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9091),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5714),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.5714),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.5833),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.4000),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(0.9091),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8824),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9231),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(0.8889),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.2000),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7143),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.2000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.)],
#  [tensor(0.5185),
#   tensor(0.4722),
#   tensor(0.3478),
#   tensor(0.7872),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8235),
#   tensor(0.8750),
#   tensor(0.6364),
#   tensor(0.9412),
#   tensor(0.6429),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.2500),
#   tensor(0.2500),
#   tensor(0.8571),
#   tensor(0.6667),
#   tensor(0.7000),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(0.8158),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3448),
#   tensor(0.7692),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.3889),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(0.8750),
#   tensor(0.4000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8636),
#   tensor(0.8000),
#   tensor(0.8667),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7727),
#   tensor(0.7692),
#   tensor(1.),
#   tensor(0.8667),
#   tensor(1.),
#   tensor(0.9500),
#   tensor(0.6250),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.3750),
#   tensor(0.7500),
#   tensor(0.9057),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(0.3333),
#   tensor(0.9313),
#   tensor(1.),
#   tensor(0.9108),
#   tensor(0.1923),
#   tensor(0.4286),
#   tensor(1.),
#   tensor(0.7414),
#   tensor(0.8148),
#   tensor(0.8333),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8750),
#   tensor(0.8636),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9841),
#   tensor(0.9615),
#   tensor(0.9839),
#   tensor(0.6667),
#   tensor(0.7391),
#   tensor(0.7273),
#   tensor(0.6667),
#   tensor(0.5714),
#   tensor(0.4444),
#   tensor(0.3478),
#   tensor(0.5152),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(0.9051),
#   tensor(0.8750),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.8636),
#   tensor(0.9143),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8049),
#   tensor(0.9154),
#   tensor(0.5385),
#   tensor(0.7500),
#   tensor(0.9351),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(1.),
#   tensor(0.9286),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7000),
#   tensor(0.7000),
#   tensor(0.8125),
#   tensor(0.5000),
#   tensor(0.8462),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3750),
#   tensor(0.6316),
#   tensor(0.9463),
#   tensor(0.7500),
#   tensor(0.8750),
#   tensor(0.8824),
#   tensor(0.3333),
#   tensor(0.9310),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.6923),
#   tensor(0.7308),
#   tensor(0.7538),
#   tensor(0.9391),
#   tensor(0.9500),
#   tensor(0.2857),
#   tensor(0.9091),
#   tensor(0.9259),
#   tensor(1.),
#   tensor(0.9333),
#   tensor(0.1538),
#   tensor(0.5000),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.5574),
#   tensor(1.),
#   tensor(0.8929),
#   tensor(0.8800),
#   tensor(0.9286),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6047),
#   tensor(0.5000),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6552),
#   tensor(0.2857),
#   tensor(0.4286),
#   tensor(1.),
#   tensor(0.1667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.9565),
#   tensor(1.),
#   tensor(0.5455),
#   tensor(0.5556),
#   tensor(1.),
#   tensor(0.7917),
#   tensor(0.7778),
#   tensor(0.7143),
#   tensor(0.6667),
#   tensor(0.9091),
#   tensor(0.8269),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.7273),
#   tensor(0.7500),
#   tensor(0.4286),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.9091),
#   tensor(0.9375),
#   tensor(0.7273),
#   tensor(0.7273),
#   tensor(1.),
#   tensor(0.9375),
#   tensor(0.9583),
#   tensor(0.8905),
#   tensor(0.5000),
#   tensor(0.3000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.8750),
#   tensor(0.9388),
#   tensor(0.9333),
#   tensor(1.),
#   tensor(0.6250),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8462),
#   tensor(1.),
#   tensor(0.2500),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9231),
#   tensor(0.3750),
#   tensor(0.5556),
#   tensor(0.7143),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(0.4872),
#   tensor(0.7865),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9189),
#   tensor(0.8571),
#   tensor(0.7500),
#   tensor(0.4286),
#   tensor(1.),
#   tensor(0.9184),
#   tensor(0.9394),
#   tensor(0.6491),
#   tensor(0.9333),
#   tensor(0.9286),
#   tensor(0.9286),
#   tensor(0.5000),
#   tensor(0.9615),
#   tensor(0.5833),
#   tensor(0.7241),
#   tensor(0.9055),
#   tensor(0.8944),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7750),
#   tensor(0.2500),
#   tensor(0.6000),
#   tensor(0.8000),
#   tensor(0.6667),
#   tensor(0.4286),
#   tensor(0.4286),
#   tensor(0.9115),
#   tensor(0.9130),
#   tensor(0.8837),
#   tensor(0.1613),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.6000),
#   tensor(0.9412),
#   tensor(0.5714),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.1316),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.1000),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8800),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7222),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5833),
#   tensor(0.5833),
#   tensor(0.6842),
#   tensor(0.7333),
#   tensor(0.7778),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.7273),
#   tensor(0.5294),
#   tensor(0.7333),
#   tensor(0.7778),
#   tensor(0.9545),
#   tensor(0.9091),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8235),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.3200),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.7500),
#   tensor(0.6667),
#   tensor(0.8182),
#   tensor(0.7500),
#   tensor(0.5652),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(0.8923),
#   tensor(1.),
#   tensor(0.6500),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.8689),
#   tensor(0.9292),
#   tensor(0.9417),
#   tensor(0.9464),
#   tensor(0.9483),
#   tensor(0.8000),
#   tensor(0.9630),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(0.6000),
#   tensor(0.7857),
#   tensor(0.5000),
#   tensor(0.8182),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9091),
#   tensor(0.6250),
#   tensor(0.8000),
#   tensor(0.5000),
#   tensor(0.5714),
#   tensor(1.),
#   tensor(0.9167),
#   tensor(0.9444),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.6774),
#   tensor(0.9302),
#   tensor(0.9406),
#   tensor(0.9223),
#   tensor(0.9469),
#   tensor(0.9204),
#   tensor(0.9216),
#   tensor(0.9459),
#   tensor(0.8983),
#   tensor(0.9020),
#   tensor(0.8870),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.4762),
#   tensor(0.6364),
#   tensor(0.6000),
#   tensor(0.3333),
#   tensor(0.9474),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.9130),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6154),
#   tensor(1.),
#   tensor(0.5556),
#   tensor(1.),
#   tensor(0.4167),
#   tensor(1.),
#   tensor(0.6250),
#   tensor(1.),
#   tensor(0.8846),
#   tensor(0.9750),
#   tensor(0.8125),
#   tensor(1.),
#   tensor(0.2500),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(0.6957),
#   tensor(0.9091),
#   tensor(0.9091),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8947),
#   tensor(1.),
#   tensor(0.8529),
#   tensor(0.2500),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6154),
#   tensor(1.),
#   tensor(0.1667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.7714),
#   tensor(0.8824),
#   tensor(0.8824),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9333),
#   tensor(0.9184),
#   tensor(0.6667),
#   tensor(0.8333),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.7273),
#   tensor(0.4792),
#   tensor(0.9000),
#   tensor(0.9016),
#   tensor(0.7500),
#   tensor(0.6250),
#   tensor(0.9268),
#   tensor(0.8571),
#   tensor(0.8148),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(0.8095),
#   tensor(0.6000),
#   tensor(0.8000),
#   tensor(0.7500),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.4167),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.9000),
#   tensor(0.7500),
#   tensor(0.8833),
#   tensor(0.8000),
#   tensor(0.8889),
#   tensor(0.6000),
#   tensor(0.3333),
#   tensor(0.6667),
#   tensor(0.8000),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.3125),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.9273),
#   tensor(0.8929),
#   tensor(0.7500),
#   tensor(0.9048),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9118),
#   tensor(0.4286),
#   tensor(0.8000),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9048),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9375),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9130),
#   tensor(0.8571),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9355),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9135),
#   tensor(0.9091),
#   tensor(0.9000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7333),
#   tensor(0.9375),
#   tensor(0.5556),
#   tensor(0.6429),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9062),
#   tensor(0.5600),
#   tensor(0.5417),
#   tensor(0.1250),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5200),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.0833),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(0.8571),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.8929),
#   tensor(0.2000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.8000),
#   tensor(0.5000),
#   tensor(0.8333),
#   tensor(0.8333),
#   tensor(0.8333),
#   tensor(0.8750),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8125),
#   tensor(0.1667),
#   tensor(0.8095),
#   tensor(0.3158),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(0.6957),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.4000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9091),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9048),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.9333),
#   tensor(0.4000),
#   tensor(0.6667),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.9355),
#   tensor(0.8889),
#   tensor(0.8889),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.8000),
#   tensor(0.8182),
#   tensor(0.8182),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9583),
#   tensor(0.9038),
#   tensor(0.9038),
#   tensor(0.9038),
#   tensor(1.),
#   tensor(0.8947),
#   tensor(0.7059),
#   tensor(0.8333),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.6111),
#   tensor(0.8000),
#   tensor(0.8000),
#   tensor(0.7692),
#   tensor(0.7143),
#   tensor(0.7143),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.9062),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.7333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7000),
#   tensor(0.1429),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.3333),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.8947),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.4286),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9167),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.9231),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.6667)],
#  [tensor(0.6719),
#   tensor(0.4595),
#   tensor(0.3103),
#   tensor(0.8043),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8298),
#   tensor(0.8485),
#   tensor(0.7500),
#   tensor(0.9057),
#   tensor(0.6735),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.1667),
#   tensor(0.2162),
#   tensor(0.7368),
#   tensor(0.6028),
#   tensor(0.2727),
#   tensor(0.7500),
#   tensor(0.6000),
#   tensor(0.6610),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3387),
#   tensor(0.4800),
#   tensor(0.9688),
#   tensor(1.),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(0.6875),
#   tensor(0.2885),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.8824),
#   tensor(0.8065),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8052),
#   tensor(0.6712),
#   tensor(0.7105),
#   tensor(0.9310),
#   tensor(0.5000),
#   tensor(0.9130),
#   tensor(0.9697),
#   tensor(0.9429),
#   tensor(0.8710),
#   tensor(0.8077),
#   tensor(0.9111),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.9714),
#   tensor(0.3043),
#   tensor(0.5294),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(0.8929),
#   tensor(0.7059),
#   tensor(0.3103),
#   tensor(0.8333),
#   tensor(0.9008),
#   tensor(0.7500),
#   tensor(0.6000),
#   tensor(0.6429),
#   tensor(0.7993),
#   tensor(0.9313),
#   tensor(0.7681),
#   tensor(0.2206),
#   tensor(0.4167),
#   tensor(1.),
#   tensor(0.7846),
#   tensor(0.6494),
#   tensor(0.8333),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.7000),
#   tensor(0.8947),
#   tensor(1.),
#   tensor(0.9040),
#   tensor(0.8717),
#   tensor(0.9119),
#   tensor(0.8843),
#   tensor(0.7500),
#   tensor(0.6040),
#   tensor(0.6433),
#   tensor(0.5714),
#   tensor(0.4444),
#   tensor(0.6667),
#   tensor(0.3125),
#   tensor(0.6993),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(0.7817),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.8947),
#   tensor(0.7746),
#   tensor(0.9143),
#   tensor(0.9200),
#   tensor(0.8447),
#   tensor(0.7885),
#   tensor(0.4500),
#   tensor(0.8000),
#   tensor(0.9053),
#   tensor(0.9351),
#   tensor(0.9351),
#   tensor(0.9496),
#   tensor(0.9351),
#   tensor(0.9351),
#   tensor(0.9444),
#   tensor(1.),
#   tensor(0.8205),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6875),
#   tensor(0.6875),
#   tensor(0.7407),
#   tensor(0.3529),
#   tensor(0.6364),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9444),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.1905),
#   tensor(0.5490),
#   tensor(0.7930),
#   tensor(0.8000),
#   tensor(0.7778),
#   tensor(0.5082),
#   tensor(0.0690),
#   tensor(0.8929),
#   tensor(1.),
#   tensor(0.9167),
#   tensor(0.5882),
#   tensor(0.6940),
#   tensor(0.7672),
#   tensor(0.8022),
#   tensor(0.8667),
#   tensor(0.1944),
#   tensor(0.8281),
#   tensor(0.9189),
#   tensor(0.8571),
#   tensor(0.9104),
#   tensor(0.0882),
#   tensor(0.5000),
#   tensor(0.5714),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7414),
#   tensor(1.),
#   tensor(0.9067),
#   tensor(0.8154),
#   tensor(0.8889),
#   tensor(0.7586),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(0.5917),
#   tensor(0.5000),
#   tensor(0.8667),
#   tensor(0.9412),
#   tensor(0.9118),
#   tensor(0.6891),
#   tensor(0.3000),
#   tensor(0.4000),
#   tensor(0.8987),
#   tensor(0.2222),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.4667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9344),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8182),
#   tensor(0.2222),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9600),
#   tensor(0.8793),
#   tensor(1.),
#   tensor(0.4000),
#   tensor(0.5000),
#   tensor(0.8857),
#   tensor(0.4918),
#   tensor(0.5833),
#   tensor(0.6800),
#   tensor(0.7500),
#   tensor(0.7762),
#   tensor(0.8372),
#   tensor(0.7273),
#   tensor(0.7273),
#   tensor(0.8889),
#   tensor(0.6429),
#   tensor(0.7500),
#   tensor(0.2381),
#   tensor(1.),
#   tensor(0.5217),
#   tensor(0.8831),
#   tensor(0.8222),
#   tensor(0.5385),
#   tensor(0.5385),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.7750),
#   tensor(0.7898),
#   tensor(0.7143),
#   tensor(0.3421),
#   tensor(0.5294),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.6875),
#   tensor(0.8087),
#   tensor(0.8850),
#   tensor(0.8750),
#   tensor(1.),
#   tensor(0.7000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8438),
#   tensor(1.),
#   tensor(0.0417),
#   tensor(0.8667),
#   tensor(0.8333),
#   tensor(0.9231),
#   tensor(1.),
#   tensor(0.8947),
#   tensor(0.2326),
#   tensor(0.2400),
#   tensor(0.5263),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8491),
#   tensor(0.7719),
#   tensor(0.7193),
#   tensor(1.),
#   tensor(0.8125),
#   tensor(0.8646),
#   tensor(0.8634),
#   tensor(0.4286),
#   tensor(0.2727),
#   tensor(1.),
#   tensor(0.7154),
#   tensor(0.8913),
#   tensor(0.7071),
#   tensor(0.6970),
#   tensor(0.6491),
#   tensor(0.6491),
#   tensor(0.4375),
#   tensor(0.9152),
#   tensor(0.4643),
#   tensor(0.3786),
#   tensor(0.7853),
#   tensor(0.7829),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9048),
#   tensor(0.8080),
#   tensor(0.2500),
#   tensor(0.6842),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(0.4615),
#   tensor(0.4615),
#   tensor(0.7914),
#   tensor(0.7914),
#   tensor(0.8641),
#   tensor(0.0480),
#   tensor(0.7939),
#   tensor(1.),
#   tensor(0.7553),
#   tensor(0.2000),
#   tensor(0.8205),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.0491),
#   tensor(1.),
#   tensor(0.8261),
#   tensor(0.9000),
#   tensor(0.6667),
#   tensor(0.0556),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.9556),
#   tensor(0.9565),
#   tensor(0.9545),
#   tensor(0.9556),
#   tensor(0.9556),
#   tensor(0.9535),
#   tensor(0.9318),
#   tensor(1.),
#   tensor(0.8095),
#   tensor(0.6200),
#   tensor(1.),
#   tensor(0.7727),
#   tensor(0.9730),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5855),
#   tensor(0.5855),
#   tensor(0.5309),
#   tensor(0.6698),
#   tensor(0.8000),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(0.6800),
#   tensor(0.7442),
#   tensor(0.5357),
#   tensor(0.6216),
#   tensor(0.7391),
#   tensor(0.8644),
#   tensor(0.8644),
#   tensor(0.9255),
#   tensor(1.),
#   tensor(0.9167),
#   tensor(1.),
#   tensor(0.8824),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.1642),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9286),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7143),
#   tensor(0.7619),
#   tensor(0.5000),
#   tensor(0.7778),
#   tensor(0.7200),
#   tensor(0.5455),
#   tensor(0.9412),
#   tensor(0.9444),
#   tensor(0.8296),
#   tensor(0.8841),
#   tensor(0.6094),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.6786),
#   tensor(0.7500),
#   tensor(0.7843),
#   tensor(0.7904),
#   tensor(0.7949),
#   tensor(0.7910),
#   tensor(0.8374),
#   tensor(0.8333),
#   tensor(0.9057),
#   tensor(0.7000),
#   tensor(1.),
#   tensor(0.7000),
#   tensor(0.5714),
#   tensor(0.6452),
#   tensor(0.5000),
#   tensor(0.6296),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7419),
#   tensor(0.6250),
#   tensor(0.6250),
#   tensor(0.5000),
#   tensor(0.6923),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(0.8723),
#   tensor(0.9103),
#   tensor(0.9474),
#   tensor(0.5000),
#   tensor(0.7807),
#   tensor(0.7961),
#   tensor(0.7939),
#   tensor(0.7940),
#   tensor(0.7978),
#   tensor(0.7881),
#   tensor(0.7879),
#   tensor(0.7978),
#   tensor(0.8000),
#   tensor(0.7790),
#   tensor(0.7601),
#   tensor(0.7500),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.5455),
#   tensor(0.4483),
#   tensor(0.3214),
#   tensor(0.0198),
#   tensor(0.8793),
#   tensor(1.),
#   tensor(0.6429),
#   tensor(0.8298),
#   tensor(0.8654),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(0.5692),
#   tensor(1.),
#   tensor(0.5556),
#   tensor(1.),
#   tensor(0.3684),
#   tensor(1.),
#   tensor(0.3889),
#   tensor(1.),
#   tensor(0.8469),
#   tensor(0.8500),
#   tensor(0.3897),
#   tensor(0.9267),
#   tensor(0.2000),
#   tensor(0.8000),
#   tensor(0.9167),
#   tensor(1.),
#   tensor(0.8442),
#   tensor(0.6957),
#   tensor(0.6957),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8929),
#   tensor(0.8235),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8478),
#   tensor(1.),
#   tensor(0.8536),
#   tensor(0.1639),
#   tensor(1.),
#   tensor(0.7579),
#   tensor(0.5610),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5526),
#   tensor(1.),
#   tensor(0.1667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.7857),
#   tensor(0.7941),
#   tensor(0.7714),
#   tensor(0.7714),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(0.7778),
#   tensor(0.8000),
#   tensor(0.9074),
#   tensor(0.9068),
#   tensor(0.5750),
#   tensor(0.8261),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.7692),
#   tensor(0.2772),
#   tensor(0.9044),
#   tensor(0.8867),
#   tensor(0.4286),
#   tensor(0.3810),
#   tensor(0.8396),
#   tensor(0.8704),
#   tensor(0.8211),
#   tensor(0.9167),
#   tensor(1.),
#   tensor(0.8952),
#   tensor(0.3385),
#   tensor(0.8000),
#   tensor(0.8000),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.2059),
#   tensor(1.),
#   tensor(0.1053),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.9500),
#   tensor(0.7143),
#   tensor(0.8897),
#   tensor(0.8833),
#   tensor(0.9032),
#   tensor(0.3889),
#   tensor(0.3500),
#   tensor(0.6667),
#   tensor(0.5152),
#   tensor(0.8000),
#   tensor(0.8750),
#   tensor(0.2418),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.8327),
#   tensor(0.8855),
#   tensor(0.7500),
#   tensor(0.8882),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7730),
#   tensor(0.3750),
#   tensor(0.8333),
#   tensor(0.3333),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8833),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9160),
#   tensor(0.9155),
#   tensor(0.9268),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.4000),
#   tensor(1.),
#   tensor(0.7857),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.9302),
#   tensor(1.),
#   tensor(0.8522),
#   tensor(0.8750),
#   tensor(0.7407),
#   tensor(1.),
#   tensor(0.9580),
#   tensor(0.9053),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8498),
#   tensor(0.9059),
#   tensor(0.6667),
#   tensor(0.4444),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.6000),
#   tensor(0.7762),
#   tensor(0.6591),
#   tensor(0.4699),
#   tensor(0.9286),
#   tensor(0.9062),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8670),
#   tensor(0.6716),
#   tensor(0.6716),
#   tensor(0.0597),
#   tensor(0.7059),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9231),
#   tensor(0.7500),
#   tensor(0.8000),
#   tensor(0.2500),
#   tensor(0.6154),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(0.4444),
#   tensor(0.8571),
#   tensor(0.9549),
#   tensor(1.),
#   tensor(0.2000),
#   tensor(0.4286),
#   tensor(0.4286),
#   tensor(0.8667),
#   tensor(0.7500),
#   tensor(0.9167),
#   tensor(0.8553),
#   tensor(0.2143),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9084),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.8776),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.8125),
#   tensor(0.5000),
#   tensor(0.8571),
#   tensor(0.8571),
#   tensor(0.8571),
#   tensor(0.7619),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.6500),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8649),
#   tensor(0.1071),
#   tensor(0.7179),
#   tensor(0.2424),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(0.8182),
#   tensor(0.5312),
#   tensor(0.6667),
#   tensor(0.6429),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9123),
#   tensor(1.),
#   tensor(0.9023),
#   tensor(0.9048),
#   tensor(0.9048),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8852),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.9167),
#   tensor(0.2500),
#   tensor(0.4000),
#   tensor(0.4615),
#   tensor(0.8750),
#   tensor(0.5000),
#   tensor(0.2889),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7059),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9091),
#   tensor(0.9328),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6765),
#   tensor(0.8286),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(0.8235),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(0.8182),
#   tensor(0.8182),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.8644),
#   tensor(0.8992),
#   tensor(0.8992),
#   tensor(0.8992),
#   tensor(1.),
#   tensor(0.7627),
#   tensor(0.6389),
#   tensor(0.8000),
#   tensor(0.8889),
#   tensor(0.8235),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8235),
#   tensor(0.4898),
#   tensor(0.8333),
#   tensor(0.9000),
#   tensor(0.7143),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.4800),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3182),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(0.8636),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.9412),
#   tensor(0.6436),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.9231),
#   tensor(0.7273),
#   tensor(0.1739),
#   tensor(0.9091),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.4000),
#   tensor(0.3448),
#   tensor(0.8750),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8966),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8276),
#   tensor(0.8600),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.0351),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6842),
#   tensor(1.),
#   tensor(0.3846),
#   tensor(1.),
#   tensor(0.9184),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.9091)])

# %% [markdown]
# Label distribution of nodes classified correctly by GAT

# %%
matching_labels_distribution(gat_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.9083)
# matching labels in 2st hop: tensor(0.8623)
# matching labels in 3rd hop: tensor(0.8197)

# %% [markdown]
# Label distribution of nodes classified correctly by our model but not by GAT

# %%
matching_labels_distribution(model_not_gat_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.6593)
# matching labels in 2st hop: tensor(0.4637)
# matching labels in 3rd hop: tensor(0.3674)

# %% [markdown]
# Label distribution of nodes classified correctly our model and by GAT

# %%
matching_labels_distribution(model_and_gat_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.9122)
# matching labels in 2st hop: tensor(0.8687)
# matching labels in 3rd hop: tensor(0.8246)

# %% [markdown]
# Label distribution of nodes classified correctly GAT but not by our model

# %%
matching_labels_distribution(gat_not_model_correct_nodes)

# %% [markdown]
# Label distribution of nodes classified incorrectly by both GAT and our model

# %%
matching_labels_distribution(gat_and_model_incorrect_nodes)
