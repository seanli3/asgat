# %% [markdown]
# Import dependencies

# %%
from model.layers import GraphSpectralFilterLayer, AnalysisFilter
from model.spectral_filter import Graph
import torch
import torch.nn.functional as F
from torch import nn
from random import seed as rseed
from numpy.random import seed as nseed
from citation import get_dataset, random_planetoid_splits, run
from citation.train_eval import evaluate
import numpy as np

# %% [markdown]
# Define hyperparameters

# %%
dataset_name = 'CiteSeer'

random_splits = False
runs = 1
epochs =400
alpha = 0.7709619178612326
seed =729
lr =0.00022455151763075903
weight_decay = 7.530100210192558e-05
patience=100
hidden=32
heads =14
dropout=0.6174883141474811
normalize_features =True
pre_training = False
cuda = False
order =15
edge_dropout =0
node_feature_dropout =0
filter_name ='analysis'

rseed(seed)
nseed(seed)
torch.manual_seed(seed)

cuda = cuda and torch.cuda.is_available()

if cuda:
    torch.cuda.manual_seed(seed)
    torch.set_default_tensor_type('torch.cuda.FloatTensor')

def get_correctly_predicted_node_idx(net, key, dataset):
    net.eval()
    with torch.no_grad():
        logits  = net(dataset[0])[0]
    mask = dataset[0]['{}_mask'.format(key)]
    pred = logits[mask].max(1)[1]
    return { *pred.eq(dataset[0].y[mask]).nonzero().view(-1).tolist() }

# %% [markdown]
# Define model

# %%
class Net(torch.nn.Module):
    def __init__(self, dataset):
        super(Net, self).__init__()
        data = dataset.data
        adj = torch.sparse_coo_tensor(data.edge_index, torch.ones(data.num_edges))
        self.G = Graph(adj)
        self.G.estimate_lmax()

        self.analysis = GraphSpectralFilterLayer(self.G, dataset.num_node_features, hidden,
                                                 dropout=dropout, out_channels=heads, filter=filter_name,
                                                 pre_training=False, device='cuda' if cuda else 'cpu',
                                                 alpha=alpha, order=order, concat=True)

        self.synthesis = GraphSpectralFilterLayer(self.G, hidden * heads, dataset.num_classes, filter=filter_name,
                                                  device='cuda' if cuda else 'cpu', dropout=dropout,
                                                  out_channels=1, alpha=alpha, pre_training=False,
                                                  order=order, concat=False)

    def reset_parameters(self):
        self.analysis.reset_parameters()
        self.synthesis.reset_parameters()

    def forward(self, data):
        x = data.x
        x = F.dropout(x, p=dropout, training=self.training)
        x, att1 = self.analysis(x)
        layer_1 = x
        x = F.dropout(x, p=dropout, training=self.training)
        x, att2 = self.synthesis(x)
        layer_2 = x
        x = F.elu(x)
        return F.log_softmax(x, dim=1), layer_1, layer_2

dataset = get_dataset(dataset_name, normalize_features, edge_dropout=edge_dropout,
                                node_feature_dropout=node_feature_dropout)

if cuda:
    dataset[0].to('cuda')

# %%
student_heads = 12
hidden= 32
dropout=0

class StudentNet(torch.nn.Module):
    def __init__(self, dataset):
        super(StudentNet, self).__init__()
        data = dataset.data
        adj = torch.sparse_coo_tensor(data.edge_index, torch.ones(data.num_edges))
        self.G = Graph(adj)
        self.G.estimate_lmax()

        self.analysis = GraphSpectralFilterLayer(self.G, dataset.num_node_features, hidden,
                                                 dropout=dropout, out_channels=student_heads, filter=filter_name,
                                                 pre_training=False, device='cuda' if cuda else 'cpu',
                                                 alpha=alpha, order=order, concat=True)

        self.synthesis = GraphSpectralFilterLayer(self.G, hidden * student_heads, dataset.num_classes, filter=filter_name,
                                                  device='cuda' if cuda else 'cpu', dropout=dropout,
                                                  out_channels=student_heads, alpha=alpha, pre_training=False,
                                                  order=order, concat=False)
    def reset_parameters(self):
        self.analysis.reset_parameters()
        # self.synthesis.reset_parameters()

    def forward(self, data):
        x = data.x
        x = F.dropout(x, p=dropout, training=self.training)
        x, att1 = self.analysis(x)
        layer_1 = x
        x = F.dropout(x, p=dropout, training=self.training)
        x, att2 = self.synthesis(x)
        layer_2 = x
        x = F.elu(x)
        return F.log_softmax(x, dim=1), layer_1, layer_2

# %% [markdown]
# Load trained model and evaluate

# %%
model = Net(dataset)
model.load_state_dict(torch.load('./model/best_Citeseer_lt_zero.pkl'.format(dataset_name),  map_location={'cuda:0': 'cpu'}))

# model = SingleNet(dataset)
# model.load_state_dict(torch.load('./model/best_{}_single_layer.pkl'.format(dataset_name)))

# filter_kernel = model.analysis.filter_kernel

# model_correct_indices = get_correctly_predicted_node_idx(model, 'test', dataset)
eval_info = evaluate(model, dataset[0])
print(eval_info)
# Out:
# {'train_loss': 0.36703506112098694, 'train_acc': 0.9211822660098522, 'train_micro_f1': 0.9211822660098522, 'train_macro_f1': 0.9157023986911743, 'val_loss': 0.6948285102844238, 'val_acc': 0.796, 'val_micro_f1': 0.796, 'val_macro_f1': 0.7447925714273606, 'test_loss': 0.6948463320732117, 'test_acc': 0.805, 'test_micro_f1': 0.805, 'test_macro_f1': 0.7737372300784445}

# %%
def train_student(Model, target_1, target_2=None, lr=lr):
    from torch.optim import Adam
    from sklearn.metrics import f1_score
    student = Model(dataset)
    student.reset_parameters()
    optimizer = Adam(student.parameters(), lr=lr, weight_decay=weight_decay)
    data = dataset.data
    epochs =2000

    for epoch in range(1, epochs + 1):
        optimizer.zero_grad()
        logits, out_2, out_1 = student(data)
        loss = F.mse_loss(out_1[dataset[0].train_mask], target_1[dataset[0].train_mask])
        if target_2 is not None:
            loss += F.mse_loss(out_2[dataset[0].train_mask], target_2[dataset[0].train_mask])
        loss.backward()
        optimizer.step()
        student.train()

        # eval_info['epoch'] = epoch
        if epoch % 10 == 0:
            student.eval()
            outs = {}
            for key in ['train', 'val', 'test']:
                mask = data['{}_mask'.format(key)]
                loss = F.mse_loss(out_1[mask], target_1[mask])
                if target_2 is not None:
                    loss += F.mse_loss(out_2[mask], target_2[mask])
                outs['{}_loss'.format(key)] = loss.item()
                # loss = F.nll_loss(logits[mask], data.y[mask]).item()
                # pred = logits[mask].max(1)[1]
                # outs['{}_loss'.format(key)] = loss
                outs['{}_micro_f1'.format(key)] = f1_score(data.y[mask].cpu(), logits[mask].max(1)[1].cpu(), average='micro')
                # outs['{}_macro_f1'.format(key)] = f1_score(data.y[mask].cpu(), logits[mask].max(1)[1].cpu(), average='macro')

            print(outs)
        # if eval_info['val_acc'] > best_val_acc or eval_info['val_loss'] < best_val_loss:
        #     if eval_info['val_acc'] >= best_val_acc and eval_info['val_loss'] <= best_val_loss:
        #         eval_info_early_model = eval_info
        #         # torch.save(model.state_dict(), './best_{}_appnp.pkl'.format(dataset.name))
        #     best_val_acc = np.max((best_val_acc, eval_info['val_acc']))
        #     best_val_loss = np.min((best_val_loss, eval_info['val_loss']))
        #     bad_counter = 0
        # else:
        #     bad_counter += 1
        #     if bad_counter == patience:
        #         break

# %%
with torch.no_grad():
    _, target_1, target_2 = model(dataset[0])

train_student(StudentNet, target_2, lr=0.001)
# Out:
# {'train_loss': 1.900356411933899, 'train_micro_f1': 0.541871921182266, 'val_loss': 1.5766907930374146, 'val_micro_f1': 0.54, 'test_loss': 1.611171007156372, 'test_micro_f1': 0.512}
# {'train_loss': 1.3834559917449951, 'train_micro_f1': 0.6661193212917351, 'val_loss': 1.1181159019470215, 'val_micro_f1': 0.676, 'test_loss': 1.1511329412460327, 'test_micro_f1': 0.639}
# {'train_loss': 0.7616308331489563, 'train_micro_f1': 0.7454844006568144, 'val_loss': 0.5927627682685852, 'val_micro_f1': 0.7160000000000001, 'test_loss': 0.6137223243713379, 'test_micro_f1': 0.734}
# {'train_loss': 0.3622009754180908, 'train_micro_f1': 0.7640941434044882, 'val_loss': 0.2867269217967987, 'val_micro_f1': 0.74, 'test_loss': 0.2945309579372406, 'test_micro_f1': 0.761}
# {'train_loss': 0.2052546739578247, 'train_micro_f1': 0.78544061302682, 'val_loss': 0.19528210163116455, 'val_micro_f1': 0.764, 'test_loss': 0.18532991409301758, 'test_micro_f1': 0.764}
# {'train_loss': 0.14457248151302338, 'train_micro_f1': 0.8155446086480569, 'val_loss': 0.17577089369297028, 'val_micro_f1': 0.7699999999999999, 'test_loss': 0.16423365473747253, 'test_micro_f1': 0.7810000000000001}
# {'train_loss': 0.10106897354125977, 'train_micro_f1': 0.8297755883962781, 'val_loss': 0.15065541863441467, 'val_micro_f1': 0.762, 'test_loss': 0.1419098973274231, 'test_micro_f1': 0.785}
# {'train_loss': 0.07976474612951279, 'train_micro_f1': 0.8445539135194308, 'val_loss': 0.13914071023464203, 'val_micro_f1': 0.768, 'test_loss': 0.13009531795978546, 'test_micro_f1': 0.7840000000000001}
# {'train_loss': 0.07237628102302551, 'train_micro_f1': 0.8478379857690203, 'val_loss': 0.1405199021100998, 'val_micro_f1': 0.7699999999999999, 'test_loss': 0.13156408071517944, 'test_micro_f1': 0.787}
# {'train_loss': 0.04611659795045853, 'train_micro_f1': 0.8713738368910783, 'val_loss': 0.11262668669223785, 'val_micro_f1': 0.764, 'test_loss': 0.10456861555576324, 'test_micro_f1': 0.7940000000000002}
# {'train_loss': 0.03252149745821953, 'train_micro_f1': 0.8856048166392994, 'val_loss': 0.09464656561613083, 'val_micro_f1': 0.78, 'test_loss': 0.08914226293563843, 'test_micro_f1': 0.793}
# {'train_loss': 0.02540547214448452, 'train_micro_f1': 0.8877941981390257, 'val_loss': 0.0883234366774559, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.0847022756934166, 'test_micro_f1': 0.7940000000000002}
# {'train_loss': 0.019872596487402916, 'train_micro_f1': 0.8949096880131363, 'val_loss': 0.08091456443071365, 'val_micro_f1': 0.786, 'test_loss': 0.07862529158592224, 'test_micro_f1': 0.798}
# {'train_loss': 0.01574544422328472, 'train_micro_f1': 0.9009304871373837, 'val_loss': 0.0775960385799408, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07595895975828171, 'test_micro_f1': 0.798}
# {'train_loss': 0.012906182557344437, 'train_micro_f1': 0.9042145593869731, 'val_loss': 0.07553194463253021, 'val_micro_f1': 0.78, 'test_loss': 0.07396930456161499, 'test_micro_f1': 0.801}
# {'train_loss': 0.010814009234309196, 'train_micro_f1': 0.9053092501368364, 'val_loss': 0.07445592433214188, 'val_micro_f1': 0.782, 'test_loss': 0.07319754362106323, 'test_micro_f1': 0.802}
# {'train_loss': 0.009224004112184048, 'train_micro_f1': 0.9080459770114943, 'val_loss': 0.07368074357509613, 'val_micro_f1': 0.782, 'test_loss': 0.07256767153739929, 'test_micro_f1': 0.802}
# {'train_loss': 0.008070286363363266, 'train_micro_f1': 0.9069512862616311, 'val_loss': 0.07323907315731049, 'val_micro_f1': 0.786, 'test_loss': 0.0723552405834198, 'test_micro_f1': 0.8000000000000002}
# {'train_loss': 0.006973397918045521, 'train_micro_f1': 0.9129720853858785, 'val_loss': 0.07310302555561066, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07210488617420197, 'test_micro_f1': 0.801}
# {'train_loss': 0.0061536384746432304, 'train_micro_f1': 0.9151614668856048, 'val_loss': 0.07307249307632446, 'val_micro_f1': 0.782, 'test_loss': 0.07207576930522919, 'test_micro_f1': 0.801}
# {'train_loss': 0.005474478006362915, 'train_micro_f1': 0.9157088122605364, 'val_loss': 0.07305096089839935, 'val_micro_f1': 0.782, 'test_loss': 0.07198268920183182, 'test_micro_f1': 0.801}
# {'train_loss': 0.00490121403709054, 'train_micro_f1': 0.916256157635468, 'val_loss': 0.0731426402926445, 'val_micro_f1': 0.782, 'test_loss': 0.07203808426856995, 'test_micro_f1': 0.802}
# {'train_loss': 0.004414261784404516, 'train_micro_f1': 0.9157088122605364, 'val_loss': 0.0732334554195404, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07205861061811447, 'test_micro_f1': 0.802}
# {'train_loss': 0.003996136132627726, 'train_micro_f1': 0.9157088122605364, 'val_loss': 0.07336974889039993, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07214155048131943, 'test_micro_f1': 0.802}
# {'train_loss': 0.0036346649285405874, 'train_micro_f1': 0.9168035030103996, 'val_loss': 0.07350518554449081, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07222045958042145, 'test_micro_f1': 0.801}
# {'train_loss': 0.003319938201457262, 'train_micro_f1': 0.9173508483853311, 'val_loss': 0.07364791631698608, 'val_micro_f1': 0.79, 'test_loss': 0.07231437414884567, 'test_micro_f1': 0.801}
# {'train_loss': 0.0030443547293543816, 'train_micro_f1': 0.9178981937602627, 'val_loss': 0.07378624379634857, 'val_micro_f1': 0.79, 'test_loss': 0.0724097266793251, 'test_micro_f1': 0.801}
# {'train_loss': 0.002801781753078103, 'train_micro_f1': 0.9184455391351942, 'val_loss': 0.07391708344221115, 'val_micro_f1': 0.79, 'test_loss': 0.07250296324491501, 'test_micro_f1': 0.801}
# {'train_loss': 0.002587223192676902, 'train_micro_f1': 0.9184455391351942, 'val_loss': 0.07404177635908127, 'val_micro_f1': 0.788, 'test_loss': 0.07259731739759445, 'test_micro_f1': 0.8000000000000002}
# {'train_loss': 0.0023966417647898197, 'train_micro_f1': 0.9184455391351942, 'val_loss': 0.07415702193975449, 'val_micro_f1': 0.788, 'test_loss': 0.0726877897977829, 'test_micro_f1': 0.799}
# {'train_loss': 0.002226669806987047, 'train_micro_f1': 0.9184455391351942, 'val_loss': 0.07426420599222183, 'val_micro_f1': 0.79, 'test_loss': 0.07277704775333405, 'test_micro_f1': 0.8000000000000002}
# {'train_loss': 0.002074538730084896, 'train_micro_f1': 0.9184455391351942, 'val_loss': 0.07436234503984451, 'val_micro_f1': 0.79, 'test_loss': 0.0728636085987091, 'test_micro_f1': 0.8000000000000002}
# {'train_loss': 0.001937918015755713, 'train_micro_f1': 0.9189928845101258, 'val_loss': 0.07445190846920013, 'val_micro_f1': 0.79, 'test_loss': 0.07294748723506927, 'test_micro_f1': 0.799}
# {'train_loss': 0.001814846065826714, 'train_micro_f1': 0.9189928845101258, 'val_loss': 0.07453348487615585, 'val_micro_f1': 0.788, 'test_loss': 0.07302896678447723, 'test_micro_f1': 0.798}
# {'train_loss': 0.0017036577919498086, 'train_micro_f1': 0.9189928845101258, 'val_loss': 0.07460750639438629, 'val_micro_f1': 0.788, 'test_loss': 0.07310790568590164, 'test_micro_f1': 0.801}
# {'train_loss': 0.0016029305988922715, 'train_micro_f1': 0.9195402298850575, 'val_loss': 0.07467455416917801, 'val_micro_f1': 0.788, 'test_loss': 0.0731845274567604, 'test_micro_f1': 0.801}
# {'train_loss': 0.0015114450361579657, 'train_micro_f1': 0.9195402298850575, 'val_loss': 0.07473520189523697, 'val_micro_f1': 0.788, 'test_loss': 0.07325907051563263, 'test_micro_f1': 0.802}
# {'train_loss': 0.001428151736035943, 'train_micro_f1': 0.9195402298850575, 'val_loss': 0.07478993386030197, 'val_micro_f1': 0.788, 'test_loss': 0.07333160191774368, 'test_micro_f1': 0.802}
# {'train_loss': 0.0014843452954664826, 'train_micro_f1': 0.9189928845101258, 'val_loss': 0.07504098862409592, 'val_micro_f1': 0.788, 'test_loss': 0.07375793904066086, 'test_micro_f1': 0.801}
# {'train_loss': 0.0013134271139279008, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.07503967732191086, 'val_micro_f1': 0.788, 'test_loss': 0.07366800308227539, 'test_micro_f1': 0.802}
# {'train_loss': 0.0012219703057780862, 'train_micro_f1': 0.9195402298850575, 'val_loss': 0.0751163586974144, 'val_micro_f1': 0.788, 'test_loss': 0.07377753406763077, 'test_micro_f1': 0.802}
# {'train_loss': 0.0013062426587566733, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07493007928133011, 'val_micro_f1': 0.788, 'test_loss': 0.07329752296209335, 'test_micro_f1': 0.802}
# {'train_loss': 0.0011136973043903708, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07492546737194061, 'val_micro_f1': 0.786, 'test_loss': 0.07359672337770462, 'test_micro_f1': 0.801}
# {'train_loss': 0.0010284923482686281, 'train_micro_f1': 0.9200875752599891, 'val_loss': 0.07483223080635071, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07364820688962936, 'test_micro_f1': 0.802}
# {'train_loss': 0.0009638849296607077, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07474174350500107, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.0735606849193573, 'test_micro_f1': 0.801}
# {'train_loss': 0.0009083399781957269, 'train_micro_f1': 0.9200875752599891, 'val_loss': 0.07459845393896103, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07347086071968079, 'test_micro_f1': 0.802}
# {'train_loss': 0.0008578383130952716, 'train_micro_f1': 0.9200875752599891, 'val_loss': 0.07450464367866516, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07340778410434723, 'test_micro_f1': 0.802}
# {'train_loss': 0.0008122351719066501, 'train_micro_f1': 0.9200875752599891, 'val_loss': 0.07442286610603333, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.0733419805765152, 'test_micro_f1': 0.803}
# {'train_loss': 0.0007707159384153783, 'train_micro_f1': 0.9200875752599891, 'val_loss': 0.0743388906121254, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07326969504356384, 'test_micro_f1': 0.803}
# {'train_loss': 0.0007328201318159699, 'train_micro_f1': 0.9200875752599891, 'val_loss': 0.07428890466690063, 'val_micro_f1': 0.786, 'test_loss': 0.07321613281965256, 'test_micro_f1': 0.804}
# {'train_loss': 0.0006983567145653069, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07425341010093689, 'val_micro_f1': 0.786, 'test_loss': 0.07317306101322174, 'test_micro_f1': 0.805}
# {'train_loss': 0.0006670691655017436, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07422438263893127, 'val_micro_f1': 0.786, 'test_loss': 0.07313697040081024, 'test_micro_f1': 0.804}
# {'train_loss': 0.0006386797758750618, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07420524954795837, 'val_micro_f1': 0.786, 'test_loss': 0.07310664653778076, 'test_micro_f1': 0.804}
# {'train_loss': 0.0006131600821390748, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07426478713750839, 'val_micro_f1': 0.786, 'test_loss': 0.07314429432153702, 'test_micro_f1': 0.803}
# {'train_loss': 0.0005892848130315542, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07422278076410294, 'val_micro_f1': 0.786, 'test_loss': 0.07312112301588058, 'test_micro_f1': 0.803}
# {'train_loss': 0.0005678480956703424, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07419206202030182, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07308762520551682, 'test_micro_f1': 0.804}
# {'train_loss': 0.0005482216365635395, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07417768985033035, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07307929545640945, 'test_micro_f1': 0.804}
# {'train_loss': 0.0005303750513121486, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07416937500238419, 'val_micro_f1': 0.788, 'test_loss': 0.07308845221996307, 'test_micro_f1': 0.804}
# {'train_loss': 0.0005139790591783822, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07415879517793655, 'val_micro_f1': 0.788, 'test_loss': 0.07310263812541962, 'test_micro_f1': 0.803}
# {'train_loss': 0.0004987608990631998, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07415150105953217, 'val_micro_f1': 0.786, 'test_loss': 0.07312449812889099, 'test_micro_f1': 0.802}
# {'train_loss': 0.0004845658550038934, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07414861768484116, 'val_micro_f1': 0.786, 'test_loss': 0.07315289974212646, 'test_micro_f1': 0.802}
# {'train_loss': 0.0004712735244538635, 'train_micro_f1': 0.9200875752599891, 'val_loss': 0.07414956390857697, 'val_micro_f1': 0.786, 'test_loss': 0.0731874331831932, 'test_micro_f1': 0.802}
# {'train_loss': 0.0004587800649460405, 'train_micro_f1': 0.9200875752599891, 'val_loss': 0.0741540715098381, 'val_micro_f1': 0.786, 'test_loss': 0.07322686910629272, 'test_micro_f1': 0.802}
# {'train_loss': 0.0004470123094506562, 'train_micro_f1': 0.9200875752599891, 'val_loss': 0.0741623193025589, 'val_micro_f1': 0.786, 'test_loss': 0.07327046990394592, 'test_micro_f1': 0.803}
# {'train_loss': 0.0004359060258138925, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07417405396699905, 'val_micro_f1': 0.786, 'test_loss': 0.073317751288414, 'test_micro_f1': 0.803}
# {'train_loss': 0.0004254088271409273, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07418924570083618, 'val_micro_f1': 0.786, 'test_loss': 0.07336835563182831, 'test_micro_f1': 0.803}
# {'train_loss': 0.00041546972352080047, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07420789450407028, 'val_micro_f1': 0.786, 'test_loss': 0.07342211902141571, 'test_micro_f1': 0.803}
# {'train_loss': 0.00040604459354653955, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07422997802495956, 'val_micro_f1': 0.786, 'test_loss': 0.07347884774208069, 'test_micro_f1': 0.802}
# {'train_loss': 0.00039709112024866045, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07425547391176224, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.0735383927822113, 'test_micro_f1': 0.802}
# {'train_loss': 0.00038857461186125875, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07428429275751114, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07360059767961502, 'test_micro_f1': 0.803}
# {'train_loss': 0.00038017210317775607, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07434038072824478, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07368677854537964, 'test_micro_f1': 0.803}
# {'train_loss': 0.000372482551028952, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07437068223953247, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07374827563762665, 'test_micro_f1': 0.803}
# {'train_loss': 0.00036497454857453704, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07441136986017227, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07382159680128098, 'test_micro_f1': 0.804}
# {'train_loss': 0.0003578709438443184, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07445429265499115, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.0738954246044159, 'test_micro_f1': 0.804}
# {'train_loss': 0.0003510905080474913, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07449805736541748, 'val_micro_f1': 0.782, 'test_loss': 0.07396889477968216, 'test_micro_f1': 0.803}
# {'train_loss': 0.0003445645561441779, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07454707473516464, 'val_micro_f1': 0.782, 'test_loss': 0.07404665648937225, 'test_micro_f1': 0.803}
# {'train_loss': 0.0003382981230970472, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07459893077611923, 'val_micro_f1': 0.782, 'test_loss': 0.07412693649530411, 'test_micro_f1': 0.804}
# {'train_loss': 0.0003322823322378099, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07465353608131409, 'val_micro_f1': 0.782, 'test_loss': 0.0742088034749031, 'test_micro_f1': 0.804}
# {'train_loss': 0.00032648854539729655, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07471141219139099, 'val_micro_f1': 0.782, 'test_loss': 0.07429325580596924, 'test_micro_f1': 0.804}
# {'train_loss': 0.00032090418972074986, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07477229833602905, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07438016682863235, 'test_micro_f1': 0.804}
# {'train_loss': 0.0003155150916427374, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07483628392219543, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.0744694247841835, 'test_micro_f1': 0.803}
# {'train_loss': 0.00031030780519358814, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07490330189466476, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07456106692552567, 'test_micro_f1': 0.803}
# {'train_loss': 0.0003052672545891255, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07497341930866241, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.0746552124619484, 'test_micro_f1': 0.803}
# {'train_loss': 0.00030038016848266125, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07504691183567047, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.0747520700097084, 'test_micro_f1': 0.802}
# {'train_loss': 0.00029563356656581163, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07512382417917252, 'val_micro_f1': 0.782, 'test_loss': 0.07485172897577286, 'test_micro_f1': 0.803}
# {'train_loss': 0.0002910197072196752, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07520412653684616, 'val_micro_f1': 0.782, 'test_loss': 0.07495422661304474, 'test_micro_f1': 0.803}
# {'train_loss': 0.0002865381247829646, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07528741657733917, 'val_micro_f1': 0.782, 'test_loss': 0.07505916804075241, 'test_micro_f1': 0.803}
# {'train_loss': 0.00028219303931109607, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07537305355072021, 'val_micro_f1': 0.782, 'test_loss': 0.07516597211360931, 'test_micro_f1': 0.803}
# {'train_loss': 0.0007534571923315525, 'train_micro_f1': 0.9222769567597153, 'val_loss': 0.07911472022533417, 'val_micro_f1': 0.776, 'test_loss': 0.07890573143959045, 'test_micro_f1': 0.803}
# {'train_loss': 0.0004880741471424699, 'train_micro_f1': 0.9189928845101258, 'val_loss': 0.07780717313289642, 'val_micro_f1': 0.778, 'test_loss': 0.07757798582315445, 'test_micro_f1': 0.805}
# {'train_loss': 0.00033887694007717073, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07771168649196625, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.0774642825126648, 'test_micro_f1': 0.804}
# {'train_loss': 0.00027023343136534095, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07798925787210464, 'val_micro_f1': 0.786, 'test_loss': 0.07755757868289948, 'test_micro_f1': 0.806}
# {'train_loss': 0.00024045640020631254, 'train_micro_f1': 0.9200875752599891, 'val_loss': 0.07771585881710052, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07727812975645065, 'test_micro_f1': 0.806}
# {'train_loss': 0.0004268398624844849, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08018305152654648, 'val_micro_f1': 0.776, 'test_loss': 0.08009342849254608, 'test_micro_f1': 0.804}
# {'train_loss': 0.0002973729860968888, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08017884194850922, 'val_micro_f1': 0.778, 'test_loss': 0.0799282044172287, 'test_micro_f1': 0.802}
# {'train_loss': 0.0007312968373298645, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.0828823670744896, 'val_micro_f1': 0.782, 'test_loss': 0.08266360312700272, 'test_micro_f1': 0.8000000000000002}
# {'train_loss': 0.0002865879505407065, 'train_micro_f1': 0.9195402298850575, 'val_loss': 0.08041266351938248, 'val_micro_f1': 0.778, 'test_loss': 0.08009954541921616, 'test_micro_f1': 0.803}
# {'train_loss': 0.0002259717439301312, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.08027531206607819, 'val_micro_f1': 0.778, 'test_loss': 0.08000506460666656, 'test_micro_f1': 0.804}
# {'train_loss': 0.00020805872918572277, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.08052726089954376, 'val_micro_f1': 0.78, 'test_loss': 0.08021992444992065, 'test_micro_f1': 0.805}
# {'train_loss': 0.00019611805328167975, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08059515058994293, 'val_micro_f1': 0.78, 'test_loss': 0.08024369925260544, 'test_micro_f1': 0.806}
# {'train_loss': 0.00026632711524143815, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.08098018169403076, 'val_micro_f1': 0.782, 'test_loss': 0.08071638643741608, 'test_micro_f1': 0.805}
# {'train_loss': 0.0002505432930774987, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07857944816350937, 'val_micro_f1': 0.786, 'test_loss': 0.07793913781642914, 'test_micro_f1': 0.804}
# {'train_loss': 0.00019332703959662467, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07887352257966995, 'val_micro_f1': 0.7840000000000001, 'test_loss': 0.07833050936460495, 'test_micro_f1': 0.805}
# {'train_loss': 0.00016773240349721164, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.07878725230693817, 'val_micro_f1': 0.782, 'test_loss': 0.0780298188328743, 'test_micro_f1': 0.805}
# {'train_loss': 0.00016131637676153332, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07864753156900406, 'val_micro_f1': 0.782, 'test_loss': 0.07787417620420456, 'test_micro_f1': 0.805}
# {'train_loss': 0.00019614277698565274, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.07891705632209778, 'val_micro_f1': 0.782, 'test_loss': 0.0781254693865776, 'test_micro_f1': 0.805}
# {'train_loss': 0.0001792520342860371, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.07916132360696793, 'val_micro_f1': 0.782, 'test_loss': 0.07820063084363937, 'test_micro_f1': 0.805}
# {'train_loss': 0.00015736390196252614, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.07916346937417984, 'val_micro_f1': 0.782, 'test_loss': 0.07830681651830673, 'test_micro_f1': 0.806}
# {'train_loss': 0.000147467537317425, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.07923110574483871, 'val_micro_f1': 0.782, 'test_loss': 0.07835453003644943, 'test_micro_f1': 0.806}
# {'train_loss': 0.0001438516628695652, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.07923751324415207, 'val_micro_f1': 0.782, 'test_loss': 0.07832396030426025, 'test_micro_f1': 0.806}
# {'train_loss': 0.0001410691038472578, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0793398916721344, 'val_micro_f1': 0.782, 'test_loss': 0.07842729240655899, 'test_micro_f1': 0.806}
# {'train_loss': 0.00013887892419006675, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.07944925129413605, 'val_micro_f1': 0.782, 'test_loss': 0.07854102551937103, 'test_micro_f1': 0.806}
# {'train_loss': 0.00013714715896639973, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.07954210042953491, 'val_micro_f1': 0.782, 'test_loss': 0.0786205530166626, 'test_micro_f1': 0.806}
# {'train_loss': 0.00013555606710724533, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.07962801307439804, 'val_micro_f1': 0.782, 'test_loss': 0.07870419323444366, 'test_micro_f1': 0.806}
# {'train_loss': 0.00013396302529145032, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0797387883067131, 'val_micro_f1': 0.782, 'test_loss': 0.07881258428096771, 'test_micro_f1': 0.806}
# {'train_loss': 0.00013244265574030578, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.07985759526491165, 'val_micro_f1': 0.782, 'test_loss': 0.0789291113615036, 'test_micro_f1': 0.806}
# {'train_loss': 0.00013095953909214586, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.07996910810470581, 'val_micro_f1': 0.782, 'test_loss': 0.07903949916362762, 'test_micro_f1': 0.806}
# {'train_loss': 0.00012951037206221372, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08007986098527908, 'val_micro_f1': 0.782, 'test_loss': 0.07915012538433075, 'test_micro_f1': 0.806}
# {'train_loss': 0.00012810560292564332, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08018818497657776, 'val_micro_f1': 0.782, 'test_loss': 0.0792580395936966, 'test_micro_f1': 0.806}
# {'train_loss': 0.0001267277548322454, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08029798418283463, 'val_micro_f1': 0.782, 'test_loss': 0.07936747372150421, 'test_micro_f1': 0.806}
# {'train_loss': 0.00012534954294096678, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0804390013217926, 'val_micro_f1': 0.782, 'test_loss': 0.07950733602046967, 'test_micro_f1': 0.806}
# {'train_loss': 0.0001241313584614545, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08050890266895294, 'val_micro_f1': 0.782, 'test_loss': 0.07957472652196884, 'test_micro_f1': 0.806}
# {'train_loss': 0.00012281739327590913, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08062834292650223, 'val_micro_f1': 0.782, 'test_loss': 0.07969530671834946, 'test_micro_f1': 0.806}
# {'train_loss': 0.00012154504656791687, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08074339479207993, 'val_micro_f1': 0.782, 'test_loss': 0.07980778068304062, 'test_micro_f1': 0.806}
# {'train_loss': 0.00012030127982143313, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08086105436086655, 'val_micro_f1': 0.782, 'test_loss': 0.07992289960384369, 'test_micro_f1': 0.805}
# {'train_loss': 0.00011908717715414241, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08097877353429794, 'val_micro_f1': 0.782, 'test_loss': 0.08003900200128555, 'test_micro_f1': 0.806}
# {'train_loss': 0.0001179174505523406, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0810927227139473, 'val_micro_f1': 0.782, 'test_loss': 0.08015074580907822, 'test_micro_f1': 0.806}
# {'train_loss': 0.00011668509978335351, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08123909682035446, 'val_micro_f1': 0.782, 'test_loss': 0.08029641211032867, 'test_micro_f1': 0.805}
# {'train_loss': 0.00011559906124603003, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08133444935083389, 'val_micro_f1': 0.782, 'test_loss': 0.08038599044084549, 'test_micro_f1': 0.805}
# {'train_loss': 0.00011449078738223761, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0814502015709877, 'val_micro_f1': 0.782, 'test_loss': 0.0805014967918396, 'test_micro_f1': 0.805}
# {'train_loss': 0.00011343158985255286, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08156335353851318, 'val_micro_f1': 0.782, 'test_loss': 0.0806112289428711, 'test_micro_f1': 0.805}
# {'train_loss': 0.00011233746772632003, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08168947696685791, 'val_micro_f1': 0.78, 'test_loss': 0.08073493838310242, 'test_micro_f1': 0.805}
# {'train_loss': 0.00011126516619697213, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0818154588341713, 'val_micro_f1': 0.78, 'test_loss': 0.0808577612042427, 'test_micro_f1': 0.805}
# {'train_loss': 0.0001102234746213071, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0819399505853653, 'val_micro_f1': 0.78, 'test_loss': 0.08097954839468002, 'test_micro_f1': 0.805}
# {'train_loss': 0.00010921085049631074, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08206196129322052, 'val_micro_f1': 0.78, 'test_loss': 0.08109921216964722, 'test_micro_f1': 0.805}
# {'train_loss': 0.00010820960596902296, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08218474686145782, 'val_micro_f1': 0.78, 'test_loss': 0.08121984452009201, 'test_micro_f1': 0.804}
# {'train_loss': 0.00010722814477048814, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08230672776699066, 'val_micro_f1': 0.78, 'test_loss': 0.08133973926305771, 'test_micro_f1': 0.803}
# {'train_loss': 0.00010626525909174234, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08242815732955933, 'val_micro_f1': 0.78, 'test_loss': 0.08145920932292938, 'test_micro_f1': 0.803}
# {'train_loss': 0.00010531848238315433, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0825495570898056, 'val_micro_f1': 0.78, 'test_loss': 0.08157844841480255, 'test_micro_f1': 0.803}
# {'train_loss': 0.00010438828758196905, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08267077058553696, 'val_micro_f1': 0.778, 'test_loss': 0.08169747143983841, 'test_micro_f1': 0.803}
# {'train_loss': 0.00010347494389861822, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08279157429933548, 'val_micro_f1': 0.778, 'test_loss': 0.08181604743003845, 'test_micro_f1': 0.803}
# {'train_loss': 0.00010257697431370616, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0829121544957161, 'val_micro_f1': 0.778, 'test_loss': 0.08193432539701462, 'test_micro_f1': 0.803}
# {'train_loss': 0.00010169462620979175, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08303229510784149, 'val_micro_f1': 0.778, 'test_loss': 0.08205217123031616, 'test_micro_f1': 0.802}
# {'train_loss': 0.0001008272884064354, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08315210044384003, 'val_micro_f1': 0.78, 'test_loss': 0.08216962963342667, 'test_micro_f1': 0.802}
# {'train_loss': 9.997451707022265e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08327149599790573, 'val_micro_f1': 0.78, 'test_loss': 0.08228666335344315, 'test_micro_f1': 0.802}
# {'train_loss': 9.913586836773902e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08339054137468338, 'val_micro_f1': 0.78, 'test_loss': 0.08240323513746262, 'test_micro_f1': 0.802}
# {'train_loss': 9.831101488089189e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08350915461778641, 'val_micro_f1': 0.78, 'test_loss': 0.08251935243606567, 'test_micro_f1': 0.802}
# {'train_loss': 9.749956370797008e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08362731337547302, 'val_micro_f1': 0.78, 'test_loss': 0.08263497054576874, 'test_micro_f1': 0.802}
# {'train_loss': 9.785486327018589e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08385656028985977, 'val_micro_f1': 0.78, 'test_loss': 0.08285745233297348, 'test_micro_f1': 0.802}
# {'train_loss': 9.612848953111097e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0838737040758133, 'val_micro_f1': 0.78, 'test_loss': 0.08287279307842255, 'test_micro_f1': 0.802}
# {'train_loss': 9.54106799326837e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08395183086395264, 'val_micro_f1': 0.78, 'test_loss': 0.08294816315174103, 'test_micro_f1': 0.802}
# {'train_loss': 9.45146894082427e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08407900482416153, 'val_micro_f1': 0.78, 'test_loss': 0.08307446539402008, 'test_micro_f1': 0.802}
# {'train_loss': 9.371549094794318e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08419173955917358, 'val_micro_f1': 0.78, 'test_loss': 0.0831858292222023, 'test_micro_f1': 0.802}
# {'train_loss': 9.295365452999249e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08430720865726471, 'val_micro_f1': 0.78, 'test_loss': 0.08329694718122482, 'test_micro_f1': 0.802}
# {'train_loss': 9.22104372875765e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08442343771457672, 'val_micro_f1': 0.78, 'test_loss': 0.0834105983376503, 'test_micro_f1': 0.802}
# {'train_loss': 9.149574907496572e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08453544229269028, 'val_micro_f1': 0.78, 'test_loss': 0.08351939916610718, 'test_micro_f1': 0.802}
# {'train_loss': 9.079232404474169e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08464790135622025, 'val_micro_f1': 0.78, 'test_loss': 0.08362836390733719, 'test_micro_f1': 0.802}
# {'train_loss': 9.009626955958083e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08476049453020096, 'val_micro_f1': 0.78, 'test_loss': 0.08373809605836868, 'test_micro_f1': 0.802}
# {'train_loss': 8.941179839894176e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08487192541360855, 'val_micro_f1': 0.78, 'test_loss': 0.0838465765118599, 'test_micro_f1': 0.802}
# {'train_loss': 8.873684419086203e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08498301357030869, 'val_micro_f1': 0.78, 'test_loss': 0.0839543417096138, 'test_micro_f1': 0.802}
# {'train_loss': 8.807058475213125e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0850936770439148, 'val_micro_f1': 0.78, 'test_loss': 0.08406178653240204, 'test_micro_f1': 0.802}
# {'train_loss': 8.741390774957836e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08520367741584778, 'val_micro_f1': 0.778, 'test_loss': 0.08416850119829178, 'test_micro_f1': 0.802}
# {'train_loss': 8.676616562297568e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08531304448843002, 'val_micro_f1': 0.778, 'test_loss': 0.08427450805902481, 'test_micro_f1': 0.802}
# {'train_loss': 8.612728561274707e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08542179316282272, 'val_micro_f1': 0.78, 'test_loss': 0.08437985926866531, 'test_micro_f1': 0.802}
# {'train_loss': 8.549706399207935e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08552991598844528, 'val_micro_f1': 0.78, 'test_loss': 0.0844845250248909, 'test_micro_f1': 0.802}
# {'train_loss': 8.487523155054078e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08563738316297531, 'val_micro_f1': 0.78, 'test_loss': 0.08458846062421799, 'test_micro_f1': 0.802}
# {'train_loss': 8.426166459685192e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08574417978525162, 'val_micro_f1': 0.78, 'test_loss': 0.08469164371490479, 'test_micro_f1': 0.802}
# {'train_loss': 8.365621033590287e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08585026115179062, 'val_micro_f1': 0.78, 'test_loss': 0.08479408919811249, 'test_micro_f1': 0.802}
# {'train_loss': 8.305862866109237e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08595563471317291, 'val_micro_f1': 0.78, 'test_loss': 0.0848957747220993, 'test_micro_f1': 0.802}
# {'train_loss': 8.24689632281661e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08606034517288208, 'val_micro_f1': 0.78, 'test_loss': 0.08499670028686523, 'test_micro_f1': 0.802}
# {'train_loss': 8.188678475562483e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08616429567337036, 'val_micro_f1': 0.78, 'test_loss': 0.08509685099124908, 'test_micro_f1': 0.802}
# {'train_loss': 8.131214417517185e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08626753091812134, 'val_micro_f1': 0.78, 'test_loss': 0.08519618958234787, 'test_micro_f1': 0.801}
# {'train_loss': 8.074472134467214e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08636998385190964, 'val_micro_f1': 0.78, 'test_loss': 0.08529473096132278, 'test_micro_f1': 0.801}
# {'train_loss': 8.018444350454956e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08647172152996063, 'val_micro_f1': 0.78, 'test_loss': 0.08539244532585144, 'test_micro_f1': 0.801}
# {'train_loss': 7.963121606735513e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08657258749008179, 'val_micro_f1': 0.78, 'test_loss': 0.08548929542303085, 'test_micro_f1': 0.801}
# {'train_loss': 7.918569463072345e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08667009323835373, 'val_micro_f1': 0.78, 'test_loss': 0.08558326214551926, 'test_micro_f1': 0.801}
# {'train_loss': 0.0005062894779257476, 'train_micro_f1': 0.9195402298850575, 'val_loss': 0.08699243515729904, 'val_micro_f1': 0.778, 'test_loss': 0.08594918996095657, 'test_micro_f1': 0.802}
# {'train_loss': 0.00018240044300910085, 'train_micro_f1': 0.9206349206349206, 'val_loss': 0.08667844533920288, 'val_micro_f1': 0.778, 'test_loss': 0.08558763563632965, 'test_micro_f1': 0.801}
# {'train_loss': 8.829380385577679e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08667143434286118, 'val_micro_f1': 0.782, 'test_loss': 0.08561288565397263, 'test_micro_f1': 0.801}
# {'train_loss': 8.351451106136665e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0867958813905716, 'val_micro_f1': 0.78, 'test_loss': 0.0857158675789833, 'test_micro_f1': 0.801}
# {'train_loss': 7.969060243340209e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08686608076095581, 'val_micro_f1': 0.778, 'test_loss': 0.08579091727733612, 'test_micro_f1': 0.801}
# {'train_loss': 7.847838423913345e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0869896411895752, 'val_micro_f1': 0.78, 'test_loss': 0.08591457456350327, 'test_micro_f1': 0.801}
# {'train_loss': 7.775118865538388e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0870775654911995, 'val_micro_f1': 0.778, 'test_loss': 0.08600074052810669, 'test_micro_f1': 0.801}
# {'train_loss': 7.664833538001403e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08720692247152328, 'val_micro_f1': 0.778, 'test_loss': 0.08612367510795593, 'test_micro_f1': 0.801}
# {'train_loss': 7.525998807977885e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08730171620845795, 'val_micro_f1': 0.778, 'test_loss': 0.086219921708107, 'test_micro_f1': 0.801}
# {'train_loss': 7.438933971570805e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0874137282371521, 'val_micro_f1': 0.778, 'test_loss': 0.08632635325193405, 'test_micro_f1': 0.801}
# {'train_loss': 7.396602450171486e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08751998841762543, 'val_micro_f1': 0.778, 'test_loss': 0.08642725646495819, 'test_micro_f1': 0.801}
# {'train_loss': 7.346199708990753e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08762066811323166, 'val_micro_f1': 0.778, 'test_loss': 0.08652407675981522, 'test_micro_f1': 0.801}
# {'train_loss': 7.299908611457795e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08772263675928116, 'val_micro_f1': 0.778, 'test_loss': 0.08662138879299164, 'test_micro_f1': 0.801}
# {'train_loss': 7.253797957673669e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08782363682985306, 'val_micro_f1': 0.78, 'test_loss': 0.08671770989894867, 'test_micro_f1': 0.801}
# {'train_loss': 7.208776514744386e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08792278170585632, 'val_micro_f1': 0.78, 'test_loss': 0.08681221306324005, 'test_micro_f1': 0.802}
# {'train_loss': 7.164070848375559e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0880202129483223, 'val_micro_f1': 0.78, 'test_loss': 0.08690496534109116, 'test_micro_f1': 0.802}
# {'train_loss': 7.11986212991178e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08811619877815247, 'val_micro_f1': 0.78, 'test_loss': 0.08699631690979004, 'test_micro_f1': 0.803}
# {'train_loss': 7.076129986671731e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08821097016334534, 'val_micro_f1': 0.782, 'test_loss': 0.08708634227514267, 'test_micro_f1': 0.803}
# {'train_loss': 7.03284313203767e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08830439299345016, 'val_micro_f1': 0.782, 'test_loss': 0.08717507869005203, 'test_micro_f1': 0.803}
# {'train_loss': 6.989992107264698e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08839655667543411, 'val_micro_f1': 0.782, 'test_loss': 0.08726251870393753, 'test_micro_f1': 0.803}
# {'train_loss': 6.947570363990963e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08848752081394196, 'val_micro_f1': 0.782, 'test_loss': 0.08734868466854095, 'test_micro_f1': 0.803}
# {'train_loss': 6.905599002493545e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08857715874910355, 'val_micro_f1': 0.782, 'test_loss': 0.08743349462747574, 'test_micro_f1': 0.803}
# {'train_loss': 6.873933307360858e-05, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.0886644497513771, 'val_micro_f1': 0.782, 'test_loss': 0.08751394599676132, 'test_micro_f1': 0.803}
# {'train_loss': 0.00016337014676537365, 'train_micro_f1': 0.9211822660098522, 'val_loss': 0.08879682421684265, 'val_micro_f1': 0.78, 'test_loss': 0.08757801353931427, 'test_micro_f1': 0.801}
