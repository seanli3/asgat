# %% [markdown]
# Import dependencies

# %%
from model.layers import GraphSpectralFilterLayer, AnalysisFilter
from model.spectral_filter import Graph
import torch
import torch.nn.functional as F
from torch import nn
from random import seed as rseed
from numpy.random import seed as nseed
from citation import get_dataset, random_planetoid_splits, run
from citation.train_eval import evaluate
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-0a5355ef1a27> in <module>
#       6 from random import seed as rseed
#       7 from numpy.random import seed as nseed
# ----> 8 from citation import get_dataset, random_planetoid_splits, run
#       9 from citation.train_eval import evaluate
#      10 import numpy as np
#
# ImportError: cannot import name 'get_dataset' from 'citation' (c:\users\sohey_m6zyufm\pycharmprojects\decimation_branch_mark\venv\lib\site-packages\torch_geometric_benchmark-0.1.0-py3.7.egg\citation\__init__.py)

# %% [markdown]
# Define hyperparameters

# %%
dataset_name = 'PubMed'

random_splits = False
runs = 1
epochs =400
alpha = 0.7709619178612326
seed =729
lr =0.00022455151763075903
weight_decay = 7.530100210192558e-05
patience=100
hidden=88
heads =12
dropout=0.6174883141474811
normalize_features =True
pre_training = False
cuda = False
chebyshev_order =15
edge_dropout =0
node_feature_dropout =0
filter_name ='analysis'

rseed(seed)
nseed(seed)
torch.manual_seed(seed)

cuda = cuda and torch.cuda.is_available()

if cuda:
    torch.cuda.manual_seed(seed)
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
    
def get_correctly_predicted_node_idx(net, key, dataset):
    net.eval()
    with torch.no_grad():
        logits  = net(dataset[0])[0]
    mask = dataset[0]['{}_mask'.format(key)]
    pred = logits[mask].max(1)[1]
    return { *pred.eq(dataset[0].y[mask]).nonzero().view(-1).tolist() }

# %%
def matching_labels_distribution(nodes_set, G, dataset):
    hop_1_matching_percent = []
    hop_2_matching_percent = []
    hop_3_matching_percent = []
    for n in nodes_set:
        hop_1_neighbours = list(nx.ego_graph(G, n, 1).nodes())
        hop_2_neighbours = list(nx.ego_graph(G, n, 2).nodes())
        hop_3_neighbours = list(nx.ego_graph(G, n, 3).nodes())
        hop_1_neighbours.remove(n)
        hop_2_neighbours.remove(n)
        hop_3_neighbours.remove(n)
        node_label = dataset[0].y[n]
        hop_1_labels = dataset[0].y[hop_1_neighbours]
        hop_2_labels = dataset[0].y[hop_2_neighbours]
        hop_3_labels = dataset[0].y[hop_3_neighbours]
        matching_1_labels = node_label == hop_1_labels
        matching_2_labels = node_label == hop_2_labels
        matching_3_labels = node_label == hop_3_labels

        hop_1_matching_percent.append(matching_1_labels.float().sum()/max(matching_1_labels.shape[0], 1))
        hop_2_matching_percent.append(matching_2_labels.float().sum()/max(matching_2_labels.shape[0], 1))
        hop_3_matching_percent.append(matching_3_labels.float().sum()/max(matching_3_labels.shape[0], 1))


    print(torch.tensor(hop_1_matching_percent).mean())
    print('matching labels in 1st hop:', torch.tensor(hop_1_matching_percent).mean())
    print('matching labels in 2st hop:', torch.tensor(hop_2_matching_percent).mean())
    print('matching labels in 3rd hop:', torch.tensor(hop_3_matching_percent).mean())
    plt.figure(figsize=(15,3))
    plt.subplot(1, 3, 1)
    plt.hist(hop_1_matching_percent, color = 'blue', edgecolor = 'black', bins = 10)
    plt.subplot(1, 3, 2)
    plt.hist(hop_2_matching_percent, color = 'blue', edgecolor = 'black', bins = 10)
    plt.subplot(1, 3, 3)
    plt.hist(hop_2_matching_percent, color = 'blue', edgecolor = 'black', bins = 10)
    return hop_1_matching_percent, hop_2_matching_percent, hop_3_matching_percent

# %% [markdown]
# Define model

# %%
class Net(torch.nn.Module):
    def __init__(self, dataset):
        super(Net, self).__init__()
        data = dataset[0]
        adj = torch.sparse_coo_tensor(data.edge_index, torch.ones(data.num_edges))
        self.G = Graph(adj)
        self.G.estimate_lmax()

        self.analysis = GraphSpectralFilterLayer(self.G, dataset.num_node_features, hidden,
                                                 dropout=dropout, out_channels=heads, filter=filter_name,
                                                 pre_training=pre_training, device='cuda' if cuda else 'cpu',
                                                 alpha=alpha, chebyshev_order=chebyshev_order)
        # self.mlp = nn.Sequential(nn.Linear(hidden * heads, 128),
        #                             nn.ReLU(inplace=True),
        #                             nn.Linear(128, 64),
        #                             nn.ReLU(inplace=True),
        #                             nn.Linear(64, 32),
        #                             nn.ReLU(inplace=True),
        #                             nn.Linear(32, dataset.num_classes),
        #                             nn.ReLU(inplace=True))

        # self.W = torch.zeros(hidden * heads, dataset.num_classes)

        self.synthesis = GraphSpectralFilterLayer(self.G, hidden * heads, dataset.num_classes, filter=filter_name,
                                                  device='cuda' if cuda else 'cpu', dropout=dropout,
                                                  out_channels=1, alpha=alpha, pre_training=False,
                                                  chebyshev_order=chebyshev_order)

    def reset_parameters(self):
        self.analysis.reset_parameters()
        # torch.nn.init.xavier_uniform_(self.W.data, gain=1.414)
        # for layer in self.mlp:
        #     if hasattr(layer, 'reset_parameters'):
        #         layer.reset_parameters()
        self.synthesis.reset_parameters()

    def forward(self, data):
        x = data.x
        x = F.dropout(x, p=dropout, training=self.training)
        x, att1 = self.analysis(x)
        x = F.dropout(x, p=dropout, training=self.training)
        x, att2 = self.synthesis(x)
        x = F.elu(x)
        # x = F.elu(x.mm(self.W))
        # x = self.mlp(x)
        return F.log_softmax(x, dim=1), att1, att2


dataset = get_dataset(dataset_name, normalize_features, edge_dropout=edge_dropout,
                                node_feature_dropout=node_feature_dropout)

if cuda:
    dataset[0].to('cuda')

# permute_masks = random_planetoid_splits if random_splits else None
# run(dataset, Net(dataset), runs, epochs, lr, weight_decay,
#     early_stopping, permute_masks)

# %%
class SingleNet(torch.nn.Module):
    def __init__(self, dataset):
        super(SingleNet, self).__init__()
        data = dataset[0]
        adj = torch.sparse_coo_tensor(data.edge_index, torch.ones(data.num_edges))
        self.G = Graph(adj)
        self.G.estimate_lmax()

        self.analysis = GraphSpectralFilterLayer(self.G, dataset.num_node_features, hidden,
                                                 dropout=dropout, out_channels=heads, filter=filter_name,
                                                 pre_training=pre_training, device='cuda' if cuda else 'cpu',
                                                 alpha=alpha, chebyshev_order=chebyshev_order)

        self.W = torch.nn.Parameter(torch.zeros(hidden * heads, dataset.num_classes))

    def reset_parameters(self):
        self.analysis.reset_parameters()
        torch.nn.init.xavier_uniform_(self.W.data, gain=1.414)

    def forward(self, data):
        x = data.x
        x = F.dropout(x, p=dropout, training=self.training)
        x, attentions_1 = self.analysis(x)
        x = F.dropout(x, p=dropout, training=self.training)
        x = F.elu(x.mm(self.W))
        return F.log_softmax(x, dim=1), attentions_1, None

# %% [markdown]
# Load trained model and evaluate

# %%
model = Net(dataset)
model.load_state_dict(torch.load('./model/best_{}_gpu.pkl'.format(dataset_name),  map_location={'cuda:0': 'cpu'}))

# model = SingleNet(dataset)
# model.load_state_dict(torch.load('./model/best_{}_single_layer.pkl'.format(dataset_name)))

filter_kernel = model.analysis.filter_kernel

# model_correct_indices = get_correctly_predicted_node_idx(model, 'test', dataset)
eval_info = evaluate(model, dataset[0])
print(eval_info)
# Out:
# {'train_loss': 0.25815349817276, 'train_acc': 0.9092056869956634, 'train_micro_f1': 0.9092056869956634, 'train_macro_f1': 0.9060534433900731, 'val_loss': 0.2487691193819046, 'val_acc': 0.916, 'val_micro_f1': 0.916, 'val_macro_f1': 0.9116419796876049, 'test_loss': 0.27245965600013733, 'test_acc': 0.903, 'test_micro_f1': 0.903, 'test_macro_f1': 0.8965550190064704}

# %% [markdown]
# Obtain attention weights in layer 1 and 2

# %%
with torch.no_grad():
    _, att1, att2 = model(dataset[0])
model_att1_sum = torch.stack(att1).sum(dim=0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-4b753baa17db> in <module>
#       1 with torch.no_grad():
#       2     _, att1, att2 = model(dataset[0])
# ----> 3 model_att1_sum = torch.stack(att1).sum(dim=0)
#
# RuntimeError: [enforce fail at ..\c10\core\CPUAllocator.cpp:72] data. DefaultCPUAllocator: not enough memory: you tried to allocate 18660484272 bytes. Buy new RAM!

# %%
for i in range(heads):
    print(att1[i][(att1[i].bool().float() - torch.eye(att1[i].shape[0], att1[i].shape[1])).nonzero(as_tuple=True)].mean())

# %% [markdown]
# Build NetworkX Graph

# %%
import networkx as nx
from scipy.sparse import coo_matrix
import numpy as np

# Build graph
adj = coo_matrix(
    (np.ones(dataset[0].num_edges),
    (dataset[0].edge_index[0].numpy(), dataset[0].edge_index[1].numpy())),
    shape=(dataset[0].num_nodes, dataset[0].num_nodes))
G = nx.Graph(adj)

# %%
from matplotlib import pyplot as plt
def plot_filter_banks(idx=list(range(heads)), kernel=model.analysis.filter._kernel, ax=None, no_ticks=False, legend=True):
    x = torch.linspace(0, 2, 100)
    if no_ticks:
        plt.xticks([])
        plt.yticks([])
    if not ax:
        plt.figure()
        plt.plot(x, kernel(x).detach()[:, idx])
#         if len(idx) > 1 and legend:
#             plt.legend(['filter {}'.format(i) for i in range(1, len(idx) + 1)])
        plt.show()
    else:
        ax.plot(x, kernel(x).detach()[:, idx])
#         if len(idx) > 1 and legend:
#             ax.legend(['filter {}'.format(i) for i in range(1, len(idx) + 1)])

# %% [markdown]
# Plot filterbanks in layer 1 and 2

# %%
plt.figure(figsize=(15,10), dpi=450)
ax1 = plt.subplot(2, 2, 1)
ax1.set_title('layer 1 fitlerbanks')
plot_filter_banks(kernel=model.analysis.filter._kernel, ax=ax1)
ax2 = plt.subplot(2, 2, 2)
ax2.set_title('chebyshev approx. layer 1 fitlerbanks')
plot_filter_banks(kernel=model.analysis.filter.cheby_eval, ax=ax2)

if hasattr(model, 'synthesis'):
    ax3 = plt.subplot(2, 2, 3)
    ax3.set_title('layer 2 fitlerbank')
    plot_filter_banks(idx=[0], kernel=model.synthesis.filter._kernel, ax=ax3, legend=False)
    ax4 = plt.subplot(2, 2, 4)
    ax4.set_title('chebyshev approx. layer 2 fitlerbank')
    plot_filter_banks(idx=[0], kernel=model.synthesis.filter.cheby_eval, ax=ax4, legend=False)

# %%
node = 269
# node = model_not_gat_correct_nodes[1].item()
Gego = nx.ego_graph(G, node, 2)
nodePos = nx.layout.kamada_kawai_layout(Gego)

node_colors = {
   0: plt.cm.Reds, 1: plt.cm.Oranges, 2: plt.cm.RdPu, 
   3: plt.cm.Greens, 4: plt.cm.Greys, 5: plt.cm.Purples, 
}
node_shapes={0: '8', 1: 'o', 2: 'd', 3: '^', 4: 's', 5: '*'}



plt.figure(figsize=(15,15), dpi=450);
# plt.figure(figsize=(15,15));

ax = plt.subplot(3, 2, 1)
                 

for n in Gego.nodes:
    nx.draw_networkx_nodes(Gego, nodePos,
                           nodelist=[n],
                           node_color=[node_colors[dataset[0].y[n].item()](0.8)],
                           node_shape=node_shapes[dataset[0].y[n].item()],
                           node_size=350 if n == node else 150,
                           ax=ax)
nx.draw_networkx_edges(Gego, nodePos,
#                            edgelist=[*[(node, n) for n in nodes], ],
                           edgelist= Gego.edges,
#                            width=[5 if e in edges else 2 for e in Gego.edges],
                           width=6,
#                            edge_color=[plt.cm.Greys(0.8) if e in edges else plt.cm.Greys(0.2) for e in Gego.edges],
                           edge_color=plt.cm.Greys(0.2),
                           ax=ax)

# for j in G.nodes:
#     a = None
#     for i in range(len(att1)):
#     #     plt.figure(figsize=(15,5), dpi=450)
# #         plt.figure(figsize=(15,5));

#         att = att1[i]
#         if a is None and len((att[j] > 0.001).nonzero().view(-1).tolist()) != 1:
#             a = len((att[j] > 0.0001).nonzero().view(-1).tolist())
#         else:
#             if a is not None and np.abs(a - len((att[j] > 0.001).nonzero().view(-1).tolist())) > 3 and len((att[j] > 0.001).nonzero().view(-1).tolist()) != 1:
#                 if nx.single_source_shortest_path_length(G, j) > 1:
#                     print(j)
#                     print(i, a, len((att[j] > 0.001).nonzero().view(-1).tolist()))

# %%
node=269
# # node=4
# # node = model_not_gat_correct_nodes[1].item()
Gego = nx.ego_graph(G, node, 2)
nodePos = nx.layout.kamada_kawai_layout(Gego)
node_colors = {
   0: plt.cm.Reds, 1: plt.cm.Oranges, 2: plt.cm.RdPu, 
   3: plt.cm.Greens, 4: plt.cm.Greys, 5: plt.cm.Purples, 
}
node_shapes={0: '8', 1: 'o', 2: 'd', 3: '^', 4: 's', 5: '*'}



# for n in Gego.nodes:
#     nx.draw_networkx_nodes(Gego, nodePos,
#                            nodelist=[n],
#                            node_color=[node_colors[dataset[0].y[n].item()](0.8)],
#                            node_shape="*" if n == node else node_shapes[dataset[0].y[n].item()],
#                            node_size=350 if n == node else 80)
# nx.draw_networkx_edges(Gego,nodePos, width=2, alpha=0.4)
for i in range(heads):
# for i in [0, 2, 3, 10]:
# for i in [3]:
    Gego = nx.ego_graph(G, node, 2)
    att = att1[i]
    nodes = (att[node] > 0.0000).nonzero().view(-1).tolist()
    print(i, len(nodes))
#     plt.figure(figsize=(15,5), dpi=450);
#     ax = plt.subplot(1, 2, 1)
#     plot_filter_banks(idx=[i], ax=ax, no_ticks=True)

    ax = plt.subplot(1, 2, 2)
#     for n in Gego.nodes:
    for n in nodes:
        nx.draw_networkx_nodes(Gego, nodePos,
                               nodelist=[n],
                               ax=ax,
                               node_color=[node_colors[dataset[0].y[n].item()](0.7)],
                               node_shape=node_shapes[dataset[0].y[n].item()],
                               node_size=300 if n == node else 150,
#                                node_size=300 if n == node else (torch.exp(att[node, n])*100).clamp(max=300, min=50),
#                                node_size=300 if n == node else 200
                              )
#     edges = list(filter(lambda e: e[0] in nodes and e[1] in nodes, list(Gego.edges)))
#     nx.draw_networkx_edges(Gego, nodePos,
# #                            edgelist=[*[(node, n) for n in nodes], ],
#                            edgelist= Gego.edges,
# #                            width=[5 if e in edges else 2 for e in Gego.edges],
#                            width=7,
# #                            edge_color=[plt.cm.Greys(0.8) if e in edges else plt.cm.Greys(0.2) for e in Gego.edges],
#                            edge_color=plt.cm.Greys(0.2),
#                            alpha=0.4,
#                            ax=ax)
#     nx.draw_networkx_edges(Gego, nodePos,
#                            edgelist=[*[(n, node) for n in nodes], ],
# #                            edgelist= Gego.edges,
# #                            width=[5 if e in edges else 2 for e in Gego.edges],
#                            width=1.5,
#                            style="dashed",
# #                            edge_color=[plt.cm.Greys(0.8) if e in edges else plt.cm.Greys(0.2) for e in Gego.edges],
# #                            alpha=0.5,
#                            edge_color=plt.cm.Greys(0.4),
#                            arrows=True,
#                            ax=ax)
    Gego = nx.DiGraph(Gego)
    nx.draw_networkx_edges(Gego, nodePos,
                           edgelist=[*[(n, node) for n in nodes], ],
#                            edgelist= Gego.edges,
#                            width=[5 if e in edges else 2 for e in Gego.edges],
                           width=4,
#                            edge_color=[plt.cm.Greys(0.8) if e in edges else plt.cm.Greys(0.2) for e in Gego.edges],
                           alpha=0.3,
                           edge_color=plt.cm.Blues(0.8),
                           connectionstyle='arc3,rad=0.1',
                           arrows=True,
                           ax=ax)
    plt.show();
# Out:
# c:\users\sohey_m6zyufm\pycharmprojects\decimation_branch_mark\venv\lib\site-packages\ipykernel_launcher.py:26: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  ..\torch\csrc\utils\python_arg_parser.cpp:766.)
# 0 20
# 1 20
# 2 20
# 3 22
# 4 20
# 5 22
# 6 22
# 7 22
# 8 20
# 9 20
# 10 20
# 11 22

# %% [markdown]
# ### Frequency cutoff analysis

# %%
# Cut frequency bands abruptly
class CutOff(nn.Module):
    def __init__(self, kernel, min_val = 0, max_val = 2):
        super(CutOff, self).__init__()
        self.min = min_val
        self.max = max_val
        self.kernel = kernel

    def reset_parameters(self):
        pass

    def forward(self, x):
        h = torch.where(x.view(-1,1).repeat(1, heads) < self.min, torch.zeros(x.shape[0], heads), self.kernel(x))
        h = torch.where(x.view(-1,1).repeat(1, heads) > self.max, torch.zeros(x.shape[0], heads), h)
        return h

# %% [markdown]
# Evaluate low pass cutoff

# %%
threshold = 1
model.analysis.filter_kernel = CutOff(max_val=threshold, kernel=filter_kernel)
model.analysis.filter._kernel = CutOff(max_val=threshold, kernel=filter_kernel)
plot_filter_banks(kernel=model.analysis.filter_kernel)
print(evaluate(model, dataset[0]))

low_pass_correct_indices = get_correctly_predicted_node_idx(model, 'test', dataset)
with torch.no_grad():
    _, low_att1, low_att2 = model(dataset[0])
# Out:
# {'train_loss': 0.43900153040885925, 'train_acc': 0.8697318007662835, 'val_loss': 0.6780003309249878, 'val_acc': 0.796, 'test_loss': 0.6835559010505676, 'test_acc': 0.801, 'f1_score': 0.8379921851517884}

# %%
min_threshold = 0.75
max_threshold = 1.25
model.analysis.filter_kernel = CutOff(max_val=max_threshold, min_val=min_threshold, kernel=filter_kernel)
model.analysis.filter._kernel = CutOff(max_val=max_threshold, min_val=min_threshold, kernel=filter_kernel)
plot_filter_banks(kernel=model.analysis.filter_kernel)
print(evaluate(model, dataset[0]))

mid_pass_correct_indices = get_correctly_predicted_node_idx(model, 'test', dataset)
with torch.no_grad():
    _, low_att1, low_att2 = model(dataset[0])
# Out:
# {'train_loss': 0.4115472435951233, 'train_acc': 0.9113300492610837, 'val_loss': 0.7065767645835876, 'val_acc': 0.792, 'test_loss': 0.7032493948936462, 'test_acc': 0.809, 'f1_score': 0.862639014126841}

# %% [markdown]
# Evaluate high pass cutoff

# %%
threshold = 1
model.analysis.filter_kernel = CutOff(min_val=threshold, kernel=filter_kernel)
model.analysis.filter._kernel = CutOff(min_val=threshold, kernel=filter_kernel)
plot_filter_banks(kernel=model.analysis.filter_kernel)
print(evaluate(model, dataset[0]))

high_pass_correct_indices = get_correctly_predicted_node_idx(model, 'test', dataset)

with torch.no_grad():
    _, high_att1, high_att2 = model(dataset[0])
# Out:
# {'train_loss': 0.891304075717926, 'train_acc': 0.8620689655172413, 'val_loss': 1.0047401189804077, 'val_acc': 0.778, 'test_loss': 1.0180137157440186, 'test_acc': 0.795, 'f1_score': 0.8292756236850015}

# %% [markdown]
# Evaluate band pass cutoff

# %%
step = 0.25
acc = []
for threshold in torch.arange(0, 1.76, 0.25):
    model.analysis.filter_kernel = CutOff(min_val=threshold, max_val=threshold+step, kernel=filter_kernel)
    model.analysis.filter._kernel = CutOff(min_val=threshold,max_val=threshold+step, kernel=filter_kernel)
#     plot_filter_banks(kernel=model.analysis.filter_kernel)
#     plot_filter_banks(kernel=model.analysis.filter.cheby_eval)
    eval_info = evaluate(model, dataset[0])
    acc.append(eval_info['test_acc'])
print(acc)
# Out:
# [0.851, 0.846, 0.849, 0.899, 0.904, 0.848, 0.843, 0.856]

# %%
x = torch.arange(0, 1.76, 0.25)
y = acc

plt.hlines(y, x, x+0.25, linestyle=":")

# %%
model.analysis.filter_kernel = CutOff(min_val=2, max_val=0, kernel=filter_kernel)
model.analysis.filter._kernel = CutOff(min_val=2, max_val=0, kernel=filter_kernel)

plot_filter_banks(kernel=model.analysis.filter_kernel)
plot_filter_banks(kernel=model.analysis.filter.cheby_eval)
print(evaluate(model, dataset[0]))
# Out:
# {'train_loss': 0.5665571689605713, 'train_acc': 0.8166392993979201, 'val_loss': 0.7179194092750549, 'val_acc': 0.776, 'test_loss': 0.7270241379737854, 'test_acc': 0.786, 'f1_score': 0.8013225127742711}

# %% [markdown]
# #### Frequency analysis on cutoff

# %%
low_not_high_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(low_pass_correct_indices.difference(high_pass_correct_indices))]
high_not_low_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(high_pass_correct_indices.difference(low_pass_correct_indices))]
high_and_low_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(high_pass_correct_indices.intersection(low_pass_correct_indices))]
low_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(low_pass_correct_indices)]
high_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(high_pass_correct_indices)]
mid_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(mid_pass_correct_indices)]


print('Number of node classified correctly by low-pass filters:', len(low_correct_nodes))
print('Number of node classified correctly by high-pass filters:', len(high_correct_nodes))
print('Number of node classified correctly by mid-pass filters:', len(mid_correct_nodes))
print('Number of node classified correctly by low-pass filters but not by high-pass filters:', len(low_not_high_correct_nodes))
print('Number of node classified correctly by high-pass filters but not by low-pass filters:', len(high_not_low_correct_nodes))
print('Number of node classified correctly by both high-pass and low-pass filters:', len(high_and_low_correct_nodes))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3cf2633e1543> in <module>
# ----> 1 low_not_high_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(low_pass_correct_indices.difference(high_pass_correct_indices))]
#       2 high_not_low_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(high_pass_correct_indices.difference(low_pass_correct_indices))]
#       3 high_and_low_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(high_pass_correct_indices.intersection(low_pass_correct_indices))]
#       4 low_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(low_pass_correct_indices)]
#       5 high_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(high_pass_correct_indices)]
#
# NameError: name 'low_pass_correct_indices' is not defined

# %% [markdown]
# Neighbour distribution of nodes classified correct by high-pass

# %%
matching_labels_distribution(high_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.9054)
# matching labels in 2st hop: tensor(0.8545)
# matching labels in 3rd hop: tensor(0.8085)

# %%
matching_labels_distribution(list(G.nodes), G, dataset);

# %% [markdown]
# Neighbour distribution of nodes classified correct by low-pass

# %%
matching_labels_distribution(low_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.9054)
# matching labels in 2st hop: tensor(0.8535)
# matching labels in 3rd hop: tensor(0.8078)

# %% [markdown]
# Neighbour distribution of nodes classified correct by high-pass but not low pass

# %%
matching_labels_distribution(high_not_low_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.5389)
# matching labels in 2st hop: tensor(0.3711)
# matching labels in 3rd hop: tensor(0.2989)

# %%
matching_labels_distribution(low_not_high_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.6325)
# matching labels in 2st hop: tensor(0.4588)
# matching labels in 3rd hop: tensor(0.4045)

# %%
matching_labels_distribution(high_and_low_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.9200)
# matching labels in 2st hop: tensor(0.8792)
# matching labels in 3rd hop: tensor(0.8354)

# %% [markdown]
# Accuracy on less-similar neighbourhoods

# %%
from matplotlib import pyplot as plt
label_distributions = matching_labels_distribution(dataset[0]['test_mask'].nonzero().view(-1).tolist(), G, dataset);
# Out:
# tensor(0.7802)
# matching labels in 1st hop: tensor(0.7802)
# matching labels in 2st hop: tensor(0.7545)
# matching labels in 3rd hop: tensor(0.6895)

# %% [markdown]
# Draw attentions from high-pass filterbank(s)

# %%
low_attentions = torch.stack(low_att1, 0).sum(0)
high_attentions = torch.stack(high_att1, 0).sum(0)

index = 5
node = high_not_low_correct_nodes[index].item()
# node = low_not_high_correct_nodes[2].item()

Gego = nx.ego_graph(G, node, 2)
nodePos = nx.layout.spring_layout(Gego)

plt.figure(figsize=(15,5))
ax1 = plt.subplot(1, 2, 1)
ax1.set_title('high pass attentions')

for n in Gego.nodes:
    nx.draw_networkx_nodes(Gego, nodePos,
                           ax=ax1,
                           nodelist=[n],
                           node_color=[node_colors[dataset[0].y[n].item()](0.5)],
                           node_shape="*" if n == node else "o",
                           node_size=300 if n == node else (high_attentions[node, n]*400).clamp(max=400, min=20))
nx.draw_networkx_edges(Gego,nodePos, linewidths=0.5, ax=ax1)

ax2 = plt.subplot(1, 2, 2)
ax2.set_title('low pass attentions')

for n in Gego.nodes:
    nx.draw_networkx_nodes(Gego, nodePos,
                           ax=ax2,
                           nodelist=[n],
                           node_color=[node_colors[dataset[0].y[n].item()](0.5)],
                           node_shape="*" if n == node else "o",
                           node_size=300 if n == node else (low_attentions[node, n]*400).clamp(max=400, min=20))
nx.draw_networkx_edges(Gego,nodePos, linewidths=0.5, ax=ax2)

plt.show()

# %%
# low_attentions = torch.stack(low_att1, 0).sum(0)
# high_attentions = torch.stack(high_att1, 0).sum(0)

index = 6
node = high_not_low_correct_nodes[index].item()
# node = low_not_high_correct_nodes[index].item()

Gego = nx.ego_graph(G, node, 2)
nodePos = nx.layout.spring_layout(Gego)

plt.figure(figsize=(15,30))

for i in range(heads):
    ax = plt.subplot(9, 2, i+1)
    ax.set_title(str(i+1) + 'th head attentions')

#     print([att1[i][node, n].item() for n in Gego.nodes])
    for n in Gego.nodes:
        nx.draw_networkx_nodes(Gego, nodePos,
                               ax=ax,
                               nodelist=[n],
                               node_color=[node_colors[dataset[0].y[n].item()](0.5)],
                               node_shape="*" if n == node else "o",
                               node_size=300 if n == node else (att1[i][node, n]*1000).clamp(max=400, min=5))
    nx.draw_networkx_edges(Gego,nodePos, linewidths=0.5, ax=ax)
plt.show()

# %% [markdown]
# Attended node centrality distribution by frequency bands

# %%
# compute all node's centrality
centrality_between = nx.betweenness_centrality(G)
centrality_degree = nx.degree_centrality(G)
centrality_close = nx.closeness_centrality(G)
centrality_eigen = nx.eigenvector_centrality(G)

# %%
min_att = 1
plt.figure(figsize=(15,15))

print('Degree centrality')
ax1 = plt.subplot(4, 2, 1)
ax1.set_title('high-pass degree centrality')
centralities = torch.tensor([centrality_degree[n] for n in (high_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)

ax2 = plt.subplot(4, 2, 2)
ax2.set_title('low-pass degree centrality')
centralities = torch.tensor([centrality_degree[n] for n in (low_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('low-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)

print('\nBetweeness centrality')
ax3 = plt.subplot(4, 2, 3)
ax3.set_title('high-pass betweeness centrality')
centralities = torch.tensor([centrality_between[n] for n in (high_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)

ax4 = plt.subplot(4, 2, 4)
ax4.set_title('low-pass betweeness centrality')
centralities = torch.tensor([centrality_between[n] for n in (low_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('low-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)

print('\nCloseness centrality')
ax5 = plt.subplot(4, 2, 5)
ax5.set_title('high-pass closeness centrality')
centralities = torch.tensor([centrality_close[n] for n in (high_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)

ax6 = plt.subplot(4, 2, 6)
ax6.set_title('low-pass closeness centrality')
centralities = torch.tensor([centrality_close[n] for n in (low_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('low-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)

print('\nEigen centrality')
ax7 = plt.subplot(4, 2, 7)
ax7.set_title('high-pass eigen centrality')
centralities = torch.tensor([centrality_eigen[n] for n in (high_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20)


ax8 = plt.subplot(4, 2, 8)
ax8.set_title('low-pass eigen centrality')
centralities = torch.tensor([centrality_eigen[n] for n in (low_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('low-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# Degree centrality
# high-pass centrality mean: 0.0007517623016610742, std: 0.001312602311372757
# low-pass centrality mean: 0.000895306293386966, std: 0.0013277808902785182
#
# Betweeness centrality
# high-pass centrality mean: 0.0008892528712749481, std: 0.004006777424365282
# low-pass centrality mean: 0.0012096225982531905, std: 0.004478680435568094
#
# Closeness centrality
# high-pass centrality mean: 0.03601938858628273, std: 0.036449939012527466
# low-pass centrality mean: 0.04148750379681587, std: 0.034750401973724365
#
# Eigen centrality
# high-pass centrality mean: 0.0032677811104804277, std: 0.02111167274415493
# low-pass centrality mean: 0.002432297682389617, std: 0.019370058551430702

# %% [markdown]
# Attended node page rank distribution by frequency bands

# %%
# compute all node's page rank
pr = nx.pagerank(G, alpha=0.9)

min_att = 1
plt.figure(figsize=(15,3))

print('Page Rank')
ax1 = plt.subplot(1, 2, 1)
ax1.set_title('high-pass degree centrality')
prs = torch.tensor([pr[n] for n in (high_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass  page rank mean: {}, std: {}'.format(prs.mean().item(), prs.std().item()))
plt.hist(prs, color = 'blue', edgecolor = 'black', bins = 20)

ax2 = plt.subplot(1, 2, 2)
ax2.set_title('low-pass degree centrality')
prs = torch.tensor([pr[n] for n in (low_attentions > min_att).nonzero(as_tuple=True)[1].tolist()])
print('low-pass page rank mean: {}, std: {}'.format(prs.mean().item(), prs.std().item()))
plt.hist(prs, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# Page Rank
# high-pass  page rank mean: 0.0003032942219767618, std: 0.0002581054545828176
# low-pass page rank mean: 0.0003389950388768384, std: 0.0002890852496913017

# %% [markdown]
# Distance distribution of attended node

# %%
# Compute distances to from a node to its attended nodes
min_att = 0

high_distances = []

masked_high_attenions = high_attentions > min_att
for n1 in G.nodes:
    for n2 in G.nodes:
        if masked_high_attenions[n1, n2]:
            high_distances.append(nx.shortest_path_length(G, n1, n2))

low_distances = []

masked_low_attenions = low_attentions > min_att
for n1 in G.nodes:
    for n2 in G.nodes:
        if masked_low_attenions[n1, n2]:
            low_distances.append(nx.shortest_path_length(G, n1, n2))

            
plt.figure(figsize=(15,3))

print('Attended node distance')
ax1 = plt.subplot(1, 2, 1)
ax1.set_title('high-pass node distance')
distances = torch.tensor(high_distances).float()
print('high-pass node distance mean: {}, std: {}'.format(distances.mean().item(), distances.std().item()))
plt.hist(distances, color = 'blue', edgecolor = 'black', bins = 20)

ax2 = plt.subplot(1, 2, 2)
ax2.set_title('low-pass node distance')
distances = torch.tensor(low_distances).float()
print('low-pass node distance mean: {}, std: {}'.format(distances.mean().item(), distances.std().item()))
plt.hist(distances, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# Attended node distance
# high-pass node distance mean: 1.6864516735076904, std: 0.5896118879318237
# low-pass node distance mean: 1.6864516735076904, std: 0.5896118879318237

# %% [markdown]
# Re-train model with cutoff

# %%
# Similar result as cutoff after training
# from citation import run
#
# model_cutoff = Net(dataset)
#
# max_cutoff=1
# cutoff_kernel = model_cutoff.analysis.filter_kernel
# model_cutoff.analysis.filter_kernel = CutOff(max_val=max_cutoff, kernel=cutoff_kernel)
# model_cutoff.analysis.filter._kernel = CutOff(max_val=max_cutoff, kernel=cutoff_kernel)
#
# plot_filter_banks(kernel=model_cutoff.analysis.filter_kernel)
# print(evaluate(model_cutoff, dataset[0]))
#
# run(dataset, model_cutoff, runs, epochs, lr, weight_decay, patience, None)
#
# plot_filter_banks(kernel=model_cutoff.analysis.filter_kernel)
# print(evaluate(model_cutoff, dataset[0]))

# %% [markdown]
# ## Evaluate filterbanks
#
# Define kernel to eliminate certain filterbanks

# %%
class Elimination(nn.Module):
    def __init__(self, zero_out_indices):
        super(Elimination, self).__init__()
        self.zero_out_indices = zero_out_indices

    def reset_parameters(self):
        pass

    def forward(self, x):
        x = filter_kernel(x)
        x[:, self.zero_out_indices] = torch.zeros(x.shape[0], len(self.zero_out_indices))
        return x

# %% [markdown]
# Evaluate each filter bank

# %%
all_indices = set(list(range(heads)))
diff= []
for i in range(heads):
    zero_out_filters = list(all_indices.difference({i}))
    model.analysis.filter_kernel = Elimination(zero_out_filters)
    model.analysis.filter._kernel = Elimination(zero_out_filters)
    # plot_filter_banks(kernel=model.analysis.filter_kernel)
    test_acc = evaluate(model, dataset[0])['test_acc']
    diff.append(test_acc - eval_info['test_acc'])
print(' & '.join(['{:.2f}\%'.format(d*100) for d in diff]))
# Out:
# -4.30\% & -4.40\% & -4.40\% & -5.40\% & -4.30\% & -5.40\% & -5.40\% & -5.40\% & -4.30\% & -4.30\% & -4.30\% & -5.40\%

# %% [markdown]
# Evaluate by eliminating only one filter bank

# %%
diff= []
for i in range(heads):
    model.analysis.filter_kernel = Elimination([i])
    model.analysis.filter._kernel = Elimination([i])
    # plot_filter_banks(kernel=model.analysis.filter_kernel)
    test_acc = evaluate(model, dataset[0])['test_acc']
    diff.append(test_acc - eval_info['test_acc'])
print(' & '.join(['{:.2f}\%'.format(d*100) for d in diff]))
# Out:
# -0.80\% & -0.80\% & -0.70\% & 0.00\% & -0.80\% & 0.00\% & 0.00\% & 0.00\% & -0.70\% & -0.80\% & -0.80\% & 0.00\%

# %% [markdown]
# Load GAT model

# %%
from torch_geometric.nn import GATConv
class GAT(torch.nn.Module):
    def __init__(self, dataset):
        super(GAT, self).__init__()
        self.conv1 = GATConv(
            dataset.num_features,
            8,
            heads=8,
            dropout=0.6)
        self.conv2 = GATConv(
            64,
            dataset.num_classes,
            heads=8,
            concat=False,
            dropout=0.6)

    def reset_parameters(self):
        self.conv1.reset_parameters()
        self.conv2.reset_parameters()

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.dropout(x, p=0.6, training=self.training)
        x, (edge_index_1, att_val_1) = self.conv1(x, edge_index, return_attention_weights=True)
        x = F.elu(x)
        x = F.dropout(x, p=0.6, training=self.training)
        x, (edge_index_2, att_val_2) = self.conv2(x, edge_index, return_attention_weights=True)
#         att1 = torch.zeros(data.num_nodes, data.num_nodes, 8)
#         att2 = torch.zeros(data.num_nodes, data.num_nodes)
#         att1[list(map(lambda x: torch.tensor(x), edge_index_1.tolist()))] = att_val_1
#         att2[list(map(lambda x: torch.tensor(x), edge_index_2.tolist()))] = att_val_2.view(-1)
        return F.log_softmax(x, dim=1), None, None
gat = GAT(dataset)
gat.load_state_dict(torch.load('./model/best_{}_gat.pkl'.format(dataset_name)))
# gat_correct_indices = get_correctly_predicted_node_idx(gat, 'test', dataset)

# with torch.no_grad():
#     _, gat_att1, gat_att2 = gat(dataset[0])
evaluate(gat, dataset[0])
# Out:
# {'train_loss': 0.5743036270141602,
#  'train_acc': 0.8336169511994291,
#  'train_micro_f1': 0.8336169511994291,
#  'train_macro_f1': 0.8270346819240206,
#  'val_loss': 0.5511019229888916,
#  'val_acc': 0.858,
#  'val_micro_f1': 0.858,
#  'val_macro_f1': 0.8575799897615889,
#  'test_loss': 0.5681866407394409,
#  'test_acc': 0.83,
#  'test_micro_f1': 0.83,
#  'test_macro_f1': 0.8154432701270306}

# %%
from torch_geometric.nn import GCNConv
class GCN(torch.nn.Module):
    def __init__(self, dataset):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(dataset.num_features, 64)
        self.conv2 = GCNConv(64, dataset.num_classes)

    def reset_parameters(self):
        self.conv1.reset_parameters()
        self.conv2.reset_parameters()

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1), None
    
gcn = GCN(dataset)
gcn.load_state_dict(torch.load('./model/best_{}_gcn.pkl'.format(dataset_name)))
# gcn_correct_indices = get_correctly_predicted_node_idx(gcn, 'test', dataset)

evaluate(gcn, dataset[0])
# Out:
# {'train_loss': 0.39128461480140686,
#  'train_acc': 0.8694625898885656,
#  'train_micro_f1': 0.8694625898885656,
#  'train_macro_f1': 0.8636294291697005,
#  'val_loss': 0.36994460225105286,
#  'val_acc': 0.898,
#  'val_micro_f1': 0.898,
#  'val_macro_f1': 0.89424675756568,
#  'test_loss': 0.38893505930900574,
#  'test_acc': 0.877,
#  'test_micro_f1': 0.8769999999999999,
#  'test_macro_f1': 0.8679939356734936}

# %%
from torch_geometric.nn import SGConv

class SGC(torch.nn.Module):
    def __init__(self, dataset):
        super(SGC, self).__init__()
        self.conv1 = SGConv(
            dataset.num_features, dataset.num_classes, K=2, cached=True)

    def reset_parameters(self):
        self.conv1.reset_parameters()

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        return F.log_softmax(x, dim=1), None

dataset_unnormalized = get_dataset(dataset_name, False, edge_dropout=edge_dropout,
                                node_feature_dropout=node_feature_dropout)
sgc = SGC(dataset_unnormalized)
sgc.load_state_dict(torch.load('./model/best_{}_sgc.pkl'.format(dataset_name)))
# sgc_correct_indices = get_correctly_predicted_node_idx(sgc, 'test', dataset_unnormalized)

evaluate(sgc, dataset_unnormalized[0])
# Out:
# {'train_loss': 0.7168481349945068,
#  'train_acc': 0.8068836800790471,
#  'train_micro_f1': 0.8068836800790472,
#  'train_macro_f1': 0.7981837274245436,
#  'val_loss': 0.7021408081054688,
#  'val_acc': 0.828,
#  'val_micro_f1': 0.828,
#  'val_macro_f1': 0.823201151763015,
#  'test_loss': 0.7068486213684082,
#  'test_acc': 0.811,
#  'test_micro_f1': 0.811,
#  'test_macro_f1': 0.7986951738884569}

# %%
from torch_geometric.nn import ChebConv


class Cheb(torch.nn.Module):
    def __init__(self, dataset):
        super(Cheb, self).__init__()
        self.conv1 = ChebConv(dataset.num_features, 16, 2)
        self.conv2 = ChebConv(16, dataset.num_classes, 2)

    def reset_parameters(self):
        self.conv1.reset_parameters()
        self.conv2.reset_parameters()

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1), None
    
cheb = Cheb(dataset)
cheb.load_state_dict(torch.load('./model/best_{}_cheb.pkl'.format(dataset_name)))
# cheb_correct_indices = get_correctly_predicted_node_idx(cheb, 'test', dataset)

evaluate(cheb, dataset[0])
# Out:
# {'train_loss': 0.37991905212402344,
#  'train_acc': 0.8864247680737772,
#  'train_micro_f1': 0.8864247680737772,
#  'train_macro_f1': 0.882758496984099,
#  'val_loss': 0.3712571859359741,
#  'val_acc': 0.906,
#  'val_micro_f1': 0.906,
#  'val_macro_f1': 0.9048042615206794,
#  'test_loss': 0.383411705493927,
#  'test_acc': 0.892,
#  'test_micro_f1': 0.892,
#  'test_macro_f1': 0.8869761813833051}

# %%
from torch_geometric.nn import APPNP
from torch.nn import Linear

class Appnp(torch.nn.Module):
    def __init__(self, dataset):
        super(Appnp, self).__init__()
        self.lin1 = Linear(dataset.num_features, 64)
        self.lin2 = Linear(64, dataset.num_classes)
        self.prop1 = APPNP(10, 0.1)

    def reset_parameters(self):
        self.lin1.reset_parameters()
        self.lin2.reset_parameters()

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(self.lin1(x))
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin2(x)
        x = self.prop1(x, edge_index)
        return F.log_softmax(x, dim=1), None
    
appnp = Appnp(dataset)
appnp.load_state_dict(torch.load('./model/best_{}_appnp.pkl'.format(dataset_name)))
# appnp_correct_indices = get_correctly_predicted_node_idx(appnp, 'test', dataset)

evaluate(appnp, dataset[0])
# Out:
# {'train_loss': 0.4207569360733032,
#  'train_acc': 0.8578800021957512,
#  'train_micro_f1': 0.8578800021957512,
#  'train_macro_f1': 0.8516924034167869,
#  'val_loss': 0.39774176478385925,
#  'val_acc': 0.89,
#  'val_micro_f1': 0.89,
#  'val_macro_f1': 0.8865113028563011,
#  'test_loss': 0.4171692728996277,
#  'test_acc': 0.861,
#  'test_micro_f1': 0.861,
#  'test_macro_f1': 0.8497166909502996}

# %%
from torch_geometric.nn import ARMAConv

class ARMA(torch.nn.Module):
    def __init__(self, dataset):
        super(ARMA, self).__init__()
        self.conv1 = ARMAConv(
            dataset.num_features,
            16,
            2,
            1,
            False,
            dropout=0.75)
        self.conv2 = ARMAConv(
            16,
            dataset.num_classes,
            2,
            1,
            False,
            dropout=0.75)

    def reset_parameters(self):
        self.conv1.reset_parameters()
        self.conv2.reset_parameters()

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1), None
    
arma = ARMA(dataset)
arma.load_state_dict(torch.load('./model/best_{}_arma.pkl'.format(dataset_name)))
# arma_correct_indices = get_correctly_predicted_node_idx(arma, 'test', dataset)

evaluate(arma, dataset[0])
# Out:
# {'train_loss': 0.38494637608528137,
#  'train_acc': 0.8880166877092825,
#  'train_micro_f1': 0.8880166877092825,
#  'train_macro_f1': 0.8831678616464885,
#  'val_loss': 0.3750688433647156,
#  'val_acc': 0.902,
#  'val_micro_f1': 0.902,
#  'val_macro_f1': 0.9019431086109782,
#  'test_loss': 0.38728955388069153,
#  'test_acc': 0.89,
#  'test_micro_f1': 0.89,
#  'test_macro_f1': 0.8831355059729841}

# %%
from random import choice
from collections import Counter
from scipy.sparse import coo_matrix
import networkx as nx

def multimode(eles, num_classes):
    res = []
    if(len(eles) == 0):
        eles = list(range(num_classes))
    counter = Counter(eles)
    temp = counter.most_common(1)[0][1]
    for ele in eles:
      if eles.count(ele) == temp:
        res.append(ele)
    return list(set(res))

class MajorityVote(torch.nn.Module):
    def __init__(self, dataset):
        super(MajorityVote, self).__init__()
        self.num_classes = dataset.num_classes
        adj = coo_matrix(
            (np.ones(dataset[0].num_edges),
             (dataset[0].edge_index[0].numpy(), dataset[0].edge_index[1].numpy())),
            shape=(dataset[0].num_nodes, dataset[0].num_nodes))
        self.G = nx.Graph(adj)
        
    def forward(self, data):
        train_nodes = set(data.train_mask.nonzero().view(-1).tolist())

        logits = []
        for n in range(data.num_nodes):
            hop_1_neighbours = set(nx.ego_graph(self.G, n, 1).nodes())
            hop_1_labels = data.y[list(hop_1_neighbours)]
            label = choice(multimode(hop_1_labels.tolist(), self.num_classes))
            logits.append(F.one_hot(torch.tensor(label), self.num_classes).float())
        return torch.stack(logits, 0), None
    
majority_vote = MajorityVote(dataset)
# arma_correct_indices = get_correctly_predicted_node_idx(arma, 'test', dataset)

evaluate(majority_vote, dataset[0])
# Out:
# {'train_loss': -0.9006971716880798,
#  'train_acc': 0.9006971510127902,
#  'train_micro_f1': 0.9006971510127902,
#  'train_macro_f1': 0.8934874729945186,
#  'val_loss': -0.9100000262260437,
#  'val_acc': 0.91,
#  'val_micro_f1': 0.91,
#  'val_macro_f1': 0.9065146446956485,
#  'test_loss': -0.8870000243186951,
#  'test_acc': 0.887,
#  'test_micro_f1': 0.887,
#  'test_macro_f1': 0.8749717900276971}

# %%
class MLP(torch.nn.Module):
    def __init__(self, dataset):
        super(MLP, self).__init__()
        self.layers = nn.Sequential(nn.Linear(dataset[0].num_node_features, 64),
                                    nn.Dropout(0.8),
                                    nn.Linear(64, dataset.num_classes),
                                    nn.ReLU(inplace=True),
                                    nn.LogSoftmax(dim=1))

    def reset_parameters(self):
        for layer in self.layers:
            if hasattr(layer, 'reset_parameters'):
                layer.reset_parameters()

    def forward(self, data):
        x = data.x
        return self.layers(x), None, None

mlp = MLP(dataset)
mlp.load_state_dict(torch.load('./model/best_{}_mlp.pkl'.format(dataset_name)))
# arma_correct_indices = get_correctly_predicted_node_idx(arma, 'test', dataset)

evaluate(mlp, dataset[0])
# Out:
# {'train_loss': 0.7047340869903564,
#  'train_acc': 0.7308009002580008,
#  'train_micro_f1': 0.7308009002580009,
#  'train_macro_f1': 0.7360615448252622,
#  'val_loss': 0.7185620665550232,
#  'val_acc': 0.72,
#  'val_micro_f1': 0.72,
#  'val_macro_f1': 0.7288225700357726,
#  'test_loss': 0.7527480721473694,
#  'test_acc': 0.736,
#  'test_micro_f1': 0.736,
#  'test_macro_f1': 0.734637971426463}

# %%
np.sum([torch.prod(torch.tensor(p.shape)) for p in list(gat.parameters())])
# Out:
# 237586

# %%
np.sum([torch.prod(torch.tensor(p.shape)) for p in list(model.parameters())])
# Out:
# 325983

# %%
step = 0.1
def cal_acc_in_noisy_neighbourhood(m, dataset):
    m.eval()
    accs = []
    with torch.no_grad():
        logits  = m(dataset[0])[0]
    for p in torch.arange(step, 1.1, step):
        dissimilar_neighbhour_nodes_mask = dataset[0]['test_mask'].clone()
        dissimilar_neighbhour_nodes_mask[dissimilar_neighbhour_nodes_mask] = (torch.tensor(label_distributions[0]) <= p).logical_and(torch.tensor(label_distributions[0]) >= p - step)
        mask = dissimilar_neighbhour_nodes_mask
        pred = logits[mask].max(1)[1]
        accs.append(pred.eq(dataset[0].y[mask]).sum().item() / mask.sum().item())
    return accs

# Try to get some standard deviations

# %%
model_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(model, dataset))
gat_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(gat, dataset))
gcn_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(gcn, dataset))
sgc_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(sgc, dataset_unnormalized))
cheb_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(cheb, dataset))
appnp_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(appnp, dataset))
arma_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(arma, dataset))
majority_vote_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(majority_vote, dataset))
mlp_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(mlp, dataset))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-30-614f664d16f7> in <module>
# ----> 1 model_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(model, dataset))
#       2 gat_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(gat, dataset))
#       3 gcn_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(gcn, dataset))
#       4 sgc_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(sgc, dataset_unnormalized))
#       5 cheb_noisy_accs = torch.tensor(cal_acc_in_noisy_neighbourhood(cheb, dataset))
#
# <ipython-input-29-0c6bdab8818c> in cal_acc_in_noisy_neighbourhood(m, dataset)
#       4     accs = []
#       5     with torch.no_grad():
# ----> 6         logits  = m(dataset[0])[0]
#       7     for p in torch.arange(step, 1.1, step):
#       8         dissimilar_neighbhour_nodes_mask = dataset[0]['test_mask'].clone()
#
# c:\users\sohey_m6zyufm\pycharmprojects\decimation_branch_mark\venv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-8-db73451eb85f> in forward(self, data)
#      38         x = data.x
#      39         x = F.dropout(x, p=dropout, training=self.training)
# ---> 40         x, att1 = self.analysis(x)
#      41         x = F.dropout(x, p=dropout, training=self.training)
#      42         x, att2 = self.synthesis(x)
#
# c:\users\sohey_m6zyufm\pycharmprojects\decimation_branch_mark\venv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\PycharmProjects\decimation_branch_mark\model\layers.py in forward(self, input)
#     116         assert not torch.isnan(h).any()
#     117
# --> 118         coefficients_list = self.filter()
#     119         h_primes = []
#     120         attentions = []
#
# c:\users\sohey_m6zyufm\pycharmprojects\decimation_branch_mark\venv\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\PycharmProjects\decimation_branch_mark\model\spectral_filter.py in forward(self)
#     249         # TODO: update Chebyshev implementation (after 2D filter banks).
#     250         c = self.compute_cheby_coeff(m=self.chebyshev_order)
# --> 251         s = self.cheby_op(c)
#     252
#     253         return s
#
# ~\PycharmProjects\decimation_branch_mark\model\spectral_filter.py in cheby_op(self, c)
#     226             twf_new = (torch.sparse_coo_tensor(fmt_index, fmt_value, [G.n_vertices, G.n_vertices]) - twf_old).coalesce()
#     227             for i in range(nf):
# --> 228                 r[i] = torch.sparse_coo_tensor(twf_new.indices(), twf_new.values() * c[k,i], twf_new.shape) + r[i]
#     229
#     230             twf_old = twf_cur
#
# RuntimeError: [enforce fail at ..\c10\core\CPUAllocator.cpp:72] data. DefaultCPUAllocator: not enough memory: you tried to allocate 9472536 bytes. Buy new RAM!

# %%
plt.figure(dpi=450)
x = [str(p)+'%' for p in range(10, 110, 10)]
plt.plot(x,
         gcn_noisy_accs,
         linestyle=':',
         zorder=2)
plt.plot(x,
         gat_noisy_accs,
         linestyle='--',
         zorder=2)
plt.plot(x,
         sgc_noisy_accs,
         linestyle='--',
         zorder=2)
plt.plot(x,
         cheb_noisy_accs,
         linestyle=':',
         zorder=2)
plt.plot(x,
         appnp_noisy_accs,
         linestyle='--',
         zorder=2)
plt.plot(x,
         arma_noisy_accs,
         linestyle=':',
         zorder=2)
plt.plot(x,
         majority_vote_noisy_accs,
         linestyle='-',
         alpha=0.3,
         zorder=2)
plt.plot(x,
         mlp_noisy_accs,
         linestyle='-',
         zorder=2)
plt.plot(x,
         model_noisy_accs,
         linewidth=1.5,
         linestyle='-',
         zorder=2)

s1 = plt.scatter(x, gcn_noisy_accs, zorder=1, marker='*')
s2 = plt.scatter(x, gat_noisy_accs, zorder=1, marker="o")
s3 = plt.scatter(x, sgc_noisy_accs, zorder=1, marker='s')
s4 = plt.scatter(x, cheb_noisy_accs, zorder=1, marker='d')
s5 = plt.scatter(x, appnp_noisy_accs, zorder=1, marker='X')
s6 = plt.scatter(x, arma_noisy_accs, zorder=1, marker='v')
s7 = plt.scatter(x, majority_vote_noisy_accs, zorder=1, marker='*', alpha=0.3)
s8 = plt.scatter(x, mlp_noisy_accs, zorder=1, marker='^')
s9 = plt.scatter(x, model_noisy_accs, zorder=1, marker='^')

plt.legend((s1, s2, s3, s4, s5, s6, s7, s8, s9), ('GCN', 'GAT', 'SGC', 'Cheby', 'APPNP', 'ARMA', 'Majority vote', 'MLP', 'Model'))
# plt.legend((s1, s3, s4, s5, s7, s8, s9), ('GCN', 'SGC', 'Cheby', 'APPNP', 'Majority vote', 'MLP', 'Model'))

data_2_save = {
    'x': x,
    'labels': ['GCN', 'GAT', 'SGC', 'Cheby', 'APPNP', 'ARMA', 'Majority vote', 'MLP', 'Model'],
    'accs': [gcn_noisy_accs, gat_noisy_accs, sgc_noisy_accs, appnp_noisy_accs, arma_noisy_accs, majority_vote_noisy_accs, mlp_noisy_accs, model_noisy_accs]
}
torch.save(data_2_save, './pubmed_beta_acc.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f07df9cf2364> in <module>
#       2 x = [str(p)+'%' for p in range(10, 110, 10)]
#       3 plt.plot(x,
# ----> 4          gcn_noisy_accs,
#       5          linestyle=':',
#       6          zorder=2)
#
# NameError: name 'gcn_noisy_accs' is not defined

# %%
(model_noisy_accs - cheb_noisy_accs).mean()
# Out:
# tensor(0.0372)

# %%
plt.figure(dpi=450)
x = [str(p)+'%' for p in range(10, 110, 10)]
plt.plot(x,
         gcn_noisy_accs,
         linestyle=':',
         zorder=2)
plt.plot(x,
         gat_noisy_accs,
         linestyle='--',
         zorder=2)
plt.plot(x,
         sgc_noisy_accs,
         linestyle='--',
         zorder=2)
plt.plot(x,
         cheb_noisy_accs,
         linestyle=':',
         zorder=2)
plt.plot(x,
         appnp_noisy_accs,
         linestyle='--',
         zorder=2)
plt.plot(x,
         arma_noisy_accs,
         linestyle=':',
         zorder=2)
plt.plot(x,
         model_noisy_accs,
         linestyle='-',
         zorder=2)

s1 = plt.scatter(x, gcn_noisy_accs, zorder=1, marker='*')
s2 = plt.scatter(x, gat_noisy_accs, zorder=1, marker="o")
s3 = plt.scatter(x, sgc_noisy_accs, zorder=1, marker='s')
s4 = plt.scatter(x, cheb_noisy_accs, zorder=1, marker='d')
s5 = plt.scatter(x, appnp_noisy_accs, zorder=1, marker='X')
s6 = plt.scatter(x, arma_noisy_accs, zorder=1, marker='v')
s7 = plt.scatter(x, model_noisy_accs, zorder=1, marker='^')
plt.legend((s1, s2, s3, s4, s5, s6, s7), ('GCN', 'GAT', 'SGC', 'Cheby', 'APPNP', 'ARMA', 'Model'))

# %% [markdown]
# Comparison with GAT

# %%
model_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(model_correct_indices)]
gat_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(gat_correct_indices)]
model_not_gat_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(model_correct_indices.difference(gat_correct_indices))]
model_and_gat_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(model_correct_indices.intersection(gat_correct_indices))]
gat_not_model_correct_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(gat_correct_indices.difference(model_correct_indices))]
gat_and_model_incorrect_nodes = dataset[0]['test_mask'].nonzero().view(-1)[list(set(dataset[0].y[dataset[0]['test_mask']].nonzero().view(-1).tolist()).difference(model_correct_indices).difference(gat_correct_indices))]
print('Number of node classified correctly by our model:', len(model_correct_nodes))
print('Number of node classified correctly by GAT:', len(gat_correct_nodes))
print('Number of node classified correctly by our model but not by GAT:', len(model_not_gat_correct_nodes))
print('Number of node classified correctly by both GAT and our model:', len(model_and_gat_correct_nodes))
print('Number of node classified correctly by GAT but not by our model:', len(gat_not_model_correct_nodes))
print('Number of node classified incorrectly by GAT and our model:', len(gat_and_model_incorrect_nodes))
# Out:
# Number of node classified correctly by our model: 805
# Number of node classified correctly by GAT: 778
# Number of node classified correctly by our model but not by GAT: 59
# Number of node classified correctly by both GAT and our model: 746
# Number of node classified correctly by GAT but not by our model: 32
# Number of node classified incorrectly by GAT and our model: 118

# %%
gat_att1_sum = gat_att1.sum(dim=2)

# %%
node = model_not_gat_correct_nodes[1].item()
Gego = nx.ego_graph(G, node, 2)
nodePos = nx.layout.spring_layout(Gego)
plt.figure()
for n in Gego.nodes:
    nx.draw_networkx_nodes(Gego, nodePos,
                           nodelist=[n],
                           node_color=[node_colors[dataset[0].y[n].item()](0.8)],
                           node_shape="*" if n == node else "o",
                           node_size=300 if n == node else (model_att1_sum[node, n]*200).clamp(max=400, min=5))
nx.draw_networkx_edges(Gego,nodePos, linewidths=0.5)


plt.figure()
for n in Gego.nodes:
    nx.draw_networkx_nodes(Gego, nodePos,
                           nodelist=[n],
                           node_color=[node_colors[dataset[0].y[n].item()](0.8)],
                           node_shape="*" if n == node else "o",
                           node_size=300 if n == node else (gat_att1_sum[node, n]*200).clamp(max=400, min=5))
nx.draw_networkx_edges(Gego,nodePos, linewidths=0.5)

# %% [markdown]
# Label distribution of nodes classified correctly by our model

# %%
print('\nBetweeness centrality')
ax3 = plt.subplot(1, 1, 1)
# ax3.set_title('high-pass betweeness centrality')
centralities = torch.tensor([centrality_between[n] for n in (gat_att1_sum).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# Betweeness centrality
# high-pass centrality mean: 0.0031025800853967667, std: 0.008951541967689991

# %%
print('\nBetweeness centrality')
ax3 = plt.subplot(1, 1, 1)
# ax3.set_title('high-pass betweeness centrality')
centralities = torch.tensor([centrality_between[n] for n in (model_att1_sum).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# Betweeness centrality
# high-pass centrality mean: 0.003282387275248766, std: 0.008437315002083778

# %%
matching_labels_distribution(model_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.8937)
# matching labels in 2st hop: tensor(0.8390)
# matching labels in 3rd hop: tensor(0.7911)

# %%
min_att = 0.2

# %% [markdown]
# Label distribution of nodes classified correctly by our model

# %%
print('\nBetweeness centrality')
ax3 = plt.subplot(1, 1, 1)
# ax3.set_title('high-pass betweeness centrality')
centralities = torch.tensor([centrality_between[n] for n in (gat_att1_sum > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# Betweeness centrality
# high-pass centrality mean: 0.0024233979638665915, std: 0.0065828170627355576

# %%
print('\nBetweeness centrality')
ax3 = plt.subplot(1, 1, 1)
# ax3.set_title('high-pass betweeness centrality')
centralities = torch.tensor([centrality_between[n] for n in (model_att1_sum > min_att).nonzero(as_tuple=True)[1].tolist()])
print('high-pass centrality mean: {}, std: {}'.format(centralities.mean().item(), centralities.std().item()))
plt.hist(centralities, color = 'blue', edgecolor = 'black', bins = 20);
# Out:
# Betweeness centrality
# high-pass centrality mean: 0.002925171982496977, std: 0.007751181721687317

# %%
matching_labels_distribution(model_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.8937)
# matching labels in 2st hop: tensor(0.8390)
# matching labels in 3rd hop: tensor(0.7911)
# ([tensor(0.6000),
#   tensor(0.5714),
#   tensor(0.6667),
#   tensor(0.9167),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7143),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5714),
#   tensor(1.),
#   tensor(0.6250),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.7143),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8462),
#   tensor(0.8333),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6250),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6923),
#   tensor(0.3750),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.6250),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8182),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.7500),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.5714),
#   tensor(0.8571),
#   tensor(0.8571),
#   tensor(0.8333),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.6667),
#   tensor(0.5000),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6364),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.4000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(0.6250),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.9000),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9091),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5714),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.5714),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.5833),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.4000),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(0.9091),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8824),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9231),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(0.8889),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.2000),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7143),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.2000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.)],
#  [tensor(0.5185),
#   tensor(0.4722),
#   tensor(0.3478),
#   tensor(0.7872),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8235),
#   tensor(0.8750),
#   tensor(0.6364),
#   tensor(0.9412),
#   tensor(0.6429),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.2500),
#   tensor(0.2500),
#   tensor(0.8571),
#   tensor(0.6667),
#   tensor(0.7000),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(0.8158),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3448),
#   tensor(0.7692),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.3889),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(0.8750),
#   tensor(0.4000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8636),
#   tensor(0.8000),
#   tensor(0.8667),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7727),
#   tensor(0.7692),
#   tensor(1.),
#   tensor(0.8667),
#   tensor(1.),
#   tensor(0.9500),
#   tensor(0.6250),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.3750),
#   tensor(0.7500),
#   tensor(0.9057),
#   tensor(0.6667),
#   tensor(0.7500),
#   tensor(0.3333),
#   tensor(0.9313),
#   tensor(1.),
#   tensor(0.9108),
#   tensor(0.1923),
#   tensor(0.4286),
#   tensor(1.),
#   tensor(0.7414),
#   tensor(0.8148),
#   tensor(0.8333),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8750),
#   tensor(0.8636),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9841),
#   tensor(0.9615),
#   tensor(0.9839),
#   tensor(0.6667),
#   tensor(0.7391),
#   tensor(0.7273),
#   tensor(0.6667),
#   tensor(0.5714),
#   tensor(0.4444),
#   tensor(0.3478),
#   tensor(0.5152),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(0.9051),
#   tensor(0.8750),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.8636),
#   tensor(0.9143),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8049),
#   tensor(0.9154),
#   tensor(0.5385),
#   tensor(0.7500),
#   tensor(0.9351),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(1.),
#   tensor(0.9286),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7000),
#   tensor(0.7000),
#   tensor(0.8125),
#   tensor(0.5000),
#   tensor(0.8462),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3750),
#   tensor(0.6316),
#   tensor(0.9463),
#   tensor(0.7500),
#   tensor(0.8750),
#   tensor(0.8824),
#   tensor(0.3333),
#   tensor(0.9310),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.6923),
#   tensor(0.7308),
#   tensor(0.7538),
#   tensor(0.9391),
#   tensor(0.9500),
#   tensor(0.2857),
#   tensor(0.9091),
#   tensor(0.9259),
#   tensor(1.),
#   tensor(0.9333),
#   tensor(0.1538),
#   tensor(0.5000),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.5574),
#   tensor(1.),
#   tensor(0.8929),
#   tensor(0.8800),
#   tensor(0.9286),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6047),
#   tensor(0.5000),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6552),
#   tensor(0.2857),
#   tensor(0.4286),
#   tensor(1.),
#   tensor(0.1667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.9565),
#   tensor(1.),
#   tensor(0.5455),
#   tensor(0.5556),
#   tensor(1.),
#   tensor(0.7917),
#   tensor(0.7778),
#   tensor(0.7143),
#   tensor(0.6667),
#   tensor(0.9091),
#   tensor(0.8269),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.7273),
#   tensor(0.7500),
#   tensor(0.4286),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.9091),
#   tensor(0.9375),
#   tensor(0.7273),
#   tensor(0.7273),
#   tensor(1.),
#   tensor(0.9375),
#   tensor(0.9583),
#   tensor(0.8905),
#   tensor(0.5000),
#   tensor(0.3000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.8750),
#   tensor(0.9388),
#   tensor(0.9333),
#   tensor(1.),
#   tensor(0.6250),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8462),
#   tensor(1.),
#   tensor(0.2500),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9231),
#   tensor(0.3750),
#   tensor(0.5556),
#   tensor(0.7143),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(0.4872),
#   tensor(0.7865),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9189),
#   tensor(0.8571),
#   tensor(0.7500),
#   tensor(0.4286),
#   tensor(1.),
#   tensor(0.9184),
#   tensor(0.9394),
#   tensor(0.6491),
#   tensor(0.9333),
#   tensor(0.9286),
#   tensor(0.9286),
#   tensor(0.5000),
#   tensor(0.9615),
#   tensor(0.5833),
#   tensor(0.7241),
#   tensor(0.9055),
#   tensor(0.8944),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7750),
#   tensor(0.2500),
#   tensor(0.6000),
#   tensor(0.8000),
#   tensor(0.6667),
#   tensor(0.4286),
#   tensor(0.4286),
#   tensor(0.9115),
#   tensor(0.9130),
#   tensor(0.8837),
#   tensor(0.1613),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.6000),
#   tensor(0.9412),
#   tensor(0.5714),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.1316),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.1000),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8800),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7222),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5833),
#   tensor(0.5833),
#   tensor(0.6842),
#   tensor(0.7333),
#   tensor(0.7778),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.7273),
#   tensor(0.5294),
#   tensor(0.7333),
#   tensor(0.7778),
#   tensor(0.9545),
#   tensor(0.9091),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8235),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.3200),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.7500),
#   tensor(0.6667),
#   tensor(0.8182),
#   tensor(0.7500),
#   tensor(0.5652),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(0.8923),
#   tensor(1.),
#   tensor(0.6500),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.8689),
#   tensor(0.9292),
#   tensor(0.9417),
#   tensor(0.9464),
#   tensor(0.9483),
#   tensor(0.8000),
#   tensor(0.9630),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(0.6000),
#   tensor(0.7857),
#   tensor(0.5000),
#   tensor(0.8182),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9091),
#   tensor(0.6250),
#   tensor(0.8000),
#   tensor(0.5000),
#   tensor(0.5714),
#   tensor(1.),
#   tensor(0.9167),
#   tensor(0.9444),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.6774),
#   tensor(0.9302),
#   tensor(0.9406),
#   tensor(0.9223),
#   tensor(0.9469),
#   tensor(0.9204),
#   tensor(0.9216),
#   tensor(0.9459),
#   tensor(0.8983),
#   tensor(0.9020),
#   tensor(0.8870),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.4762),
#   tensor(0.6364),
#   tensor(0.6000),
#   tensor(0.3333),
#   tensor(0.9474),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.9130),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6154),
#   tensor(1.),
#   tensor(0.5556),
#   tensor(1.),
#   tensor(0.4167),
#   tensor(1.),
#   tensor(0.6250),
#   tensor(1.),
#   tensor(0.8846),
#   tensor(0.9750),
#   tensor(0.8125),
#   tensor(1.),
#   tensor(0.2500),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(0.6957),
#   tensor(0.9091),
#   tensor(0.9091),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8947),
#   tensor(1.),
#   tensor(0.8529),
#   tensor(0.2500),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6154),
#   tensor(1.),
#   tensor(0.1667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.7714),
#   tensor(0.8824),
#   tensor(0.8824),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9333),
#   tensor(0.9184),
#   tensor(0.6667),
#   tensor(0.8333),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.7273),
#   tensor(0.4792),
#   tensor(0.9000),
#   tensor(0.9016),
#   tensor(0.7500),
#   tensor(0.6250),
#   tensor(0.9268),
#   tensor(0.8571),
#   tensor(0.8148),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(0.8095),
#   tensor(0.6000),
#   tensor(0.8000),
#   tensor(0.7500),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.4167),
#   tensor(1.),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.9000),
#   tensor(0.7500),
#   tensor(0.8833),
#   tensor(0.8000),
#   tensor(0.8889),
#   tensor(0.6000),
#   tensor(0.3333),
#   tensor(0.6667),
#   tensor(0.8000),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.3125),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.9273),
#   tensor(0.8929),
#   tensor(0.7500),
#   tensor(0.9048),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9118),
#   tensor(0.4286),
#   tensor(0.8000),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9048),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9375),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9130),
#   tensor(0.8571),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9355),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9135),
#   tensor(0.9091),
#   tensor(0.9000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7333),
#   tensor(0.9375),
#   tensor(0.5556),
#   tensor(0.6429),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9062),
#   tensor(0.5600),
#   tensor(0.5417),
#   tensor(0.1250),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5200),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.0833),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(0.8571),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.8929),
#   tensor(0.2000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.8000),
#   tensor(0.5000),
#   tensor(0.8333),
#   tensor(0.8333),
#   tensor(0.8333),
#   tensor(0.8750),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8125),
#   tensor(0.1667),
#   tensor(0.8095),
#   tensor(0.3158),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(0.6957),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.4000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9091),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9048),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.9333),
#   tensor(0.4000),
#   tensor(0.6667),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.3333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.9355),
#   tensor(0.8889),
#   tensor(0.8889),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.8000),
#   tensor(0.8182),
#   tensor(0.8182),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9583),
#   tensor(0.9038),
#   tensor(0.9038),
#   tensor(0.9038),
#   tensor(1.),
#   tensor(0.8947),
#   tensor(0.7059),
#   tensor(0.8333),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.6111),
#   tensor(0.8000),
#   tensor(0.8000),
#   tensor(0.7692),
#   tensor(0.7143),
#   tensor(0.7143),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.9062),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.7333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7000),
#   tensor(0.1429),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.3333),
#   tensor(0.5000),
#   tensor(0.6667),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.8947),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.4286),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9167),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.9231),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.6667)],
#  [tensor(0.6719),
#   tensor(0.4595),
#   tensor(0.3103),
#   tensor(0.8043),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8298),
#   tensor(0.8485),
#   tensor(0.7500),
#   tensor(0.9057),
#   tensor(0.6735),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.1667),
#   tensor(0.2162),
#   tensor(0.7368),
#   tensor(0.6028),
#   tensor(0.2727),
#   tensor(0.7500),
#   tensor(0.6000),
#   tensor(0.6610),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3387),
#   tensor(0.4800),
#   tensor(0.9688),
#   tensor(1.),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(0.6875),
#   tensor(0.2885),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.8824),
#   tensor(0.8065),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8052),
#   tensor(0.6712),
#   tensor(0.7105),
#   tensor(0.9310),
#   tensor(0.5000),
#   tensor(0.9130),
#   tensor(0.9697),
#   tensor(0.9429),
#   tensor(0.8710),
#   tensor(0.8077),
#   tensor(0.9111),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.9714),
#   tensor(0.3043),
#   tensor(0.5294),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(0.8929),
#   tensor(0.7059),
#   tensor(0.3103),
#   tensor(0.8333),
#   tensor(0.9008),
#   tensor(0.7500),
#   tensor(0.6000),
#   tensor(0.6429),
#   tensor(0.7993),
#   tensor(0.9313),
#   tensor(0.7681),
#   tensor(0.2206),
#   tensor(0.4167),
#   tensor(1.),
#   tensor(0.7846),
#   tensor(0.6494),
#   tensor(0.8333),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.7000),
#   tensor(0.8947),
#   tensor(1.),
#   tensor(0.9040),
#   tensor(0.8717),
#   tensor(0.9119),
#   tensor(0.8843),
#   tensor(0.7500),
#   tensor(0.6040),
#   tensor(0.6433),
#   tensor(0.5714),
#   tensor(0.4444),
#   tensor(0.6667),
#   tensor(0.3125),
#   tensor(0.6993),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(0.7817),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.8947),
#   tensor(0.7746),
#   tensor(0.9143),
#   tensor(0.9200),
#   tensor(0.8447),
#   tensor(0.7885),
#   tensor(0.4500),
#   tensor(0.8000),
#   tensor(0.9053),
#   tensor(0.9351),
#   tensor(0.9351),
#   tensor(0.9496),
#   tensor(0.9351),
#   tensor(0.9351),
#   tensor(0.9444),
#   tensor(1.),
#   tensor(0.8205),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6875),
#   tensor(0.6875),
#   tensor(0.7407),
#   tensor(0.3529),
#   tensor(0.6364),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9444),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.1905),
#   tensor(0.5490),
#   tensor(0.7930),
#   tensor(0.8000),
#   tensor(0.7778),
#   tensor(0.5082),
#   tensor(0.0690),
#   tensor(0.8929),
#   tensor(1.),
#   tensor(0.9167),
#   tensor(0.5882),
#   tensor(0.6940),
#   tensor(0.7672),
#   tensor(0.8022),
#   tensor(0.8667),
#   tensor(0.1944),
#   tensor(0.8281),
#   tensor(0.9189),
#   tensor(0.8571),
#   tensor(0.9104),
#   tensor(0.0882),
#   tensor(0.5000),
#   tensor(0.5714),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.7414),
#   tensor(1.),
#   tensor(0.9067),
#   tensor(0.8154),
#   tensor(0.8889),
#   tensor(0.7586),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(0.5917),
#   tensor(0.5000),
#   tensor(0.8667),
#   tensor(0.9412),
#   tensor(0.9118),
#   tensor(0.6891),
#   tensor(0.3000),
#   tensor(0.4000),
#   tensor(0.8987),
#   tensor(0.2222),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.4667),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9344),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8182),
#   tensor(0.2222),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9600),
#   tensor(0.8793),
#   tensor(1.),
#   tensor(0.4000),
#   tensor(0.5000),
#   tensor(0.8857),
#   tensor(0.4918),
#   tensor(0.5833),
#   tensor(0.6800),
#   tensor(0.7500),
#   tensor(0.7762),
#   tensor(0.8372),
#   tensor(0.7273),
#   tensor(0.7273),
#   tensor(0.8889),
#   tensor(0.6429),
#   tensor(0.7500),
#   tensor(0.2381),
#   tensor(1.),
#   tensor(0.5217),
#   tensor(0.8831),
#   tensor(0.8222),
#   tensor(0.5385),
#   tensor(0.5385),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.7750),
#   tensor(0.7898),
#   tensor(0.7143),
#   tensor(0.3421),
#   tensor(0.5294),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(0.6875),
#   tensor(0.8087),
#   tensor(0.8850),
#   tensor(0.8750),
#   tensor(1.),
#   tensor(0.7000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8438),
#   tensor(1.),
#   tensor(0.0417),
#   tensor(0.8667),
#   tensor(0.8333),
#   tensor(0.9231),
#   tensor(1.),
#   tensor(0.8947),
#   tensor(0.2326),
#   tensor(0.2400),
#   tensor(0.5263),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8491),
#   tensor(0.7719),
#   tensor(0.7193),
#   tensor(1.),
#   tensor(0.8125),
#   tensor(0.8646),
#   tensor(0.8634),
#   tensor(0.4286),
#   tensor(0.2727),
#   tensor(1.),
#   tensor(0.7154),
#   tensor(0.8913),
#   tensor(0.7071),
#   tensor(0.6970),
#   tensor(0.6491),
#   tensor(0.6491),
#   tensor(0.4375),
#   tensor(0.9152),
#   tensor(0.4643),
#   tensor(0.3786),
#   tensor(0.7853),
#   tensor(0.7829),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9048),
#   tensor(0.8080),
#   tensor(0.2500),
#   tensor(0.6842),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(0.4615),
#   tensor(0.4615),
#   tensor(0.7914),
#   tensor(0.7914),
#   tensor(0.8641),
#   tensor(0.0480),
#   tensor(0.7939),
#   tensor(1.),
#   tensor(0.7553),
#   tensor(0.2000),
#   tensor(0.8205),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.0491),
#   tensor(1.),
#   tensor(0.8261),
#   tensor(0.9000),
#   tensor(0.6667),
#   tensor(0.0556),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.9556),
#   tensor(0.9565),
#   tensor(0.9545),
#   tensor(0.9556),
#   tensor(0.9556),
#   tensor(0.9535),
#   tensor(0.9318),
#   tensor(1.),
#   tensor(0.8095),
#   tensor(0.6200),
#   tensor(1.),
#   tensor(0.7727),
#   tensor(0.9730),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5855),
#   tensor(0.5855),
#   tensor(0.5309),
#   tensor(0.6698),
#   tensor(0.8000),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(0.6800),
#   tensor(0.7442),
#   tensor(0.5357),
#   tensor(0.6216),
#   tensor(0.7391),
#   tensor(0.8644),
#   tensor(0.8644),
#   tensor(0.9255),
#   tensor(1.),
#   tensor(0.9167),
#   tensor(1.),
#   tensor(0.8824),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.1642),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9286),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7143),
#   tensor(0.7619),
#   tensor(0.5000),
#   tensor(0.7778),
#   tensor(0.7200),
#   tensor(0.5455),
#   tensor(0.9412),
#   tensor(0.9444),
#   tensor(0.8296),
#   tensor(0.8841),
#   tensor(0.6094),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.6786),
#   tensor(0.7500),
#   tensor(0.7843),
#   tensor(0.7904),
#   tensor(0.7949),
#   tensor(0.7910),
#   tensor(0.8374),
#   tensor(0.8333),
#   tensor(0.9057),
#   tensor(0.7000),
#   tensor(1.),
#   tensor(0.7000),
#   tensor(0.5714),
#   tensor(0.6452),
#   tensor(0.5000),
#   tensor(0.6296),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7419),
#   tensor(0.6250),
#   tensor(0.6250),
#   tensor(0.5000),
#   tensor(0.6923),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(0.8723),
#   tensor(0.9103),
#   tensor(0.9474),
#   tensor(0.5000),
#   tensor(0.7807),
#   tensor(0.7961),
#   tensor(0.7939),
#   tensor(0.7940),
#   tensor(0.7978),
#   tensor(0.7881),
#   tensor(0.7879),
#   tensor(0.7978),
#   tensor(0.8000),
#   tensor(0.7790),
#   tensor(0.7601),
#   tensor(0.7500),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.5455),
#   tensor(0.4483),
#   tensor(0.3214),
#   tensor(0.0198),
#   tensor(0.8793),
#   tensor(1.),
#   tensor(0.6429),
#   tensor(0.8298),
#   tensor(0.8654),
#   tensor(0.9412),
#   tensor(1.),
#   tensor(0.5692),
#   tensor(1.),
#   tensor(0.5556),
#   tensor(1.),
#   tensor(0.3684),
#   tensor(1.),
#   tensor(0.3889),
#   tensor(1.),
#   tensor(0.8469),
#   tensor(0.8500),
#   tensor(0.3897),
#   tensor(0.9267),
#   tensor(0.2000),
#   tensor(0.8000),
#   tensor(0.9167),
#   tensor(1.),
#   tensor(0.8442),
#   tensor(0.6957),
#   tensor(0.6957),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8929),
#   tensor(0.8235),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8478),
#   tensor(1.),
#   tensor(0.8536),
#   tensor(0.1639),
#   tensor(1.),
#   tensor(0.7579),
#   tensor(0.5610),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5526),
#   tensor(1.),
#   tensor(0.1667),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.7857),
#   tensor(0.7941),
#   tensor(0.7714),
#   tensor(0.7714),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(0.7778),
#   tensor(0.8000),
#   tensor(0.9074),
#   tensor(0.9068),
#   tensor(0.5750),
#   tensor(0.8261),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.7692),
#   tensor(0.2772),
#   tensor(0.9044),
#   tensor(0.8867),
#   tensor(0.4286),
#   tensor(0.3810),
#   tensor(0.8396),
#   tensor(0.8704),
#   tensor(0.8211),
#   tensor(0.9167),
#   tensor(1.),
#   tensor(0.8952),
#   tensor(0.3385),
#   tensor(0.8000),
#   tensor(0.8000),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.2059),
#   tensor(1.),
#   tensor(0.1053),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8000),
#   tensor(0.9500),
#   tensor(0.7143),
#   tensor(0.8897),
#   tensor(0.8833),
#   tensor(0.9032),
#   tensor(0.3889),
#   tensor(0.3500),
#   tensor(0.6667),
#   tensor(0.5152),
#   tensor(0.8000),
#   tensor(0.8750),
#   tensor(0.2418),
#   tensor(0.6667),
#   tensor(1.),
#   tensor(0.8327),
#   tensor(0.8855),
#   tensor(0.7500),
#   tensor(0.8882),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7730),
#   tensor(0.3750),
#   tensor(0.8333),
#   tensor(0.3333),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8833),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9160),
#   tensor(0.9155),
#   tensor(0.9268),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.4000),
#   tensor(1.),
#   tensor(0.7857),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.9302),
#   tensor(1.),
#   tensor(0.8522),
#   tensor(0.8750),
#   tensor(0.7407),
#   tensor(1.),
#   tensor(0.9580),
#   tensor(0.9053),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8498),
#   tensor(0.9059),
#   tensor(0.6667),
#   tensor(0.4444),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.6000),
#   tensor(0.7762),
#   tensor(0.6591),
#   tensor(0.4699),
#   tensor(0.9286),
#   tensor(0.9062),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9000),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8670),
#   tensor(0.6716),
#   tensor(0.6716),
#   tensor(0.0597),
#   tensor(0.7059),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9231),
#   tensor(0.7500),
#   tensor(0.8000),
#   tensor(0.2500),
#   tensor(0.6154),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(0.4444),
#   tensor(0.8571),
#   tensor(0.9549),
#   tensor(1.),
#   tensor(0.2000),
#   tensor(0.4286),
#   tensor(0.4286),
#   tensor(0.8667),
#   tensor(0.7500),
#   tensor(0.9167),
#   tensor(0.8553),
#   tensor(0.2143),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9084),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8889),
#   tensor(0.8889),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.8776),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.8125),
#   tensor(0.5000),
#   tensor(0.8571),
#   tensor(0.8571),
#   tensor(0.8571),
#   tensor(0.7619),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(0.6500),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8649),
#   tensor(0.1071),
#   tensor(0.7179),
#   tensor(0.2424),
#   tensor(0.6667),
#   tensor(0.6667),
#   tensor(0.8182),
#   tensor(0.5312),
#   tensor(0.6667),
#   tensor(0.6429),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9123),
#   tensor(1.),
#   tensor(0.9023),
#   tensor(0.9048),
#   tensor(0.9048),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8852),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.9167),
#   tensor(0.2500),
#   tensor(0.4000),
#   tensor(0.4615),
#   tensor(0.8750),
#   tensor(0.5000),
#   tensor(0.2889),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7059),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9091),
#   tensor(0.9328),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6765),
#   tensor(0.8286),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(0.8235),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.7500),
#   tensor(0.8182),
#   tensor(0.8182),
#   tensor(1.),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.8644),
#   tensor(0.8992),
#   tensor(0.8992),
#   tensor(0.8992),
#   tensor(1.),
#   tensor(0.7627),
#   tensor(0.6389),
#   tensor(0.8000),
#   tensor(0.8889),
#   tensor(0.8235),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8235),
#   tensor(0.4898),
#   tensor(0.8333),
#   tensor(0.9000),
#   tensor(0.7143),
#   tensor(0.5000),
#   tensor(0.5000),
#   tensor(0.4800),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.3182),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(1.),
#   tensor(0.6000),
#   tensor(1.),
#   tensor(0.8636),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6667),
#   tensor(0.9412),
#   tensor(0.6436),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8571),
#   tensor(0.9231),
#   tensor(0.7273),
#   tensor(0.1739),
#   tensor(0.9091),
#   tensor(1.),
#   tensor(0.7500),
#   tensor(0.4000),
#   tensor(0.3448),
#   tensor(0.8750),
#   tensor(0.7778),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.9333),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8966),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.8276),
#   tensor(0.8600),
#   tensor(1.),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.0351),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.6842),
#   tensor(1.),
#   tensor(0.3846),
#   tensor(1.),
#   tensor(0.9184),
#   tensor(0.8571),
#   tensor(1.),
#   tensor(1.),
#   tensor(0.5000),
#   tensor(0.9091)])

# %% [markdown]
# Label distribution of nodes classified correctly by GAT

# %%
matching_labels_distribution(gat_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.9083)
# matching labels in 2st hop: tensor(0.8623)
# matching labels in 3rd hop: tensor(0.8197)

# %% [markdown]
# Label distribution of nodes classified correctly by our model but not by GAT

# %%
matching_labels_distribution(model_not_gat_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.6593)
# matching labels in 2st hop: tensor(0.4637)
# matching labels in 3rd hop: tensor(0.3674)

# %% [markdown]
# Label distribution of nodes classified correctly our model and by GAT

# %%
matching_labels_distribution(model_and_gat_correct_nodes);
# Out:
# matching labels in 1st hop: tensor(0.9122)
# matching labels in 2st hop: tensor(0.8687)
# matching labels in 3rd hop: tensor(0.8246)

# %% [markdown]
# Label distribution of nodes classified correctly GAT but not by our model

# %%
matching_labels_distribution(gat_not_model_correct_nodes)

# %% [markdown]
# Label distribution of nodes classified incorrectly by both GAT and our model

# %%
matching_labels_distribution(gat_and_model_incorrect_nodes)
